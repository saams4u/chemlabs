# %% [markdown]
# ## Chemprop: Molecular Property Prediction
#
# [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/chemprop)](https://badge.fury.io/py/chemprop)
# [![PyPI version](https://badge.fury.io/py/chemprop.svg)](https://badge.fury.io/py/chemprop)
# [![Build Status](https://github.com/chemprop/chemprop/workflows/tests/badge.svg)](https://github.com/chemprop/chemprop)
#
# This repository contains message passing neural networks for molecular property prediction as described in the paper [Analyzing Learned Molecular Representations for Property Prediction](https://pubs.acs.org/doi/abs/10.1021/acs.jcim.9b00237) and as used in the paper [A Deep Learning Approach to Antibiotic Discovery](https://www.cell.com/cell/fulltext/S0092-8674(20)30102-1).
#
# **Documentation:** Full documentation of Chemprop is available at https://chemprop.readthedocs.io/en/latest/.
#
# **Website:** A web prediction interface with some trained Chemprop models is available at [chemprop.csail.mit.edu](http://chemprop.csail.mit.edu).
#
# **Tutorial:** These [slides](https://docs.google.com/presentation/d/14pbd9LTXzfPSJHyXYkfLxnK8Q80LhVnjImg8a3WqCRM/edit?usp=sharing) provide a Chemprop tutorial and highlight recent additions as of April 28th, 2020.

# %%
# !git clone https://github.com/chemprop/chemprop.git
# %cd /content/chemprop

# !pip install -e .
# !pip install rdkit-pypi==2021.3.1.5

# %%
# !tar -zxvf data.tar.gz

# %% [markdown]
# ### Usage: Chemprop Train

# %%
import logging
from typing import Callable

from tensorboardX import SummaryWriter
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.optim.lr_scheduler import _LRScheduler
from tqdm import tqdm

from chemprop.args import TrainArgs
from chemprop.data import MoleculeDataLoader, MoleculeDataset
from chemprop.models import MoleculeModel
from chemprop.nn_utils import compute_gnorm, compute_pnorm, NoamLR

# %%
def train(model: MoleculeModel,
          data_loader: MoleculeDataLoader,
          loss_func: Callable,
          optimizer: Optimizer,
          scheduler: _LRScheduler,
          args: TrainArgs,
          n_iter: int = 0,
          logger: logging.Logger = None,
          writer: SummaryWriter = None) -> int:
    """
    Trains a model for an epoch.

    :param model: A :class:`~chemprop.models.model.MoleculeModel`.
    :param data_loader: A :class:`~chemprop.data.data.MoleculeDataLoader`.
    :param loss_func: Loss function.
    :param optimizer: An optimizer.
    :param scheduler: A learning rate scheduler.
    :param args: A :class:`~chemprop.args.TrainArgs` object containing arguments for training the model.
    :param n_iter: The number of iterations (training examples) trained on so far.
    :param logger: A logger for recording output.
    :param writer: A tensorboardX SummaryWriter.
    :return: The total number of iterations (training examples) trained on so far.
    """
    debug = logger.debug if logger is not None else print

    model.train()
    loss_sum = iter_count = 0

    for batch in tqdm(data_loader, total=len(data_loader), leave=False):
        # Prepare batch
        batch: MoleculeDataset
        mol_batch, features_batch, target_batch, atom_descriptors_batch, atom_features_batch, bond_features_batch, data_weights_batch = \
            batch.batch_graph(), batch.features(), batch.targets(), batch.atom_descriptors(), \
            batch.atom_features(), batch.bond_features(), batch.data_weights()

        mask = torch.Tensor([[x is not None for x in tb] for tb in target_batch])
        targets = torch.Tensor([[0 if x is None else x for x in tb] for tb in target_batch])

        if args.target_weights is not None:
            target_weights = torch.Tensor(args.target_weights)
        else:
            target_weights = torch.ones_like(targets)
        data_weights = torch.Tensor(data_weights_batch).unsqueeze(1)

        # Run model
        model.zero_grad()
        preds = model(mol_batch, features_batch, atom_descriptors_batch, atom_features_batch, bond_features_batch)

        # Move tensors to correct device
        mask = mask.to(preds.device)
        targets = targets.to(preds.device)
        target_weights = target_weights.to(preds.device)
        data_weights = data_weights.to(preds.device)

        if args.dataset_type == 'multiclass':
            targets = targets.long()
            loss = torch.cat([loss_func(preds[:, target_index, :], targets[:, target_index]).unsqueeze(1) for target_index in range(preds.size(1))], dim=1) * target_weights * data_weights * mask
        else:
            loss = loss_func(preds, targets) * target_weights * data_weights * mask
        loss = loss.sum() / mask.sum()

        loss_sum += loss.item()
        iter_count += 1

        loss.backward()
        if args.grad_clip:
            nn.utils.clip_grad_norm_(model.parameters(), args.grad_clip)
        optimizer.step()

        if isinstance(scheduler, NoamLR):
            scheduler.step()

        n_iter += len(batch)

        # Log and/or add to tensorboard
        if (n_iter // args.batch_size) % args.log_frequency == 0:
            lrs = scheduler.get_lr()
            pnorm = compute_pnorm(model)
            gnorm = compute_gnorm(model)
            loss_avg = loss_sum / iter_count
            loss_sum = iter_count = 0

            lrs_str = ', '.join(f'lr_{i} = {lr:.4e}' for i, lr in enumerate(lrs))
            debug(f'Loss = {loss_avg:.4e}, PNorm = {pnorm:.4f}, GNorm = {gnorm:.4f}, {lrs_str}')

            if writer is not None:
                writer.add_scalar('train_loss', loss_avg, n_iter)
                writer.add_scalar('param_norm', pnorm, n_iter)
                writer.add_scalar('gradient_norm', gnorm, n_iter)
                for i, lr in enumerate(lrs):
                    writer.add_scalar(f'learning_rate_{i}', lr, n_iter)

    return n_iter

# %%
# !python train.py --data_path data/tox21.csv --dataset_type classification --save_dir tox21_checkpoints
# Out:
# Command line
# python train.py --data_path data/tox21.csv --dataset_type classification --save_dir tox21_checkpoints
# Args
# {'activation': 'ReLU',
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': 'data/tox21.csv',
#  'data_weights_path': None,
#  'dataset_type': 'classification',
#  'depth': 3,
#  'device': device(type='cuda'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 30,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'auc',
#  'metrics': ['auc'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 12,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'resume_experiment': False,
#  'save_dir': 'tox21_checkpoints',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'split_sizes': (0.8, 0.1, 0.1),
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['NR-AR',
#                 'NR-AR-LBD',
#                 'NR-AhR',
#                 'NR-Aromatase',
#                 'NR-ER',
#                 'NR-ER-LBD',
#                 'NR-PPAR-gamma',
#                 'SR-ARE',
#                 'SR-ATAD5',
#                 'SR-HSE',
#                 'SR-MMP',
#                 'SR-p53'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# Loading data
# 7831it [00:00, 64931.88it/s]
# 100% 7831/7831 [00:00<00:00, 326120.92it/s]
#   0% 0/7831 [00:00<?, ?it/s][17:15:54] WARNING: not removing hydrogen atom without neighbors
# 100% 7831/7831 [00:00<00:00, 11174.91it/s]
# Number of tasks = 12
# Fold 0
# Splitting data with seed 0
# Class sizes
# NR-AR 0: 95.75%, 1: 4.25%
# NR-AR-LBD 0: 96.49%, 1: 3.51%
# NR-AhR 0: 88.27%, 1: 11.73%
# NR-Aromatase 0: 94.85%, 1: 5.15%
# NR-ER 0: 87.20%, 1: 12.80%
# NR-ER-LBD 0: 94.97%, 1: 5.03%
# NR-PPAR-gamma 0: 97.12%, 1: 2.88%
# SR-ARE 0: 83.85%, 1: 16.15%
# SR-ATAD5 0: 96.27%, 1: 3.73%
# SR-HSE 0: 94.25%, 1: 5.75%
# SR-MMP 0: 84.20%, 1: 15.80%
# SR-p53 0: 93.76%, 1: 6.24%
# Total size = 7,831 | train size = 6,264 | val size = 783 | test size = 784
# Building model 0
# MoleculeModel(
#   (sigmoid): Sigmoid()
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=12, bias=True)
#   )
# )
# Number of parameters = 358,512
# Moving model to cuda
#   0% 0/30 [00:00<?, ?it/s]Epoch 0
#
#   0% 0/126 [00:00<?, ?it/s]
#   1% 1/126 [00:00<00:14,  8.68it/s]
#   2% 3/126 [00:00<00:09, 13.27it/s]
#   4% 5/126 [00:00<00:07, 15.46it/s]
#   6% 7/126 [00:00<00:07, 15.89it/s]
#   7% 9/126 [00:00<00:07, 15.76it/s]Loss = 6.5307e-01, PNorm = 34.3449, GNorm = 0.8312, lr_0 = 1.3960e-04
#
#   9% 11/126 [00:00<00:09, 12.63it/s]
#  10% 13/126 [00:00<00:08, 13.44it/s]
#  12% 15/126 [00:01<00:07, 14.11it/s]
#  13% 17/126 [00:01<00:07, 14.46it/s]
#  15% 19/126 [00:01<00:07, 14.81it/s]Loss = 4.5877e-01, PNorm = 34.3571, GNorm = 0.5662, lr_0 = 1.7560e-04
#
#  17% 21/126 [00:01<00:06, 15.32it/s]
#  18% 23/126 [00:01<00:06, 15.46it/s]
#  20% 25/126 [00:01<00:06, 15.50it/s]
#  21% 27/126 [00:01<00:06, 15.77it/s]
#  23% 29/126 [00:02<00:08, 11.95it/s]Loss = 2.9521e-01, PNorm = 34.3764, GNorm = 0.2599, lr_0 = 2.1160e-04
#
#  25% 31/126 [00:02<00:07, 12.67it/s]
#  26% 33/126 [00:02<00:06, 13.34it/s]
#  28% 35/126 [00:02<00:06, 14.10it/s]
#  29% 37/126 [00:02<00:05, 15.09it/s]
#  31% 39/126 [00:02<00:05, 15.60it/s]Loss = 2.8976e-01, PNorm = 34.3854, GNorm = 0.2898, lr_0 = 2.4760e-04
#
#  33% 41/126 [00:02<00:05, 15.70it/s]
#  34% 43/126 [00:02<00:05, 15.68it/s]
#  36% 45/126 [00:03<00:05, 16.12it/s]
#  37% 47/126 [00:03<00:07, 10.91it/s]
#  39% 49/126 [00:03<00:06, 12.17it/s]Loss = 2.6006e-01, PNorm = 34.3925, GNorm = 0.2469, lr_0 = 2.8360e-04
#
#  40% 51/126 [00:03<00:05, 13.08it/s]
#  42% 53/126 [00:03<00:05, 13.74it/s]
#  44% 55/126 [00:03<00:04, 14.41it/s]
#  45% 57/126 [00:04<00:04, 15.05it/s]
#  47% 59/126 [00:04<00:04, 15.51it/s]Loss = 2.6144e-01, PNorm = 34.4011, GNorm = 0.1559, lr_0 = 3.1960e-04
#
#  48% 61/126 [00:04<00:04, 15.47it/s]
#  50% 63/126 [00:04<00:04, 15.71it/s]
#  52% 65/126 [00:04<00:03, 15.74it/s]
#  53% 67/126 [00:04<00:03, 15.29it/s]
#  55% 69/126 [00:05<00:05,  9.76it/s]Loss = 2.5971e-01, PNorm = 34.4157, GNorm = 0.2849, lr_0 = 3.5560e-04
#
#  56% 71/126 [00:05<00:04, 11.07it/s]
#  58% 73/126 [00:05<00:04, 12.48it/s]
#  60% 75/126 [00:05<00:03, 13.54it/s]
#  61% 77/126 [00:05<00:03, 14.38it/s]
#  63% 79/126 [00:05<00:03, 15.28it/s]Loss = 2.6849e-01, PNorm = 34.4322, GNorm = 0.1890, lr_0 = 3.9160e-04
#
#  64% 81/126 [00:05<00:02, 15.92it/s]
#  66% 83/126 [00:05<00:02, 15.80it/s]
#  67% 85/126 [00:05<00:02, 15.85it/s]
#  69% 87/126 [00:06<00:02, 16.24it/s]
#  71% 89/126 [00:06<00:02, 16.36it/s]Loss = 2.2572e-01, PNorm = 34.4519, GNorm = 0.2456, lr_0 = 4.2760e-04
#
#  72% 91/126 [00:06<00:02, 16.38it/s]
#  74% 93/126 [00:06<00:02, 16.38it/s]
#  75% 95/126 [00:06<00:03,  8.67it/s]
#  77% 97/126 [00:07<00:02, 10.01it/s]
#  79% 99/126 [00:07<00:02, 11.13it/s]Loss = 2.6066e-01, PNorm = 34.4676, GNorm = 0.2803, lr_0 = 4.6360e-04
#
#  80% 101/126 [00:07<00:02, 12.40it/s]
#  82% 103/126 [00:07<00:01, 13.46it/s]
#  83% 105/126 [00:07<00:01, 13.92it/s]
#  85% 107/126 [00:07<00:01, 14.74it/s]
#  87% 109/126 [00:07<00:01, 15.28it/s]Loss = 2.3627e-01, PNorm = 34.4900, GNorm = 0.3067, lr_0 = 4.9960e-04
#
#  88% 111/126 [00:07<00:00, 15.37it/s]
#  90% 113/126 [00:08<00:00, 15.81it/s]
#  91% 115/126 [00:08<00:00, 15.65it/s]
#  93% 117/126 [00:08<00:00, 15.58it/s]
#  94% 119/126 [00:08<00:00, 15.92it/s]Loss = 2.3811e-01, PNorm = 34.5107, GNorm = 0.2800, lr_0 = 5.3560e-04
#
#  96% 121/126 [00:08<00:00, 16.20it/s]
#  98% 123/126 [00:08<00:00, 16.12it/s]
#  99% 125/126 [00:08<00:00, 16.66it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:00, 19.95it/s]
#  25% 4/16 [00:00<00:00, 19.26it/s]
#  38% 6/16 [00:00<00:01,  6.29it/s]
#  50% 8/16 [00:00<00:00,  8.49it/s]
#  62% 10/16 [00:00<00:00, 10.53it/s]
#  75% 12/16 [00:01<00:00, 12.07it/s]
#  88% 14/16 [00:01<00:00, 13.51it/s]
#                                    Validation auc = 0.704586
#   3% 1/30 [00:10<04:55, 10.20s/it]Epoch 1
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 2.0056e-01, PNorm = 34.5367, GNorm = 0.2750, lr_0 = 5.7520e-04
#
#   4% 5/126 [00:00<00:02, 48.69it/s]
#   9% 11/126 [00:00<00:02, 50.59it/s]Loss = 2.3421e-01, PNorm = 34.5602, GNorm = 0.3801, lr_0 = 6.1120e-04
#
#  13% 17/126 [00:00<00:02, 49.93it/s]
#  18% 23/126 [00:00<00:02, 49.94it/s]Loss = 2.5318e-01, PNorm = 34.5902, GNorm = 0.3700, lr_0 = 6.4720e-04
#
#  22% 28/126 [00:00<00:01, 49.71it/s]
#  27% 34/126 [00:00<00:01, 50.51it/s]Loss = 2.4651e-01, PNorm = 34.6216, GNorm = 0.1842, lr_0 = 6.8320e-04
#
#  32% 40/126 [00:00<00:01, 50.27it/s]Loss = 2.1907e-01, PNorm = 34.6645, GNorm = 0.7369, lr_0 = 7.1920e-04
#
#  37% 46/126 [00:00<00:01, 50.11it/s]
#  41% 52/126 [00:01<00:01, 50.72it/s]Loss = 2.4446e-01, PNorm = 34.6889, GNorm = 0.2527, lr_0 = 7.5520e-04
#
#  46% 58/126 [00:01<00:01, 50.59it/s]
#  51% 64/126 [00:01<00:01, 50.51it/s]Loss = 2.2811e-01, PNorm = 34.7177, GNorm = 0.2905, lr_0 = 7.9120e-04
#
#  56% 70/126 [00:01<00:01, 49.94it/s]Loss = 2.2799e-01, PNorm = 34.7619, GNorm = 0.1595, lr_0 = 8.2720e-04
#
#  60% 76/126 [00:01<00:01, 49.88it/s]
#  64% 81/126 [00:01<00:00, 49.73it/s]Loss = 1.9189e-01, PNorm = 34.8028, GNorm = 0.1263, lr_0 = 8.6320e-04
#
#  69% 87/126 [00:01<00:00, 50.59it/s]
#  74% 93/126 [00:01<00:00, 50.16it/s]Loss = 2.4723e-01, PNorm = 34.8337, GNorm = 0.3356, lr_0 = 8.9920e-04
#
#  79% 99/126 [00:01<00:00, 49.62it/s]
#  83% 104/126 [00:02<00:00, 48.61it/s]Loss = 2.5083e-01, PNorm = 34.8740, GNorm = 0.3491, lr_0 = 9.3520e-04
#
#  87% 109/126 [00:02<00:00, 48.90it/s]Loss = 2.1626e-01, PNorm = 34.9193, GNorm = 0.1429, lr_0 = 9.7120e-04
#
#  91% 115/126 [00:02<00:00, 49.97it/s]
#  96% 121/126 [00:02<00:00, 50.20it/s]Loss = 2.3524e-01, PNorm = 34.9741, GNorm = 0.2122, lr_0 = 9.9869e-04
# Loss = 4.2411e-01, PNorm = 34.9792, GNorm = 0.5399, lr_0 = 9.9803e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 72.30it/s]
# 100% 16/16 [00:00<00:00, 73.68it/s]
#                                    Validation auc = 0.730885
#   7% 2/30 [00:12<02:43,  5.84s/it]Epoch 2
#
#   0% 0/126 [00:00<?, ?it/s]
#   5% 6/126 [00:00<00:02, 50.43it/s]Loss = 2.0851e-01, PNorm = 35.0338, GNorm = 0.1400, lr_0 = 9.9148e-04
#
#  10% 12/126 [00:00<00:02, 50.20it/s]
#  14% 18/126 [00:00<00:02, 49.91it/s]Loss = 1.9020e-01, PNorm = 35.0795, GNorm = 0.1663, lr_0 = 9.8498e-04
#
#  18% 23/126 [00:00<00:02, 49.36it/s]
#  23% 29/126 [00:00<00:01, 49.51it/s]Loss = 2.1917e-01, PNorm = 35.1160, GNorm = 0.1793, lr_0 = 9.7852e-04
#
#  27% 34/126 [00:00<00:01, 48.75it/s]Loss = 2.1622e-01, PNorm = 35.1817, GNorm = 0.1552, lr_0 = 9.7211e-04
#
#  32% 40/126 [00:00<00:01, 50.01it/s]
#  36% 45/126 [00:00<00:01, 49.93it/s]Loss = 2.3025e-01, PNorm = 35.2439, GNorm = 0.2921, lr_0 = 9.6573e-04
#
#  40% 50/126 [00:01<00:01, 49.76it/s]
#  44% 56/126 [00:01<00:01, 50.36it/s]Loss = 2.0910e-01, PNorm = 35.3004, GNorm = 0.1686, lr_0 = 9.5940e-04
#
#  49% 62/126 [00:01<00:01, 49.60it/s]
#  53% 67/126 [00:01<00:01, 49.68it/s]Loss = 2.1537e-01, PNorm = 35.3560, GNorm = 0.1888, lr_0 = 9.5311e-04
#
#  57% 72/126 [00:01<00:01, 49.05it/s]
#  62% 78/126 [00:01<00:00, 49.65it/s]Loss = 2.1262e-01, PNorm = 35.4239, GNorm = 0.1579, lr_0 = 9.4686e-04
#
#  67% 84/126 [00:01<00:00, 50.14it/s]Loss = 2.4806e-01, PNorm = 35.4827, GNorm = 0.1855, lr_0 = 9.4065e-04
#
#  71% 90/126 [00:01<00:00, 50.94it/s]
#  76% 96/126 [00:01<00:00, 50.56it/s]Loss = 2.2403e-01, PNorm = 35.5352, GNorm = 0.1471, lr_0 = 9.3448e-04
#
#  81% 102/126 [00:02<00:00, 50.05it/s]
#  86% 108/126 [00:02<00:00, 50.56it/s]Loss = 2.2582e-01, PNorm = 35.5982, GNorm = 0.1333, lr_0 = 9.2836e-04
#
#  90% 114/126 [00:02<00:00, 50.47it/s]Loss = 2.2546e-01, PNorm = 35.6460, GNorm = 0.2837, lr_0 = 9.2227e-04
#
#  95% 120/126 [00:02<00:00, 50.35it/s]
# 100% 126/126 [00:02<00:00, 51.33it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 71.61it/s]
# 100% 16/16 [00:00<00:00, 72.60it/s]
#                                    Validation auc = 0.784430
#  10% 3/30 [00:15<02:00,  4.45s/it]Epoch 3
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 2.1415e-01, PNorm = 35.7042, GNorm = 0.1456, lr_0 = 9.1562e-04
#
#   4% 5/126 [00:00<00:02, 47.89it/s]
#   9% 11/126 [00:00<00:02, 50.25it/s]Loss = 2.1145e-01, PNorm = 35.7664, GNorm = 0.1788, lr_0 = 9.0961e-04
#
#  13% 17/126 [00:00<00:02, 48.21it/s]
#  18% 23/126 [00:00<00:02, 49.47it/s]Loss = 2.0608e-01, PNorm = 35.8304, GNorm = 0.2632, lr_0 = 9.0365e-04
#
#  22% 28/126 [00:00<00:02, 48.17it/s]
#  27% 34/126 [00:00<00:01, 49.15it/s]Loss = 2.0054e-01, PNorm = 35.8902, GNorm = 0.2078, lr_0 = 8.9772e-04
#
#  31% 39/126 [00:00<00:01, 49.33it/s]Loss = 2.2474e-01, PNorm = 35.9639, GNorm = 0.3010, lr_0 = 8.9184e-04
#
#  36% 45/126 [00:00<00:01, 49.63it/s]
#  40% 51/126 [00:01<00:01, 50.04it/s]Loss = 2.0160e-01, PNorm = 36.0175, GNorm = 0.2130, lr_0 = 8.8599e-04
#
#  45% 57/126 [00:01<00:01, 50.35it/s]
#  50% 63/126 [00:01<00:01, 50.38it/s]Loss = 2.0483e-01, PNorm = 36.0651, GNorm = 0.2298, lr_0 = 8.8018e-04
#
#  55% 69/126 [00:01<00:01, 50.49it/s]Loss = 2.1940e-01, PNorm = 36.1287, GNorm = 0.1592, lr_0 = 8.7441e-04
#
#  60% 75/126 [00:01<00:01, 49.53it/s]
#  63% 80/126 [00:01<00:00, 49.42it/s]Loss = 2.0526e-01, PNorm = 36.1983, GNorm = 0.3116, lr_0 = 8.6867e-04
#
#  68% 86/126 [00:01<00:00, 49.51it/s]
#  72% 91/126 [00:01<00:00, 48.94it/s]Loss = 2.1330e-01, PNorm = 36.2478, GNorm = 0.1453, lr_0 = 8.6298e-04
#
#  76% 96/126 [00:01<00:00, 48.68it/s]
#  81% 102/126 [00:02<00:00, 49.85it/s]Loss = 2.1113e-01, PNorm = 36.3038, GNorm = 0.3192, lr_0 = 8.5732e-04
#
#  85% 107/126 [00:02<00:00, 49.26it/s]
#  89% 112/126 [00:02<00:00, 49.30it/s]Loss = 2.0227e-01, PNorm = 36.3582, GNorm = 0.1824, lr_0 = 8.5170e-04
#
#  93% 117/126 [00:02<00:00, 48.86it/s]
#  98% 123/126 [00:02<00:00, 49.64it/s]Loss = 2.0778e-01, PNorm = 36.4182, GNorm = 0.4320, lr_0 = 8.4611e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 69.49it/s]
#  94% 15/16 [00:00<00:00, 69.19it/s]
#                                    Validation auc = 0.813359
#  13% 4/30 [00:18<01:39,  3.81s/it]Epoch 4
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 48.45it/s]Loss = 1.9919e-01, PNorm = 36.4664, GNorm = 0.1746, lr_0 = 8.4057e-04
#
#   9% 11/126 [00:00<00:02, 49.93it/s]
#  13% 17/126 [00:00<00:02, 50.24it/s]Loss = 2.0281e-01, PNorm = 36.5260, GNorm = 0.1785, lr_0 = 8.3505e-04
#
#  18% 23/126 [00:00<00:02, 50.31it/s]Loss = 2.0704e-01, PNorm = 36.5845, GNorm = 0.6765, lr_0 = 8.2958e-04
#
#  23% 29/126 [00:00<00:01, 49.93it/s]
#  27% 34/126 [00:00<00:01, 49.72it/s]Loss = 2.0489e-01, PNorm = 36.6424, GNorm = 0.2056, lr_0 = 8.2414e-04
#
#  32% 40/126 [00:00<00:01, 50.29it/s]
#  37% 46/126 [00:00<00:01, 49.60it/s]Loss = 2.0524e-01, PNorm = 36.7150, GNorm = 0.2265, lr_0 = 8.1873e-04
#
#  41% 52/126 [00:01<00:01, 49.49it/s]
#  46% 58/126 [00:01<00:01, 49.72it/s]Loss = 2.1857e-01, PNorm = 36.7846, GNorm = 0.1475, lr_0 = 8.1337e-04
#
#  50% 63/126 [00:01<00:01, 49.56it/s]Loss = 2.2025e-01, PNorm = 36.8552, GNorm = 0.2956, lr_0 = 8.0803e-04
#
#  55% 69/126 [00:01<00:01, 49.70it/s]
#  59% 74/126 [00:01<00:01, 49.64it/s]Loss = 2.1077e-01, PNorm = 36.9026, GNorm = 0.3315, lr_0 = 8.0273e-04
#
#  63% 79/126 [00:01<00:00, 49.19it/s]
#  67% 85/126 [00:01<00:00, 49.42it/s]Loss = 1.8693e-01, PNorm = 36.9783, GNorm = 0.1594, lr_0 = 7.9747e-04
#
#  71% 90/126 [00:01<00:00, 49.31it/s]
#  75% 95/126 [00:01<00:00, 48.96it/s]Loss = 2.0051e-01, PNorm = 37.0356, GNorm = 0.3319, lr_0 = 7.9224e-04
#
#  79% 100/126 [00:02<00:00, 49.15it/s]
#  84% 106/126 [00:02<00:00, 49.69it/s]Loss = 1.8626e-01, PNorm = 37.0897, GNorm = 0.1499, lr_0 = 7.8705e-04
#
#  89% 112/126 [00:02<00:00, 49.69it/s]
#  94% 118/126 [00:02<00:00, 50.15it/s]Loss = 1.9638e-01, PNorm = 37.1531, GNorm = 0.3361, lr_0 = 7.8188e-04
#
#  98% 124/126 [00:02<00:00, 50.17it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 71.94it/s]
# 100% 16/16 [00:00<00:00, 71.70it/s]
#                                    Validation auc = 0.829881
#  17% 5/30 [00:21<01:26,  3.45s/it]Epoch 5
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.8403e-01, PNorm = 37.2094, GNorm = 0.3457, lr_0 = 7.7625e-04
#
#   4% 5/126 [00:00<00:02, 47.42it/s]
#   9% 11/126 [00:00<00:02, 49.74it/s]Loss = 1.8393e-01, PNorm = 37.2681, GNorm = 0.2500, lr_0 = 7.7116e-04
#
#  13% 16/126 [00:00<00:02, 48.92it/s]
#  17% 22/126 [00:00<00:02, 50.57it/s]Loss = 2.0399e-01, PNorm = 37.3180, GNorm = 0.2533, lr_0 = 7.6610e-04
#
#  22% 28/126 [00:00<00:01, 50.07it/s]Loss = 1.9327e-01, PNorm = 37.3816, GNorm = 0.2394, lr_0 = 7.6108e-04
#
#  27% 34/126 [00:00<00:01, 50.39it/s]
#  32% 40/126 [00:00<00:01, 49.96it/s]Loss = 1.9441e-01, PNorm = 37.4357, GNorm = 0.1841, lr_0 = 7.5609e-04
#
#  36% 45/126 [00:00<00:01, 49.30it/s]
#  40% 51/126 [00:01<00:01, 49.52it/s]Loss = 2.1053e-01, PNorm = 37.4877, GNorm = 0.1688, lr_0 = 7.5113e-04
#
#  44% 56/126 [00:01<00:03, 20.74it/s]
#  49% 62/126 [00:01<00:02, 25.66it/s]Loss = 1.9169e-01, PNorm = 37.5470, GNorm = 0.4203, lr_0 = 7.4620e-04
#
#  53% 67/126 [00:01<00:02, 29.41it/s]
#  58% 73/126 [00:01<00:01, 34.11it/s]Loss = 1.8962e-01, PNorm = 37.6041, GNorm = 0.1431, lr_0 = 7.4131e-04
#
#  62% 78/126 [00:02<00:01, 37.31it/s]
#  66% 83/126 [00:02<00:01, 40.05it/s]Loss = 2.0084e-01, PNorm = 37.6593, GNorm = 0.1994, lr_0 = 7.3645e-04
#
#  71% 89/126 [00:02<00:00, 43.00it/s]Loss = 1.8713e-01, PNorm = 37.7052, GNorm = 0.1760, lr_0 = 7.3162e-04
#
#  75% 95/126 [00:02<00:00, 45.19it/s]
#  80% 101/126 [00:02<00:00, 46.79it/s]Loss = 1.8003e-01, PNorm = 37.7586, GNorm = 0.1931, lr_0 = 7.2682e-04
#
#  85% 107/126 [00:02<00:00, 47.95it/s]
#  89% 112/126 [00:02<00:00, 48.34it/s]Loss = 2.2335e-01, PNorm = 37.8041, GNorm = 0.1470, lr_0 = 7.2206e-04
#
#  93% 117/126 [00:02<00:00, 48.60it/s]
#  98% 123/126 [00:02<00:00, 49.00it/s]Loss = 2.0661e-01, PNorm = 37.8669, GNorm = 0.1643, lr_0 = 7.1732e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 69.77it/s]
#  94% 15/16 [00:00<00:00, 69.27it/s]
#                                    Validation auc = 0.834895
#  20% 6/30 [00:24<01:21,  3.40s/it]Epoch 6
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 49.01it/s]Loss = 2.0364e-01, PNorm = 37.9445, GNorm = 0.2134, lr_0 = 7.1215e-04
#
#   8% 10/126 [00:00<00:02, 48.51it/s]
#  13% 16/126 [00:00<00:02, 50.34it/s]Loss = 1.5641e-01, PNorm = 38.0064, GNorm = 0.1747, lr_0 = 7.0748e-04
#
#  17% 22/126 [00:00<00:02, 49.64it/s]
#  22% 28/126 [00:00<00:01, 50.43it/s]Loss = 1.8627e-01, PNorm = 38.0626, GNorm = 0.2390, lr_0 = 7.0284e-04
#
#  27% 34/126 [00:00<00:01, 50.26it/s]Loss = 1.7054e-01, PNorm = 38.1201, GNorm = 0.2115, lr_0 = 6.9823e-04
#
#  32% 40/126 [00:00<00:01, 49.34it/s]
#  37% 46/126 [00:00<00:01, 49.80it/s]Loss = 2.0187e-01, PNorm = 38.1668, GNorm = 0.2572, lr_0 = 6.9365e-04
#
#  41% 52/126 [00:01<00:01, 49.96it/s]
#  45% 57/126 [00:01<00:01, 49.40it/s]Loss = 1.9477e-01, PNorm = 38.2215, GNorm = 0.1792, lr_0 = 6.8911e-04
#
#  49% 62/126 [00:01<00:01, 49.39it/s]
#  54% 68/126 [00:01<00:01, 49.89it/s]Loss = 1.9485e-01, PNorm = 38.2666, GNorm = 0.5654, lr_0 = 6.8459e-04
#
#  58% 73/126 [00:01<00:01, 49.67it/s]Loss = 1.7894e-01, PNorm = 38.3136, GNorm = 0.1504, lr_0 = 6.8010e-04
#
#  63% 79/126 [00:01<00:00, 49.56it/s]
#  67% 84/126 [00:01<00:00, 48.72it/s]Loss = 2.0955e-01, PNorm = 38.3698, GNorm = 0.5666, lr_0 = 6.7564e-04
#
#  71% 89/126 [00:01<00:00, 48.86it/s]
#  75% 94/126 [00:01<00:00, 48.22it/s]Loss = 1.7203e-01, PNorm = 38.4370, GNorm = 0.1418, lr_0 = 6.7121e-04
#
#  79% 100/126 [00:02<00:00, 49.10it/s]
#  84% 106/126 [00:02<00:00, 49.85it/s]Loss = 1.9771e-01, PNorm = 38.4847, GNorm = 0.1804, lr_0 = 6.6681e-04
#
#  89% 112/126 [00:02<00:00, 50.30it/s]
#  94% 118/126 [00:02<00:00, 50.62it/s]Loss = 2.0089e-01, PNorm = 38.5295, GNorm = 0.3009, lr_0 = 6.6243e-04
#
#  98% 124/126 [00:02<00:00, 50.01it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.74it/s]
# 100% 16/16 [00:00<00:00, 70.22it/s]
#                                    Validation auc = 0.839953
#  23% 7/30 [00:27<01:13,  3.21s/it]Epoch 7
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 2.0208e-01, PNorm = 38.5978, GNorm = 0.4667, lr_0 = 6.5766e-04
#
#   4% 5/126 [00:00<00:02, 47.39it/s]
#   9% 11/126 [00:00<00:02, 48.88it/s]Loss = 1.8319e-01, PNorm = 38.6547, GNorm = 0.1235, lr_0 = 6.5335e-04
#
#  13% 16/126 [00:00<00:02, 47.92it/s]
#  17% 21/126 [00:00<00:02, 47.84it/s]Loss = 1.9567e-01, PNorm = 38.7187, GNorm = 0.2061, lr_0 = 6.4906e-04
#
#  21% 26/126 [00:00<00:02, 48.29it/s]
#  25% 31/126 [00:00<00:01, 47.68it/s]Loss = 1.8957e-01, PNorm = 38.7748, GNorm = 0.2228, lr_0 = 6.4481e-04
#
#  29% 36/126 [00:00<00:01, 46.09it/s]
#  33% 41/126 [00:00<00:01, 46.17it/s]Loss = 1.9470e-01, PNorm = 38.8187, GNorm = 0.1762, lr_0 = 6.4058e-04
#
#  37% 46/126 [00:00<00:01, 45.66it/s]
#  40% 51/126 [00:01<00:01, 46.22it/s]Loss = 1.8382e-01, PNorm = 38.8728, GNorm = 0.1682, lr_0 = 6.3638e-04
#
#  44% 56/126 [00:01<00:01, 46.66it/s]
#  48% 61/126 [00:01<00:01, 46.89it/s]Loss = 2.0952e-01, PNorm = 38.9165, GNorm = 0.7022, lr_0 = 6.3220e-04
#
#  52% 66/126 [00:01<00:01, 47.13it/s]
#  56% 71/126 [00:01<00:01, 47.89it/s]Loss = 1.9913e-01, PNorm = 38.9610, GNorm = 0.3101, lr_0 = 6.2806e-04
#
#  60% 76/126 [00:01<00:01, 48.26it/s]
#  65% 82/126 [00:01<00:00, 49.65it/s]Loss = 2.0062e-01, PNorm = 39.0205, GNorm = 0.2274, lr_0 = 6.2394e-04
#
#  69% 87/126 [00:01<00:00, 49.57it/s]
#  73% 92/126 [00:01<00:00, 49.22it/s]Loss = 1.7762e-01, PNorm = 39.0700, GNorm = 0.1570, lr_0 = 6.1985e-04
#
#  78% 98/126 [00:02<00:00, 49.59it/s]Loss = 1.7796e-01, PNorm = 39.1221, GNorm = 0.3236, lr_0 = 6.1578e-04
#
#  83% 104/126 [00:02<00:00, 50.04it/s]
#  87% 109/126 [00:02<00:00, 50.02it/s]Loss = 1.9515e-01, PNorm = 39.1649, GNorm = 0.5598, lr_0 = 6.1175e-04
#
#  90% 114/126 [00:02<00:00, 49.55it/s]
#  95% 120/126 [00:02<00:00, 49.73it/s]Loss = 1.7746e-01, PNorm = 39.2156, GNorm = 0.3108, lr_0 = 6.0774e-04
#
#  99% 125/126 [00:02<00:00, 49.41it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.98it/s]
# 100% 16/16 [00:00<00:00, 70.75it/s]
#                                    Validation auc = 0.842025
#  27% 8/30 [00:30<01:08,  3.11s/it]Epoch 8
#
#   0% 0/126 [00:00<?, ?it/s]
#   5% 6/126 [00:00<00:02, 49.73it/s]Loss = 1.8094e-01, PNorm = 39.2662, GNorm = 0.1778, lr_0 = 6.0375e-04
#
#  10% 12/126 [00:00<00:02, 50.09it/s]Loss = 1.7291e-01, PNorm = 39.3106, GNorm = 0.2526, lr_0 = 5.9979e-04
#
#  14% 18/126 [00:00<00:02, 48.93it/s]
#  18% 23/126 [00:00<00:02, 48.91it/s]Loss = 2.0173e-01, PNorm = 39.3605, GNorm = 0.2321, lr_0 = 5.9586e-04
#
#  22% 28/126 [00:00<00:01, 49.14it/s]
#  26% 33/126 [00:00<00:01, 48.86it/s]Loss = 1.8100e-01, PNorm = 39.4068, GNorm = 0.1894, lr_0 = 5.9195e-04
#
#  30% 38/126 [00:00<00:01, 48.90it/s]
#  35% 44/126 [00:00<00:01, 49.37it/s]Loss = 1.8319e-01, PNorm = 39.4611, GNorm = 0.2967, lr_0 = 5.8807e-04
#
#  39% 49/126 [00:00<00:01, 49.45it/s]
#  44% 55/126 [00:01<00:01, 50.31it/s]Loss = 1.8404e-01, PNorm = 39.5047, GNorm = 0.1430, lr_0 = 5.8421e-04
#
#  48% 61/126 [00:01<00:01, 50.24it/s]
#  53% 67/126 [00:01<00:01, 50.33it/s]Loss = 1.9711e-01, PNorm = 39.5474, GNorm = 0.2527, lr_0 = 5.8038e-04
#
#  58% 73/126 [00:01<00:01, 49.94it/s]Loss = 1.7419e-01, PNorm = 39.5949, GNorm = 0.2738, lr_0 = 5.7658e-04
#
#  63% 79/126 [00:01<00:00, 50.13it/s]
#  67% 85/126 [00:01<00:00, 48.96it/s]Loss = 1.6509e-01, PNorm = 39.6340, GNorm = 0.3507, lr_0 = 5.7280e-04
#
#  71% 90/126 [00:01<00:00, 48.11it/s]
#  76% 96/126 [00:01<00:00, 49.49it/s]Loss = 1.7931e-01, PNorm = 39.6783, GNorm = 0.3154, lr_0 = 5.6904e-04
#
#  80% 101/126 [00:02<00:00, 49.49it/s]
#  84% 106/126 [00:02<00:00, 49.43it/s]Loss = 1.8097e-01, PNorm = 39.7142, GNorm = 0.1895, lr_0 = 5.6531e-04
#
#  88% 111/126 [00:02<00:00, 49.37it/s]
#  92% 116/126 [00:02<00:00, 49.46it/s]Loss = 1.9254e-01, PNorm = 39.7590, GNorm = 0.1441, lr_0 = 5.6160e-04
#
#  97% 122/126 [00:02<00:00, 49.79it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 71.65it/s]
# 100% 16/16 [00:00<00:00, 72.36it/s]
#                                    Validation auc = 0.845830
#  30% 9/30 [00:33<01:03,  3.02s/it]Epoch 9
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.7513e-01, PNorm = 39.8022, GNorm = 0.3859, lr_0 = 5.5755e-04
#
#   4% 5/126 [00:00<00:02, 41.97it/s]
#   9% 11/126 [00:00<00:02, 46.92it/s]Loss = 1.7895e-01, PNorm = 39.8563, GNorm = 0.1921, lr_0 = 5.5390e-04
#
#  13% 16/126 [00:00<00:02, 47.99it/s]
#  17% 21/126 [00:00<00:02, 48.42it/s]Loss = 1.7572e-01, PNorm = 39.9135, GNorm = 0.2219, lr_0 = 5.5026e-04
#
#  21% 27/126 [00:00<00:02, 49.12it/s]
#  25% 32/126 [00:00<00:01, 49.25it/s]Loss = 1.8109e-01, PNorm = 39.9704, GNorm = 0.2644, lr_0 = 5.4666e-04
#
#  29% 37/126 [00:00<00:01, 49.40it/s]Loss = 1.8653e-01, PNorm = 40.0229, GNorm = 0.1926, lr_0 = 5.4307e-04
#
#  34% 43/126 [00:00<00:01, 49.71it/s]
#  38% 48/126 [00:00<00:01, 49.72it/s]Loss = 1.8310e-01, PNorm = 40.0590, GNorm = 0.2364, lr_0 = 5.3951e-04
#
#  43% 54/126 [00:01<00:01, 50.14it/s]
#  48% 60/126 [00:01<00:01, 49.80it/s]Loss = 1.8585e-01, PNorm = 40.0998, GNorm = 0.2108, lr_0 = 5.3597e-04
#
#  52% 65/126 [00:01<00:01, 49.70it/s]
#  56% 71/126 [00:01<00:01, 50.45it/s]Loss = 1.8621e-01, PNorm = 40.1414, GNorm = 0.2084, lr_0 = 5.3246e-04
#
#  61% 77/126 [00:01<00:00, 50.03it/s]Loss = 1.7541e-01, PNorm = 40.1733, GNorm = 0.1996, lr_0 = 5.2897e-04
#
#  66% 83/126 [00:01<00:00, 50.06it/s]
#  71% 89/126 [00:01<00:00, 49.85it/s]Loss = 1.7848e-01, PNorm = 40.2150, GNorm = 0.4826, lr_0 = 5.2550e-04
#
#  75% 94/126 [00:01<00:00, 49.79it/s]
#  79% 100/126 [00:02<00:00, 50.28it/s]Loss = 1.8690e-01, PNorm = 40.2562, GNorm = 0.1802, lr_0 = 5.2205e-04
#
#  84% 106/126 [00:02<00:00, 51.07it/s]
#  89% 112/126 [00:02<00:00, 50.88it/s]Loss = 1.8239e-01, PNorm = 40.2914, GNorm = 0.1351, lr_0 = 5.1863e-04
#
#  94% 118/126 [00:02<00:00, 50.78it/s]Loss = 1.6666e-01, PNorm = 40.3234, GNorm = 0.1806, lr_0 = 5.1523e-04
#
#  98% 124/126 [00:02<00:00, 50.66it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 72.61it/s]
# 100% 16/16 [00:00<00:00, 73.28it/s]
#                                    Validation auc = 0.849893
#  33% 10/30 [00:36<00:59,  2.95s/it]Epoch 10
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 47.74it/s]Loss = 1.7389e-01, PNorm = 40.3687, GNorm = 0.4526, lr_0 = 5.1151e-04
#
#   9% 11/126 [00:00<00:02, 49.96it/s]
#  13% 17/126 [00:00<00:02, 51.70it/s]Loss = 1.6440e-01, PNorm = 40.4197, GNorm = 0.3595, lr_0 = 5.0816e-04
#
#  18% 23/126 [00:00<00:02, 51.02it/s]Loss = 1.8069e-01, PNorm = 40.4567, GNorm = 0.1913, lr_0 = 5.0483e-04
#
#  23% 29/126 [00:00<00:01, 49.40it/s]
#  28% 35/126 [00:00<00:01, 49.84it/s]Loss = 2.0572e-01, PNorm = 40.4970, GNorm = 0.4286, lr_0 = 5.0152e-04
#
#  33% 41/126 [00:00<00:01, 50.57it/s]
#  37% 47/126 [00:00<00:01, 50.89it/s]Loss = 1.7982e-01, PNorm = 40.5466, GNorm = 0.1815, lr_0 = 4.9823e-04
#
#  42% 53/126 [00:01<00:01, 50.68it/s]Loss = 1.8943e-01, PNorm = 40.5878, GNorm = 0.2453, lr_0 = 4.9496e-04
#
#  47% 59/126 [00:01<00:01, 49.34it/s]
#  51% 64/126 [00:01<00:01, 49.24it/s]Loss = 1.6493e-01, PNorm = 40.6331, GNorm = 0.2340, lr_0 = 4.9172e-04
#
#  55% 69/126 [00:01<00:01, 49.11it/s]
#  59% 74/126 [00:01<00:01, 49.28it/s]Loss = 1.7483e-01, PNorm = 40.6687, GNorm = 0.1596, lr_0 = 4.8849e-04
#
#  63% 79/126 [00:01<00:00, 49.10it/s]
#  67% 85/126 [00:01<00:00, 50.09it/s]Loss = 1.5203e-01, PNorm = 40.7041, GNorm = 0.1693, lr_0 = 4.8529e-04
#
#  72% 91/126 [00:01<00:00, 49.83it/s]
#  76% 96/126 [00:01<00:00, 49.80it/s]Loss = 1.7914e-01, PNorm = 40.7477, GNorm = 0.2163, lr_0 = 4.8211e-04
#
#  81% 102/126 [00:02<00:00, 49.70it/s]Loss = 1.7333e-01, PNorm = 40.7848, GNorm = 0.2681, lr_0 = 4.7895e-04
#
#  86% 108/126 [00:02<00:00, 49.97it/s]
#  90% 113/126 [00:02<00:00, 49.50it/s]Loss = 1.7733e-01, PNorm = 40.8121, GNorm = 0.1687, lr_0 = 4.7580e-04
#
#  94% 118/126 [00:02<00:00, 49.02it/s]
#  98% 124/126 [00:02<00:00, 49.76it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  44% 7/16 [00:00<00:00, 65.42it/s]
#  88% 14/16 [00:00<00:00, 63.39it/s]
#                                    Validation auc = 0.844256
#  37% 11/30 [00:38<00:55,  2.90s/it]Epoch 11
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.4890e-01, PNorm = 40.8494, GNorm = 0.1679, lr_0 = 4.7268e-04
#
#   3% 4/126 [00:00<00:03, 39.46it/s]
#   7% 9/126 [00:00<00:02, 44.59it/s]Loss = 1.7117e-01, PNorm = 40.8975, GNorm = 0.1612, lr_0 = 4.6959e-04
#
#  12% 15/126 [00:00<00:02, 48.35it/s]
#  17% 21/126 [00:00<00:02, 50.25it/s]Loss = 1.7039e-01, PNorm = 40.9349, GNorm = 0.5091, lr_0 = 4.6651e-04
#
#  21% 27/126 [00:00<00:01, 50.04it/s]Loss = 1.7897e-01, PNorm = 40.9690, GNorm = 0.2447, lr_0 = 4.6345e-04
#
#  26% 33/126 [00:00<00:01, 50.37it/s]
#  31% 39/126 [00:00<00:01, 50.04it/s]Loss = 1.7231e-01, PNorm = 41.0082, GNorm = 0.1821, lr_0 = 4.6041e-04
#
#  35% 44/126 [00:00<00:01, 49.13it/s]
#  40% 50/126 [00:01<00:01, 49.20it/s]Loss = 1.9551e-01, PNorm = 41.0382, GNorm = 0.4090, lr_0 = 4.5739e-04
#
#  44% 55/126 [00:01<00:01, 48.07it/s]
#  48% 60/126 [00:01<00:01, 48.44it/s]Loss = 1.7607e-01, PNorm = 41.0771, GNorm = 0.4583, lr_0 = 4.5439e-04
#
#  52% 66/126 [00:01<00:01, 49.26it/s]
#  56% 71/126 [00:01<00:01, 49.09it/s]Loss = 1.6671e-01, PNorm = 41.1148, GNorm = 0.2058, lr_0 = 4.5141e-04
#
#  60% 76/126 [00:01<00:01, 49.29it/s]
#  64% 81/126 [00:01<00:00, 49.11it/s]Loss = 1.8903e-01, PNorm = 41.1544, GNorm = 0.2136, lr_0 = 4.4845e-04
#
#  68% 86/126 [00:01<00:00, 48.60it/s]
#  72% 91/126 [00:02<00:01, 19.74it/s]Loss = 1.6236e-01, PNorm = 41.1972, GNorm = 0.3148, lr_0 = 4.4551e-04
#
#  76% 96/126 [00:02<00:01, 23.64it/s]
#  80% 101/126 [00:02<00:00, 27.98it/s]Loss = 1.6072e-01, PNorm = 41.2357, GNorm = 0.4316, lr_0 = 4.4259e-04
#
#  84% 106/126 [00:02<00:00, 31.96it/s]Loss = 1.7630e-01, PNorm = 41.2594, GNorm = 0.1831, lr_0 = 4.3969e-04
#
#  89% 112/126 [00:02<00:00, 36.52it/s]
#  94% 118/126 [00:02<00:00, 40.61it/s]Loss = 1.7207e-01, PNorm = 41.2854, GNorm = 0.1922, lr_0 = 4.3680e-04
#
#  98% 124/126 [00:03<00:00, 43.49it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  44% 7/16 [00:00<00:00, 69.82it/s]
#  94% 15/16 [00:00<00:00, 69.85it/s]
#                                    Validation auc = 0.847534
#  40% 12/30 [00:42<00:54,  3.02s/it]Epoch 12
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 49.14it/s]Loss = 1.4876e-01, PNorm = 41.3180, GNorm = 0.1937, lr_0 = 4.3365e-04
#
#   8% 10/126 [00:00<00:02, 49.16it/s]
#  13% 16/126 [00:00<00:02, 50.09it/s]Loss = 1.6824e-01, PNorm = 41.3472, GNorm = 0.2092, lr_0 = 4.3081e-04
#
#  17% 22/126 [00:00<00:02, 48.59it/s]Loss = 1.6097e-01, PNorm = 41.3772, GNorm = 0.4212, lr_0 = 4.2799e-04
#
#  21% 27/126 [00:00<00:02, 49.00it/s]
#  26% 33/126 [00:00<00:01, 50.59it/s]Loss = 1.6489e-01, PNorm = 41.4126, GNorm = 0.3189, lr_0 = 4.2518e-04
#
#  31% 39/126 [00:00<00:01, 50.24it/s]
#  36% 45/126 [00:00<00:01, 50.32it/s]Loss = 1.6392e-01, PNorm = 41.4439, GNorm = 0.2171, lr_0 = 4.2239e-04
#
#  40% 51/126 [00:01<00:01, 49.74it/s]
#  44% 56/126 [00:01<00:01, 49.63it/s]Loss = 1.7149e-01, PNorm = 41.4749, GNorm = 0.1861, lr_0 = 4.1962e-04
#
#  49% 62/126 [00:01<00:01, 50.04it/s]Loss = 1.7480e-01, PNorm = 41.5108, GNorm = 0.4545, lr_0 = 4.1687e-04
#
#  54% 68/126 [00:01<00:01, 49.84it/s]
#  58% 73/126 [00:01<00:01, 49.45it/s]Loss = 1.6791e-01, PNorm = 41.5441, GNorm = 0.1653, lr_0 = 4.1414e-04
#
#  62% 78/126 [00:01<00:00, 49.44it/s]
#  67% 84/126 [00:01<00:00, 50.08it/s]Loss = 1.7799e-01, PNorm = 41.5741, GNorm = 0.3859, lr_0 = 4.1142e-04
#
#  71% 90/126 [00:01<00:00, 48.56it/s]
#  75% 95/126 [00:01<00:00, 48.77it/s]Loss = 1.7442e-01, PNorm = 41.6138, GNorm = 0.5442, lr_0 = 4.0872e-04
#
#  80% 101/126 [00:02<00:00, 49.52it/s]Loss = 1.7300e-01, PNorm = 41.6418, GNorm = 0.3688, lr_0 = 4.0604e-04
#
#  85% 107/126 [00:02<00:00, 49.73it/s]
#  89% 112/126 [00:02<00:00, 49.68it/s]Loss = 1.9052e-01, PNorm = 41.6687, GNorm = 0.3999, lr_0 = 4.0338e-04
#
#  93% 117/126 [00:02<00:00, 49.56it/s]
#  97% 122/126 [00:02<00:00, 49.68it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 72.26it/s]
# 100% 16/16 [00:00<00:00, 72.65it/s]
#                                    Validation auc = 0.849114
#  43% 13/30 [00:44<00:50,  2.95s/it]Epoch 13
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.7209e-01, PNorm = 41.6965, GNorm = 0.1729, lr_0 = 4.0047e-04
#
#   4% 5/126 [00:00<00:02, 45.82it/s]
#   9% 11/126 [00:00<00:02, 48.68it/s]Loss = 1.7128e-01, PNorm = 41.7307, GNorm = 0.4518, lr_0 = 3.9785e-04
#
#  13% 16/126 [00:00<00:02, 49.12it/s]
#  17% 21/126 [00:00<00:02, 49.28it/s]Loss = 1.5903e-01, PNorm = 41.7649, GNorm = 0.2395, lr_0 = 3.9524e-04
#
#  21% 26/126 [00:00<00:02, 49.10it/s]
#  25% 31/126 [00:00<00:01, 49.35it/s]Loss = 1.6523e-01, PNorm = 41.7993, GNorm = 0.2616, lr_0 = 3.9264e-04
#
#  29% 36/126 [00:00<00:01, 48.52it/s]
#  33% 41/126 [00:00<00:01, 48.36it/s]Loss = 1.5673e-01, PNorm = 41.8323, GNorm = 0.1993, lr_0 = 3.9007e-04
#
#  37% 47/126 [00:00<00:01, 49.36it/s]Loss = 1.6929e-01, PNorm = 41.8604, GNorm = 0.2446, lr_0 = 3.8751e-04
#
#  41% 52/126 [00:01<00:01, 48.89it/s]
#  46% 58/126 [00:01<00:01, 49.89it/s]Loss = 1.6529e-01, PNorm = 41.8812, GNorm = 0.2054, lr_0 = 3.8497e-04
#
#  50% 63/126 [00:01<00:01, 49.81it/s]
#  55% 69/126 [00:01<00:01, 50.60it/s]Loss = 1.7158e-01, PNorm = 41.9128, GNorm = 0.2597, lr_0 = 3.8245e-04
#
#  60% 75/126 [00:01<00:01, 50.59it/s]
#  64% 81/126 [00:01<00:00, 51.52it/s]Loss = 1.5392e-01, PNorm = 41.9352, GNorm = 0.2355, lr_0 = 3.7994e-04
#
#  69% 87/126 [00:01<00:00, 51.25it/s]Loss = 1.7667e-01, PNorm = 41.9640, GNorm = 0.1933, lr_0 = 3.7745e-04
#
#  74% 93/126 [00:01<00:00, 50.37it/s]
#  79% 99/126 [00:01<00:00, 50.78it/s]Loss = 1.7448e-01, PNorm = 41.9913, GNorm = 0.3956, lr_0 = 3.7497e-04
#
#  83% 105/126 [00:02<00:00, 50.10it/s]
#  88% 111/126 [00:02<00:00, 50.39it/s]Loss = 1.6559e-01, PNorm = 42.0195, GNorm = 0.2069, lr_0 = 3.7251e-04
#
#  93% 117/126 [00:02<00:00, 49.05it/s]Loss = 1.8433e-01, PNorm = 42.0473, GNorm = 0.3503, lr_0 = 3.7007e-04
#
#  98% 123/126 [00:02<00:00, 49.58it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.45it/s]
# 100% 16/16 [00:00<00:00, 72.34it/s]
#                                    Validation auc = 0.851338
#  47% 14/30 [00:47<00:46,  2.90s/it]Epoch 14
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 48.15it/s]Loss = 1.5371e-01, PNorm = 42.0703, GNorm = 0.3193, lr_0 = 3.6740e-04
#
#   9% 11/126 [00:00<00:02, 49.54it/s]Loss = 1.7120e-01, PNorm = 42.0980, GNorm = 0.1693, lr_0 = 3.6499e-04
#
#  13% 17/126 [00:00<00:02, 49.40it/s]
#  18% 23/126 [00:00<00:02, 49.73it/s]Loss = 1.5574e-01, PNorm = 42.1262, GNorm = 0.2741, lr_0 = 3.6260e-04
#
#  22% 28/126 [00:00<00:01, 49.65it/s]
#  27% 34/126 [00:00<00:01, 50.81it/s]Loss = 1.5618e-01, PNorm = 42.1563, GNorm = 0.1889, lr_0 = 3.6022e-04
#
#  32% 40/126 [00:00<00:01, 50.15it/s]
#  37% 46/126 [00:00<00:01, 50.66it/s]Loss = 1.6584e-01, PNorm = 42.1863, GNorm = 0.2598, lr_0 = 3.5786e-04
#
#  41% 52/126 [00:01<00:01, 50.31it/s]Loss = 1.9203e-01, PNorm = 42.2123, GNorm = 0.2298, lr_0 = 3.5551e-04
#
#  46% 58/126 [00:01<00:01, 49.85it/s]
#  51% 64/126 [00:01<00:01, 49.78it/s]Loss = 1.6532e-01, PNorm = 42.2412, GNorm = 0.2820, lr_0 = 3.5318e-04
#
#  55% 69/126 [00:01<00:01, 49.53it/s]
#  60% 75/126 [00:01<00:01, 49.72it/s]Loss = 1.6840e-01, PNorm = 42.2726, GNorm = 0.2028, lr_0 = 3.5087e-04
#
#  63% 80/126 [00:01<00:00, 49.76it/s]
#  67% 85/126 [00:01<00:00, 49.39it/s]Loss = 1.8005e-01, PNorm = 42.2981, GNorm = 0.1816, lr_0 = 3.4857e-04
#
#  72% 91/126 [00:01<00:00, 49.84it/s]
#  76% 96/126 [00:01<00:00, 49.74it/s]Loss = 1.5858e-01, PNorm = 42.3241, GNorm = 0.2978, lr_0 = 3.4628e-04
#
#  81% 102/126 [00:02<00:00, 50.53it/s]Loss = 1.5393e-01, PNorm = 42.3493, GNorm = 0.2133, lr_0 = 3.4401e-04
#
#  86% 108/126 [00:02<00:00, 50.72it/s]
#  90% 114/126 [00:02<00:00, 50.48it/s]Loss = 1.5765e-01, PNorm = 42.3745, GNorm = 0.1715, lr_0 = 3.4175e-04
#
#  95% 120/126 [00:02<00:00, 50.22it/s]
# 100% 126/126 [00:02<00:00, 51.67it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.55it/s]
# 100% 16/16 [00:00<00:00, 71.93it/s]
#                                    Validation auc = 0.850158
#  50% 15/30 [00:50<00:42,  2.86s/it]Epoch 15
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.5754e-01, PNorm = 42.3962, GNorm = 0.2109, lr_0 = 3.3951e-04
#
#   4% 5/126 [00:00<00:02, 46.72it/s]Loss = 1.5328e-01, PNorm = 42.4247, GNorm = 0.3014, lr_0 = 3.3729e-04
#
#   9% 11/126 [00:00<00:02, 48.84it/s]
#  13% 16/126 [00:00<00:02, 48.38it/s]Loss = 1.5773e-01, PNorm = 42.4497, GNorm = 0.1700, lr_0 = 3.3508e-04
#
#  17% 22/126 [00:00<00:02, 49.80it/s]
#  22% 28/126 [00:00<00:01, 50.17it/s]Loss = 1.4298e-01, PNorm = 42.4741, GNorm = 0.2772, lr_0 = 3.3288e-04
#
#  27% 34/126 [00:00<00:01, 49.83it/s]
#  31% 39/126 [00:00<00:01, 49.27it/s]Loss = 1.6933e-01, PNorm = 42.5022, GNorm = 0.3254, lr_0 = 3.3070e-04
#
#  35% 44/126 [00:00<00:01, 49.47it/s]
#  39% 49/126 [00:00<00:01, 49.07it/s]Loss = 1.5499e-01, PNorm = 42.5237, GNorm = 0.2889, lr_0 = 3.2853e-04
#
#  43% 54/126 [00:01<00:01, 48.95it/s]
#  48% 60/126 [00:01<00:01, 49.60it/s]Loss = 1.8352e-01, PNorm = 42.5402, GNorm = 0.3129, lr_0 = 3.2637e-04
#
#  52% 65/126 [00:01<00:01, 49.65it/s]
#  56% 70/126 [00:01<00:01, 49.53it/s]Loss = 1.6071e-01, PNorm = 42.5611, GNorm = 0.4094, lr_0 = 3.2423e-04
#
#  60% 75/126 [00:01<00:01, 49.47it/s]
#  63% 80/126 [00:01<00:00, 49.62it/s]Loss = 1.7976e-01, PNorm = 42.5828, GNorm = 0.2355, lr_0 = 3.2211e-04
#
#  67% 85/126 [00:01<00:00, 49.72it/s]Loss = 1.6059e-01, PNorm = 42.6112, GNorm = 0.3108, lr_0 = 3.1999e-04
#
#  72% 91/126 [00:01<00:00, 50.19it/s]
#  77% 97/126 [00:01<00:00, 50.15it/s]Loss = 1.7671e-01, PNorm = 42.6302, GNorm = 0.3541, lr_0 = 3.1790e-04
#
#  82% 103/126 [00:02<00:00, 50.29it/s]
#  87% 109/126 [00:02<00:00, 50.05it/s]Loss = 1.6313e-01, PNorm = 42.6578, GNorm = 0.2221, lr_0 = 3.1581e-04
#
#  91% 115/126 [00:02<00:00, 49.71it/s]Loss = 1.5563e-01, PNorm = 42.6799, GNorm = 0.2335, lr_0 = 3.1374e-04
#
#  96% 121/126 [00:02<00:00, 49.82it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 72.44it/s]
# 100% 16/16 [00:00<00:00, 72.60it/s]
#                                    Validation auc = 0.852760
#  53% 16/30 [00:53<00:39,  2.84s/it]Epoch 16
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 49.94it/s]Loss = 1.5048e-01, PNorm = 42.7045, GNorm = 0.2247, lr_0 = 3.1148e-04
#
#   9% 11/126 [00:00<00:02, 50.61it/s]Loss = 1.6745e-01, PNorm = 42.7260, GNorm = 0.2150, lr_0 = 3.0944e-04
#
#  13% 17/126 [00:00<00:02, 49.34it/s]
#  17% 22/126 [00:00<00:02, 49.24it/s]Loss = 1.3959e-01, PNorm = 42.7485, GNorm = 0.1873, lr_0 = 3.0741e-04
#
#  22% 28/126 [00:00<00:01, 50.53it/s]
#  27% 34/126 [00:00<00:01, 50.52it/s]Loss = 1.6622e-01, PNorm = 42.7687, GNorm = 0.1960, lr_0 = 3.0539e-04
#
#  32% 40/126 [00:00<00:01, 50.11it/s]Loss = 1.5458e-01, PNorm = 42.7924, GNorm = 0.2747, lr_0 = 3.0339e-04
#
#  37% 46/126 [00:00<00:01, 49.55it/s]
#  40% 51/126 [00:01<00:01, 49.01it/s]Loss = 1.5017e-01, PNorm = 42.8187, GNorm = 0.2093, lr_0 = 3.0140e-04
#
#  45% 57/126 [00:01<00:01, 49.69it/s]
#  50% 63/126 [00:01<00:01, 50.06it/s]Loss = 1.6107e-01, PNorm = 42.8416, GNorm = 0.3334, lr_0 = 2.9942e-04
#
#  55% 69/126 [00:01<00:01, 49.52it/s]
#  60% 75/126 [00:01<00:01, 50.26it/s]Loss = 1.6117e-01, PNorm = 42.8602, GNorm = 0.2368, lr_0 = 2.9746e-04
#
#  64% 81/126 [00:01<00:00, 49.90it/s]Loss = 1.6971e-01, PNorm = 42.8816, GNorm = 0.2768, lr_0 = 2.9551e-04
#
#  68% 86/126 [00:01<00:00, 49.55it/s]
#  72% 91/126 [00:01<00:00, 49.54it/s]Loss = 1.5620e-01, PNorm = 42.8980, GNorm = 0.2973, lr_0 = 2.9357e-04
#
#  77% 97/126 [00:01<00:00, 49.75it/s]
#  81% 102/126 [00:02<00:00, 49.56it/s]Loss = 1.6620e-01, PNorm = 42.9188, GNorm = 0.2087, lr_0 = 2.9165e-04
#
#  85% 107/126 [00:02<00:00, 47.88it/s]
#  89% 112/126 [00:02<00:00, 48.46it/s]Loss = 1.6706e-01, PNorm = 42.9350, GNorm = 0.2784, lr_0 = 2.8973e-04
#
#  94% 118/126 [00:02<00:00, 49.18it/s]
#  98% 124/126 [00:02<00:00, 50.29it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 72.08it/s]
# 100% 16/16 [00:00<00:00, 72.80it/s]
#                                    Validation auc = 0.852102
#  57% 17/30 [00:56<00:36,  2.82s/it]Epoch 17
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.6863e-01, PNorm = 42.9609, GNorm = 0.2364, lr_0 = 2.8765e-04
#
#   4% 5/126 [00:00<00:02, 43.77it/s]Loss = 1.6261e-01, PNorm = 42.9831, GNorm = 0.2025, lr_0 = 2.8576e-04
#
#   9% 11/126 [00:00<00:02, 47.56it/s]
#  13% 17/126 [00:00<00:02, 48.89it/s]Loss = 1.5110e-01, PNorm = 43.0069, GNorm = 0.2649, lr_0 = 2.8389e-04
#
#  17% 22/126 [00:00<00:02, 48.63it/s]
#  21% 27/126 [00:00<00:02, 48.99it/s]Loss = 1.3715e-01, PNorm = 43.0283, GNorm = 0.2405, lr_0 = 2.8202e-04
#
#  26% 33/126 [00:00<00:01, 49.50it/s]
#  30% 38/126 [00:00<00:01, 49.52it/s]Loss = 1.6606e-01, PNorm = 43.0510, GNorm = 0.6559, lr_0 = 2.8017e-04
#
#  34% 43/126 [00:00<00:01, 49.48it/s]
#  38% 48/126 [00:00<00:01, 49.49it/s]Loss = 1.5766e-01, PNorm = 43.0758, GNorm = 0.3531, lr_0 = 2.7834e-04
#
#  42% 53/126 [00:01<00:01, 49.60it/s]
#  47% 59/126 [00:01<00:01, 50.69it/s]Loss = 1.6623e-01, PNorm = 43.0958, GNorm = 0.2989, lr_0 = 2.7651e-04
#
#  52% 65/126 [00:01<00:01, 50.48it/s]Loss = 1.6039e-01, PNorm = 43.1163, GNorm = 0.2784, lr_0 = 2.7470e-04
#
#  56% 71/126 [00:01<00:01, 50.83it/s]
#  61% 77/126 [00:01<00:00, 50.90it/s]Loss = 1.5841e-01, PNorm = 43.1407, GNorm = 0.3575, lr_0 = 2.7290e-04
#
#  66% 83/126 [00:01<00:00, 49.18it/s]
#  71% 89/126 [00:01<00:00, 49.59it/s]Loss = 1.6685e-01, PNorm = 43.1609, GNorm = 0.2252, lr_0 = 2.7111e-04
#
#  75% 94/126 [00:01<00:00, 49.30it/s]
#  79% 100/126 [00:02<00:00, 50.09it/s]Loss = 1.5850e-01, PNorm = 43.1790, GNorm = 0.2777, lr_0 = 2.6933e-04
#
#  84% 106/126 [00:02<00:00, 49.97it/s]Loss = 1.4862e-01, PNorm = 43.1992, GNorm = 0.3309, lr_0 = 2.6756e-04
#
#  89% 112/126 [00:02<00:00, 49.84it/s]
#  94% 118/126 [00:02<00:00, 50.51it/s]Loss = 1.6204e-01, PNorm = 43.2120, GNorm = 0.2546, lr_0 = 2.6581e-04
#
#  98% 124/126 [00:02<00:00, 49.97it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 71.41it/s]
# 100% 16/16 [00:00<00:00, 70.71it/s]
#                                    Validation auc = 0.849590
#  60% 18/30 [00:58<00:33,  2.80s/it]Epoch 18
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.4053e-01, PNorm = 43.2352, GNorm = 0.3118, lr_0 = 2.6407e-04
#
#   4% 5/126 [00:00<00:02, 47.54it/s]
#   9% 11/126 [00:00<00:02, 49.63it/s]Loss = 1.6973e-01, PNorm = 43.2509, GNorm = 0.2161, lr_0 = 2.6234e-04
#
#  13% 16/126 [00:00<00:02, 49.40it/s]
#  17% 22/126 [00:00<00:02, 50.51it/s]Loss = 1.6310e-01, PNorm = 43.2692, GNorm = 0.2382, lr_0 = 2.6062e-04
#
#  22% 28/126 [00:00<00:01, 50.73it/s]
#  27% 34/126 [00:00<00:01, 50.52it/s]Loss = 1.5733e-01, PNorm = 43.2927, GNorm = 0.2842, lr_0 = 2.5891e-04
#
#  32% 40/126 [00:00<00:01, 50.58it/s]Loss = 1.5028e-01, PNorm = 43.3095, GNorm = 0.4008, lr_0 = 2.5721e-04
#
#  37% 46/126 [00:01<00:03, 21.43it/s]
#  41% 52/126 [00:01<00:02, 26.17it/s]Loss = 1.6847e-01, PNorm = 43.3297, GNorm = 0.4567, lr_0 = 2.5552e-04
#
#  46% 58/126 [00:01<00:02, 30.79it/s]
#  51% 64/126 [00:01<00:01, 34.96it/s]Loss = 1.6080e-01, PNorm = 43.3423, GNorm = 0.2229, lr_0 = 2.5385e-04
#
#  56% 70/126 [00:01<00:01, 38.63it/s]Loss = 1.4007e-01, PNorm = 43.3621, GNorm = 0.2399, lr_0 = 2.5218e-04
#
#  60% 76/126 [00:02<00:01, 41.31it/s]
#  64% 81/126 [00:02<00:01, 43.03it/s]Loss = 1.6107e-01, PNorm = 43.3793, GNorm = 0.2877, lr_0 = 2.5053e-04
#
#  68% 86/126 [00:02<00:00, 44.28it/s]
#  72% 91/126 [00:02<00:00, 45.71it/s]Loss = 1.5579e-01, PNorm = 43.3954, GNorm = 0.1983, lr_0 = 2.4889e-04
#
#  76% 96/126 [00:02<00:00, 46.48it/s]
#  81% 102/126 [00:02<00:00, 48.08it/s]Loss = 1.4262e-01, PNorm = 43.4119, GNorm = 0.2408, lr_0 = 2.4725e-04
#
#  86% 108/126 [00:02<00:00, 48.52it/s]
#  90% 114/126 [00:02<00:00, 49.17it/s]Loss = 1.6205e-01, PNorm = 43.4271, GNorm = 0.2165, lr_0 = 2.4563e-04
#
#  94% 119/126 [00:02<00:00, 49.24it/s]
#  98% 124/126 [00:02<00:00, 49.10it/s]Loss = 1.4982e-01, PNorm = 43.4421, GNorm = 0.1920, lr_0 = 2.4402e-04
# Loss = 1.5452e-01, PNorm = 43.4436, GNorm = 0.3561, lr_0 = 2.4386e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.95it/s]
# 100% 16/16 [00:00<00:00, 72.50it/s]
#                                    Validation auc = 0.853316
#  63% 19/30 [01:02<00:32,  2.95s/it]Epoch 19
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 47.65it/s]Loss = 1.3563e-01, PNorm = 43.4627, GNorm = 0.2951, lr_0 = 2.4226e-04
#
#   9% 11/126 [00:00<00:02, 49.31it/s]
#  13% 16/126 [00:00<00:02, 49.23it/s]Loss = 1.6823e-01, PNorm = 43.4794, GNorm = 0.2501, lr_0 = 2.4067e-04
#
#  17% 21/126 [00:00<00:02, 48.84it/s]
#  21% 27/126 [00:00<00:02, 49.20it/s]Loss = 1.5897e-01, PNorm = 43.4987, GNorm = 0.2506, lr_0 = 2.3910e-04
#
#  25% 32/126 [00:00<00:01, 49.16it/s]
#  30% 38/126 [00:00<00:01, 49.93it/s]Loss = 1.4247e-01, PNorm = 43.5193, GNorm = 0.3013, lr_0 = 2.3753e-04
#
#  34% 43/126 [00:00<00:01, 49.66it/s]
#  38% 48/126 [00:00<00:01, 49.57it/s]Loss = 1.6290e-01, PNorm = 43.5330, GNorm = 0.2150, lr_0 = 2.3597e-04
#
#  42% 53/126 [00:01<00:01, 49.33it/s]
#  47% 59/126 [00:01<00:01, 50.84it/s]Loss = 1.4712e-01, PNorm = 43.5453, GNorm = 0.2788, lr_0 = 2.3442e-04
#
#  52% 65/126 [00:01<00:01, 50.73it/s]Loss = 1.6188e-01, PNorm = 43.5624, GNorm = 0.3223, lr_0 = 2.3289e-04
#
#  56% 71/126 [00:01<00:01, 49.79it/s]
#  61% 77/126 [00:01<00:00, 50.43it/s]Loss = 1.5022e-01, PNorm = 43.5802, GNorm = 0.1646, lr_0 = 2.3136e-04
#
#  66% 83/126 [00:01<00:00, 50.58it/s]
#  71% 89/126 [00:01<00:00, 50.30it/s]Loss = 1.5105e-01, PNorm = 43.5985, GNorm = 0.3928, lr_0 = 2.2984e-04
#
#  75% 95/126 [00:01<00:00, 50.08it/s]Loss = 1.5424e-01, PNorm = 43.6136, GNorm = 0.1843, lr_0 = 2.2833e-04
#
#  80% 101/126 [00:02<00:00, 49.80it/s]
#  85% 107/126 [00:02<00:00, 50.27it/s]Loss = 1.5264e-01, PNorm = 43.6275, GNorm = 0.3038, lr_0 = 2.2684e-04
#
#  90% 113/126 [00:02<00:00, 49.82it/s]
#  94% 118/126 [00:02<00:00, 48.91it/s]Loss = 1.5989e-01, PNorm = 43.6472, GNorm = 0.1969, lr_0 = 2.2535e-04
#
#  98% 124/126 [00:02<00:00, 49.47it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.85it/s]
# 100% 16/16 [00:00<00:00, 72.92it/s]
#                                    Validation auc = 0.853051
#  67% 20/30 [01:04<00:28,  2.90s/it]Epoch 20
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.4898e-01, PNorm = 43.6626, GNorm = 0.2513, lr_0 = 2.2372e-04
#
#   4% 5/126 [00:00<00:02, 47.29it/s]
#   9% 11/126 [00:00<00:02, 49.20it/s]Loss = 1.5819e-01, PNorm = 43.6801, GNorm = 0.2818, lr_0 = 2.2226e-04
#
#  13% 16/126 [00:00<00:02, 49.45it/s]
#  17% 22/126 [00:00<00:02, 50.37it/s]Loss = 1.3827e-01, PNorm = 43.6964, GNorm = 0.2504, lr_0 = 2.2080e-04
#
#  22% 28/126 [00:00<00:01, 50.14it/s]
#  27% 34/126 [00:00<00:01, 50.19it/s]Loss = 1.6929e-01, PNorm = 43.7069, GNorm = 0.1908, lr_0 = 2.1935e-04
#
#  32% 40/126 [00:00<00:01, 50.15it/s]Loss = 1.6287e-01, PNorm = 43.7197, GNorm = 0.2491, lr_0 = 2.1791e-04
#
#  37% 46/126 [00:00<00:01, 49.78it/s]
#  41% 52/126 [00:01<00:01, 49.92it/s]Loss = 1.4483e-01, PNorm = 43.7350, GNorm = 0.2444, lr_0 = 2.1649e-04
#
#  45% 57/126 [00:01<00:01, 49.16it/s]
#  50% 63/126 [00:01<00:01, 49.88it/s]Loss = 1.4347e-01, PNorm = 43.7534, GNorm = 0.1551, lr_0 = 2.1507e-04
#
#  55% 69/126 [00:01<00:01, 50.60it/s]Loss = 1.4909e-01, PNorm = 43.7663, GNorm = 0.2594, lr_0 = 2.1366e-04
#
#  60% 75/126 [00:01<00:01, 50.17it/s]
#  64% 81/126 [00:01<00:00, 50.55it/s]Loss = 1.5412e-01, PNorm = 43.7825, GNorm = 0.3076, lr_0 = 2.1225e-04
#
#  69% 87/126 [00:01<00:00, 50.41it/s]
#  74% 93/126 [00:01<00:00, 50.13it/s]Loss = 1.4313e-01, PNorm = 43.7997, GNorm = 0.2841, lr_0 = 2.1086e-04
#
#  79% 99/126 [00:01<00:00, 49.95it/s]
#  83% 104/126 [00:02<00:00, 49.94it/s]Loss = 1.5604e-01, PNorm = 43.8116, GNorm = 0.2370, lr_0 = 2.0948e-04
#
#  87% 109/126 [00:02<00:00, 49.73it/s]
#  90% 114/126 [00:02<00:00, 47.57it/s]Loss = 1.5241e-01, PNorm = 43.8254, GNorm = 0.2795, lr_0 = 2.0811e-04
#
#  94% 119/126 [00:02<00:00, 46.39it/s]
#  98% 124/126 [00:02<00:00, 46.02it/s]Loss = 1.5324e-01, PNorm = 43.8396, GNorm = 0.3054, lr_0 = 2.0674e-04
# Loss = 1.1358e-01, PNorm = 43.8419, GNorm = 0.6899, lr_0 = 2.0661e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  44% 7/16 [00:00<00:00, 68.05it/s]
#  88% 14/16 [00:00<00:00, 67.78it/s]
#                                    Validation auc = 0.856424
#  70% 21/30 [01:07<00:25,  2.88s/it]Epoch 21
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 45.64it/s]Loss = 1.4199e-01, PNorm = 43.8571, GNorm = 0.1749, lr_0 = 2.0525e-04
#
#   8% 10/126 [00:00<00:02, 47.13it/s]
# ...
#
#  37% 47/126 [00:00<00:01, 49.20it/s]
#  42% 53/126 [00:01<00:01, 49.74it/s]Loss = 1.5293e-01, PNorm = 44.0800, GNorm = 0.4084, lr_0 = 1.8353e-04
#
#  46% 58/126 [00:01<00:01, 49.09it/s]Loss = 1.5170e-01, PNorm = 44.0935, GNorm = 0.2697, lr_0 = 1.8233e-04
#
#  51% 64/126 [00:01<00:01, 49.70it/s]
#  55% 69/126 [00:01<00:01, 49.31it/s]Loss = 1.3894e-01, PNorm = 44.1040, GNorm = 0.3624, lr_0 = 1.8113e-04
#
#  59% 74/126 [00:01<00:01, 48.65it/s]
#  63% 80/126 [00:01<00:00, 48.88it/s]Loss = 1.5328e-01, PNorm = 44.1205, GNorm = 0.2638, lr_0 = 1.7995e-04
#
#  67% 85/126 [00:01<00:00, 48.93it/s]
#  72% 91/126 [00:01<00:00, 49.68it/s]Loss = 1.5592e-01, PNorm = 44.1306, GNorm = 0.1687, lr_0 = 1.7877e-04
#
#  76% 96/126 [00:01<00:00, 49.72it/s]
#  81% 102/126 [00:02<00:00, 50.55it/s]Loss = 1.4208e-01, PNorm = 44.1461, GNorm = 0.2561, lr_0 = 1.7759e-04
#
#  86% 108/126 [00:02<00:00, 50.90it/s]Loss = 1.4081e-01, PNorm = 44.1597, GNorm = 0.2118, lr_0 = 1.7643e-04
#
#  90% 114/126 [00:02<00:00, 49.94it/s]
#  95% 120/126 [00:02<00:00, 50.74it/s]Loss = 1.3716e-01, PNorm = 44.1741, GNorm = 0.3141, lr_0 = 1.7527e-04
#
# 100% 126/126 [00:02<00:00, 51.37it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.48it/s]
# 100% 16/16 [00:00<00:00, 72.51it/s]
#                                    Validation auc = 0.855133
#  77% 23/30 [01:13<00:19,  2.83s/it]Epoch 23
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 48.25it/s]Loss = 1.4252e-01, PNorm = 44.1873, GNorm = 0.1960, lr_0 = 1.7401e-04
#
#   8% 10/126 [00:00<00:02, 48.56it/s]
#  13% 16/126 [00:00<00:02, 49.46it/s]Loss = 1.4299e-01, PNorm = 44.2010, GNorm = 0.1881, lr_0 = 1.7287e-04
#
#  17% 21/126 [00:00<00:02, 49.57it/s]
#  21% 26/126 [00:00<00:02, 49.07it/s]Loss = 1.4956e-01, PNorm = 44.2135, GNorm = 0.2468, lr_0 = 1.7173e-04
#
#  25% 31/126 [00:00<00:01, 48.53it/s]
#  29% 37/126 [00:00<00:01, 49.43it/s]Loss = 1.5594e-01, PNorm = 44.2268, GNorm = 0.3258, lr_0 = 1.7061e-04
#
#  33% 42/126 [00:00<00:01, 48.88it/s]
#  38% 48/126 [00:00<00:01, 49.84it/s]Loss = 1.5955e-01, PNorm = 44.2358, GNorm = 0.2083, lr_0 = 1.6949e-04
#
#  42% 53/126 [00:01<00:01, 49.66it/s]Loss = 1.4567e-01, PNorm = 44.2441, GNorm = 0.2889, lr_0 = 1.6838e-04
#
#  47% 59/126 [00:01<00:01, 49.92it/s]
#  51% 64/126 [00:01<00:01, 49.59it/s]Loss = 1.3809e-01, PNorm = 44.2578, GNorm = 0.3327, lr_0 = 1.6727e-04
#
#  56% 70/126 [00:01<00:01, 50.10it/s]
#  60% 76/126 [00:01<00:00, 50.57it/s]Loss = 1.4854e-01, PNorm = 44.2679, GNorm = 0.2012, lr_0 = 1.6618e-04
#
#  65% 82/126 [00:01<00:00, 49.94it/s]
#  69% 87/126 [00:01<00:00, 49.48it/s]Loss = 1.5622e-01, PNorm = 44.2794, GNorm = 0.4640, lr_0 = 1.6509e-04
#
#  73% 92/126 [00:01<00:00, 49.50it/s]
#  78% 98/126 [00:01<00:00, 50.07it/s]Loss = 1.3371e-01, PNorm = 44.2894, GNorm = 0.2958, lr_0 = 1.6401e-04
#
#  83% 104/126 [00:02<00:00, 49.74it/s]Loss = 1.5010e-01, PNorm = 44.3021, GNorm = 0.2280, lr_0 = 1.6293e-04
#
#  87% 109/126 [00:02<00:00, 49.56it/s]
#  91% 115/126 [00:02<00:00, 49.81it/s]Loss = 1.4613e-01, PNorm = 44.3126, GNorm = 0.5821, lr_0 = 1.6186e-04
#
#  95% 120/126 [00:02<00:00, 49.30it/s]
# 100% 126/126 [00:02<00:00, 51.47it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  44% 7/16 [00:00<00:00, 68.46it/s]
#  88% 14/16 [00:00<00:00, 68.52it/s]
#                                    Validation auc = 0.855908
#  80% 24/30 [01:16<00:16,  2.81s/it]Epoch 24
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.3404e-01, PNorm = 44.3255, GNorm = 0.4096, lr_0 = 1.6069e-04
#
#   4% 5/126 [00:00<00:02, 49.16it/s]
#   8% 10/126 [00:00<00:02, 48.84it/s]Loss = 1.3932e-01, PNorm = 44.3368, GNorm = 0.5849, lr_0 = 1.5964e-04
#
#  12% 15/126 [00:00<00:02, 49.10it/s]
#  16% 20/126 [00:00<00:02, 48.29it/s]Loss = 1.3973e-01, PNorm = 44.3473, GNorm = 0.2217, lr_0 = 1.5859e-04
#
#  21% 26/126 [00:00<00:02, 49.38it/s]
#  25% 31/126 [00:00<00:01, 49.40it/s]Loss = 1.3866e-01, PNorm = 44.3581, GNorm = 0.2730, lr_0 = 1.5755e-04
#
#  29% 36/126 [00:00<00:01, 49.32it/s]
#  33% 41/126 [00:00<00:01, 49.10it/s]Loss = 1.6040e-01, PNorm = 44.3669, GNorm = 0.2975, lr_0 = 1.5652e-04
#
#  37% 46/126 [00:00<00:01, 48.29it/s]
#  40% 51/126 [00:01<00:01, 48.80it/s]Loss = 1.3987e-01, PNorm = 44.3818, GNorm = 0.3338, lr_0 = 1.5549e-04
#
#  44% 56/126 [00:01<00:01, 48.98it/s]
#  49% 62/126 [00:01<00:01, 50.17it/s]Loss = 1.5140e-01, PNorm = 44.3910, GNorm = 0.6891, lr_0 = 1.5447e-04
#
#  54% 68/126 [00:01<00:01, 50.16it/s]Loss = 1.3596e-01, PNorm = 44.4029, GNorm = 0.2700, lr_0 = 1.5346e-04
#
#  59% 74/126 [00:01<00:01, 50.63it/s]
#  63% 80/126 [00:01<00:00, 50.09it/s]Loss = 1.5231e-01, PNorm = 44.4089, GNorm = 0.4276, lr_0 = 1.5246e-04
#
#  68% 86/126 [00:01<00:00, 49.79it/s]
#  72% 91/126 [00:01<00:00, 49.54it/s]Loss = 1.5237e-01, PNorm = 44.4196, GNorm = 0.4690, lr_0 = 1.5146e-04
#
#  76% 96/126 [00:01<00:00, 48.50it/s]
#  80% 101/126 [00:02<00:01, 20.76it/s]Loss = 1.6400e-01, PNorm = 44.4276, GNorm = 0.3691, lr_0 = 1.5046e-04
#
#  85% 107/126 [00:02<00:00, 25.74it/s]
#  90% 113/126 [00:02<00:00, 30.70it/s]Loss = 1.5128e-01, PNorm = 44.4386, GNorm = 0.2604, lr_0 = 1.4948e-04
#
#  94% 118/126 [00:02<00:00, 34.04it/s]
#  98% 123/126 [00:02<00:00, 37.40it/s]Loss = 1.4195e-01, PNorm = 44.4478, GNorm = 0.2422, lr_0 = 1.4850e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.27it/s]
# 100% 16/16 [00:00<00:00, 72.04it/s]
#                                    Validation auc = 0.856324
#  83% 25/30 [01:19<00:14,  2.95s/it]Epoch 25
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 48.05it/s]Loss = 1.4233e-01, PNorm = 44.4590, GNorm = 0.2572, lr_0 = 1.4752e-04
#
#   8% 10/126 [00:00<00:02, 48.56it/s]
#  13% 16/126 [00:00<00:02, 49.70it/s]Loss = 1.3259e-01, PNorm = 44.4683, GNorm = 0.2420, lr_0 = 1.4655e-04
#
#  17% 22/126 [00:00<00:02, 50.29it/s]Loss = 1.6883e-01, PNorm = 44.4770, GNorm = 0.4156, lr_0 = 1.4559e-04
#
#  22% 28/126 [00:00<00:01, 50.04it/s]
#  27% 34/126 [00:00<00:01, 49.57it/s]Loss = 1.4813e-01, PNorm = 44.4874, GNorm = 0.2900, lr_0 = 1.4464e-04
#
#  32% 40/126 [00:00<00:01, 49.83it/s]
#  37% 46/126 [00:00<00:01, 50.51it/s]Loss = 1.4183e-01, PNorm = 44.4998, GNorm = 0.2222, lr_0 = 1.4369e-04
#
#  41% 52/126 [00:01<00:01, 49.99it/s]Loss = 1.4596e-01, PNorm = 44.5099, GNorm = 0.3969, lr_0 = 1.4275e-04
#
#  46% 58/126 [00:01<00:01, 50.08it/s]
#  51% 64/126 [00:01<00:01, 49.66it/s]Loss = 1.4252e-01, PNorm = 44.5209, GNorm = 0.2303, lr_0 = 1.4181e-04
#
#  55% 69/126 [00:01<00:01, 49.58it/s]
#  60% 75/126 [00:01<00:01, 49.94it/s]Loss = 1.4844e-01, PNorm = 44.5258, GNorm = 0.2842, lr_0 = 1.4088e-04
#
#  63% 80/126 [00:01<00:00, 49.74it/s]
#  68% 86/126 [00:01<00:00, 50.04it/s]Loss = 1.2874e-01, PNorm = 44.5350, GNorm = 0.3265, lr_0 = 1.3996e-04
#
#  73% 92/126 [00:01<00:00, 49.12it/s]
#  77% 97/126 [00:01<00:00, 49.22it/s]Loss = 1.3938e-01, PNorm = 44.5466, GNorm = 0.2458, lr_0 = 1.3904e-04
#
#  81% 102/126 [00:02<00:00, 48.95it/s]
#  85% 107/126 [00:02<00:00, 48.95it/s]Loss = 1.5127e-01, PNorm = 44.5556, GNorm = 0.2902, lr_0 = 1.3813e-04
#
#  90% 113/126 [00:02<00:00, 49.76it/s]Loss = 1.5226e-01, PNorm = 44.5678, GNorm = 0.2567, lr_0 = 1.3722e-04
#
#  94% 118/126 [00:02<00:00, 49.27it/s]
#  98% 124/126 [00:02<00:00, 50.09it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  44% 7/16 [00:00<00:00, 68.58it/s]
#  88% 14/16 [00:00<00:00, 69.19it/s]
#                                    Validation auc = 0.854319
#  87% 26/30 [01:22<00:11,  2.89s/it]Epoch 26
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.6727e-01, PNorm = 44.5772, GNorm = 0.3201, lr_0 = 1.3623e-04
#
#   4% 5/126 [00:00<00:02, 43.90it/s]
#   9% 11/126 [00:00<00:02, 48.48it/s]Loss = 1.3980e-01, PNorm = 44.5871, GNorm = 0.2493, lr_0 = 1.3534e-04
#
#  13% 16/126 [00:00<00:02, 48.71it/s]
#  17% 21/126 [00:00<00:02, 48.94it/s]Loss = 1.4776e-01, PNorm = 44.5959, GNorm = 0.2566, lr_0 = 1.3445e-04
#
#  21% 27/126 [00:00<00:01, 50.00it/s]
#  25% 32/126 [00:00<00:01, 49.95it/s]Loss = 1.4988e-01, PNorm = 44.6061, GNorm = 0.3136, lr_0 = 1.3357e-04
#
#  30% 38/126 [00:00<00:01, 50.37it/s]Loss = 1.5248e-01, PNorm = 44.6139, GNorm = 0.3028, lr_0 = 1.3270e-04
#
#  35% 44/126 [00:00<00:01, 50.46it/s]
#  40% 50/126 [00:01<00:01, 49.58it/s]Loss = 1.5579e-01, PNorm = 44.6239, GNorm = 0.1992, lr_0 = 1.3183e-04
#
#  44% 55/126 [00:01<00:01, 49.68it/s]
#  48% 61/126 [00:01<00:01, 49.94it/s]Loss = 1.3657e-01, PNorm = 44.6326, GNorm = 0.2089, lr_0 = 1.3096e-04
#
#  52% 66/126 [00:01<00:01, 49.43it/s]
#  56% 71/126 [00:01<00:01, 49.46it/s]Loss = 1.2101e-01, PNorm = 44.6444, GNorm = 0.2338, lr_0 = 1.3010e-04
#
#  61% 77/126 [00:01<00:00, 50.03it/s]
#  65% 82/126 [00:01<00:00, 49.86it/s]Loss = 1.4977e-01, PNorm = 44.6527, GNorm = 0.2601, lr_0 = 1.2925e-04
#
#  70% 88/126 [00:01<00:00, 50.36it/s]Loss = 1.2253e-01, PNorm = 44.6618, GNorm = 0.3199, lr_0 = 1.2840e-04
#
#  75% 94/126 [00:01<00:00, 50.23it/s]
#  79% 100/126 [00:02<00:00, 49.28it/s]Loss = 1.4584e-01, PNorm = 44.6699, GNorm = 0.2343, lr_0 = 1.2756e-04
#
#  83% 105/126 [00:02<00:00, 48.84it/s]
#  88% 111/126 [00:02<00:00, 49.49it/s]Loss = 1.4705e-01, PNorm = 44.6778, GNorm = 0.3691, lr_0 = 1.2672e-04
#
#  92% 116/126 [00:02<00:00, 49.31it/s]
#  97% 122/126 [00:02<00:00, 50.52it/s]Loss = 1.4111e-01, PNorm = 44.6852, GNorm = 0.3556, lr_0 = 1.2589e-04
#
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 72.63it/s]
# 100% 16/16 [00:00<00:00, 72.71it/s]
#                                    Validation auc = 0.854608
#  90% 27/30 [01:24<00:08,  2.85s/it]Epoch 27
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 48.38it/s]Loss = 1.2575e-01, PNorm = 44.6949, GNorm = 0.4073, lr_0 = 1.2498e-04
#
#   8% 10/126 [00:00<00:02, 47.63it/s]
#  12% 15/126 [00:00<00:02, 47.69it/s]Loss = 1.5213e-01, PNorm = 44.7039, GNorm = 0.4757, lr_0 = 1.2417e-04
#
#  17% 21/126 [00:00<00:02, 49.12it/s]
#  21% 27/126 [00:00<00:01, 49.94it/s]Loss = 1.3546e-01, PNorm = 44.7124, GNorm = 0.2469, lr_0 = 1.2335e-04
#
#  26% 33/126 [00:00<00:01, 50.64it/s]Loss = 1.4449e-01, PNorm = 44.7184, GNorm = 0.5621, lr_0 = 1.2254e-04
#
#  31% 39/126 [00:00<00:01, 50.91it/s]
#  36% 45/126 [00:00<00:01, 50.77it/s]Loss = 1.3837e-01, PNorm = 44.7260, GNorm = 0.2649, lr_0 = 1.2174e-04
#
#  40% 51/126 [00:01<00:01, 50.05it/s]
#  45% 57/126 [00:01<00:01, 49.41it/s]Loss = 1.4772e-01, PNorm = 44.7346, GNorm = 0.3389, lr_0 = 1.2094e-04
#
#  49% 62/126 [00:01<00:01, 48.83it/s]Loss = 1.3752e-01, PNorm = 44.7439, GNorm = 0.3378, lr_0 = 1.2015e-04
#
#  54% 68/126 [00:01<00:01, 49.44it/s]
#  58% 73/126 [00:01<00:01, 49.22it/s]Loss = 1.4729e-01, PNorm = 44.7529, GNorm = 0.2322, lr_0 = 1.1936e-04
#
#  63% 79/126 [00:01<00:00, 49.71it/s]
#  67% 85/126 [00:01<00:00, 50.19it/s]Loss = 1.3993e-01, PNorm = 44.7604, GNorm = 0.3763, lr_0 = 1.1858e-04
#
#  72% 91/126 [00:01<00:00, 50.40it/s]
#  77% 97/126 [00:01<00:00, 50.16it/s]Loss = 1.5011e-01, PNorm = 44.7669, GNorm = 0.2727, lr_0 = 1.1780e-04
#
#  82% 103/126 [00:02<00:00, 49.24it/s]Loss = 1.3461e-01, PNorm = 44.7748, GNorm = 0.4637, lr_0 = 1.1703e-04
#
#  86% 108/126 [00:02<00:00, 49.20it/s]
#  90% 113/126 [00:02<00:00, 48.20it/s]Loss = 1.4355e-01, PNorm = 44.7831, GNorm = 0.2505, lr_0 = 1.1626e-04
#
#  94% 119/126 [00:02<00:00, 48.85it/s]
#  99% 125/126 [00:02<00:00, 49.50it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.06it/s]
# 100% 16/16 [00:00<00:00, 71.92it/s]
#                                    Validation auc = 0.856762
#  93% 28/30 [01:27<00:05,  2.84s/it]Epoch 28
#
#   0% 0/126 [00:00<?, ?it/s]Loss = 1.5532e-01, PNorm = 44.7934, GNorm = 0.5033, lr_0 = 1.1542e-04
#
#   4% 5/126 [00:00<00:02, 46.89it/s]
#   8% 10/126 [00:00<00:02, 48.16it/s]Loss = 1.2751e-01, PNorm = 44.8037, GNorm = 0.2861, lr_0 = 1.1466e-04
#
#  13% 16/126 [00:00<00:02, 49.66it/s]
#  17% 21/126 [00:00<00:02, 49.04it/s]Loss = 1.4666e-01, PNorm = 44.8112, GNorm = 0.3588, lr_0 = 1.1391e-04
#
#  21% 26/126 [00:00<00:02, 49.36it/s]
#  25% 32/126 [00:00<00:01, 50.51it/s]Loss = 1.5388e-01, PNorm = 44.8191, GNorm = 0.2877, lr_0 = 1.1317e-04
#
#  30% 38/126 [00:00<00:01, 50.40it/s]Loss = 1.3382e-01, PNorm = 44.8275, GNorm = 0.2195, lr_0 = 1.1242e-04
#
#  35% 44/126 [00:00<00:01, 50.50it/s]
#  40% 50/126 [00:01<00:01, 50.16it/s]Loss = 1.4047e-01, PNorm = 44.8347, GNorm = 0.2194, lr_0 = 1.1169e-04
#
#  44% 56/126 [00:01<00:01, 50.62it/s]
#  49% 62/126 [00:01<00:01, 50.06it/s]Loss = 1.5052e-01, PNorm = 44.8413, GNorm = 0.2419, lr_0 = 1.1095e-04
#
#  54% 68/126 [00:01<00:01, 49.09it/s]Loss = 1.4553e-01, PNorm = 44.8502, GNorm = 0.3039, lr_0 = 1.1023e-04
#
#  58% 73/126 [00:01<00:01, 49.19it/s]
#  62% 78/126 [00:01<00:00, 48.56it/s]Loss = 1.3660e-01, PNorm = 44.8584, GNorm = 0.2747, lr_0 = 1.0950e-04
#
#  66% 83/126 [00:01<00:00, 48.75it/s]
#  71% 89/126 [00:01<00:00, 49.46it/s]Loss = 1.5013e-01, PNorm = 44.8651, GNorm = 0.2745, lr_0 = 1.0879e-04
#
#  75% 94/126 [00:01<00:00, 48.95it/s]
#  79% 100/126 [00:02<00:00, 49.86it/s]Loss = 1.2850e-01, PNorm = 44.8732, GNorm = 0.3259, lr_0 = 1.0807e-04
#
#  83% 105/126 [00:02<00:00, 49.85it/s]
#  88% 111/126 [00:02<00:00, 50.24it/s]Loss = 1.5022e-01, PNorm = 44.8797, GNorm = 0.3074, lr_0 = 1.0736e-04
#
#  93% 117/126 [00:02<00:00, 48.74it/s]Loss = 1.2428e-01, PNorm = 44.8879, GNorm = 0.2188, lr_0 = 1.0666e-04
#
#  98% 123/126 [00:02<00:00, 49.76it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  44% 7/16 [00:00<00:00, 68.40it/s]
#  94% 15/16 [00:00<00:00, 69.69it/s]
#                                    Validation auc = 0.854857
#  97% 29/30 [01:30<00:02,  2.82s/it]Epoch 29
#
#   0% 0/126 [00:00<?, ?it/s]
#   4% 5/126 [00:00<00:02, 46.71it/s]Loss = 1.5359e-01, PNorm = 44.8920, GNorm = 0.3410, lr_0 = 1.0596e-04
#
#   9% 11/126 [00:00<00:02, 49.80it/s]Loss = 1.3903e-01, PNorm = 44.8992, GNorm = 0.2959, lr_0 = 1.0527e-04
#
#  13% 17/126 [00:00<00:02, 49.84it/s]
#  18% 23/126 [00:00<00:02, 50.37it/s]Loss = 1.2750e-01, PNorm = 44.9054, GNorm = 0.3579, lr_0 = 1.0458e-04
#
#  23% 29/126 [00:00<00:01, 49.49it/s]
#  27% 34/126 [00:00<00:01, 49.30it/s]Loss = 1.2568e-01, PNorm = 44.9124, GNorm = 0.2856, lr_0 = 1.0389e-04
#
#  31% 39/126 [00:00<00:01, 49.20it/s]
#  36% 45/126 [00:00<00:01, 49.89it/s]Loss = 1.4946e-01, PNorm = 44.9195, GNorm = 0.2647, lr_0 = 1.0321e-04
#
#  40% 50/126 [00:01<00:01, 49.61it/s]
#  44% 55/126 [00:01<00:01, 49.39it/s]Loss = 1.3337e-01, PNorm = 44.9276, GNorm = 0.2810, lr_0 = 1.0253e-04
#
#  48% 60/126 [00:01<00:01, 49.17it/s]
#  52% 65/126 [00:01<00:01, 48.60it/s]Loss = 1.4230e-01, PNorm = 44.9332, GNorm = 0.2388, lr_0 = 1.0186e-04
#
#  56% 71/126 [00:01<00:01, 49.29it/s]
#  60% 76/126 [00:01<00:01, 49.47it/s]Loss = 1.3332e-01, PNorm = 44.9414, GNorm = 0.3703, lr_0 = 1.0119e-04
#
#  64% 81/126 [00:01<00:00, 48.99it/s]
#  68% 86/126 [00:01<00:00, 47.79it/s]Loss = 1.5035e-01, PNorm = 44.9456, GNorm = 0.3726, lr_0 = 1.0053e-04
#
#  72% 91/126 [00:01<00:00, 47.37it/s]
#  76% 96/126 [00:01<00:00, 47.59it/s]Loss = 1.3990e-01, PNorm = 44.9541, GNorm = 0.3265, lr_0 = 1.0000e-04
#
#  80% 101/126 [00:02<00:00, 47.34it/s]Loss = 1.5294e-01, PNorm = 44.9617, GNorm = 0.3643, lr_0 = 1.0000e-04
#
#  85% 107/126 [00:02<00:00, 48.69it/s]
#  90% 113/126 [00:02<00:00, 49.60it/s]Loss = 1.2777e-01, PNorm = 44.9688, GNorm = 0.2674, lr_0 = 1.0000e-04
#
#  94% 118/126 [00:02<00:00, 49.54it/s]
#  98% 124/126 [00:02<00:00, 49.97it/s]
#
#   0% 0/16 [00:00<?, ?it/s]
#  50% 8/16 [00:00<00:00, 70.33it/s]
# 100% 16/16 [00:00<00:00, 71.45it/s]
#                                    Validation auc = 0.856668
# 100% 30/30 [01:33<00:00,  3.11s/it]
# Model 0 best validation auc = 0.856762 on epoch 27
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Moving model to cuda
# Model 0 test auc = 0.840654
# Ensemble test auc = 0.840654
# 1-fold cross validation
# 	Seed 0 ==> test auc = 0.840654
# Overall test auc = 0.840654 +/- 0.000000
# Elapsed time = 0:01:42

# %% [markdown]
# ### Usage: Chemprop Predict

# %%
from typing import List

import torch
from tqdm import tqdm

from chemprop.data import MoleculeDataLoader, MoleculeDataset, StandardScaler
from chemprop.models import MoleculeModel

# %%
def predict(model: MoleculeModel,
            data_loader: MoleculeDataLoader,
            disable_progress_bar: bool = False,
            scaler: StandardScaler = None) -> List[List[float]]:
    """
    Makes predictions on a dataset using an ensemble of models.

    :param model: A :class:`~chemprop.models.model.MoleculeModel`.
    :param data_loader: A :class:`~chemprop.data.data.MoleculeDataLoader`.
    :param disable_progress_bar: Whether to disable the progress bar.
    :param scaler: A :class:`~chemprop.features.scaler.StandardScaler` object fit on the training targets.
    :return: A list of lists of predictions. The outer list is molecules while the inner list is tasks.
    """
    model.eval()

    preds = []

    for batch in tqdm(data_loader, disable=disable_progress_bar, leave=False):
        # Prepare batch
        batch: MoleculeDataset
        mol_batch, features_batch, atom_descriptors_batch, atom_features_batch, bond_features_batch = \
            batch.batch_graph(), batch.features(), batch.atom_descriptors(), batch.atom_features(), batch.bond_features()

        # Make predictions
        with torch.no_grad():
            batch_preds = model(mol_batch, features_batch, atom_descriptors_batch,
                                atom_features_batch, bond_features_batch)

        batch_preds = batch_preds.data.cpu().numpy()

        # Inverse scale if regression
        if scaler is not None:
            batch_preds = scaler.inverse_transform(batch_preds)

        # Collect vectors
        batch_preds = batch_preds.tolist()
        preds.extend(batch_preds)

    return preds

# %%
# !python predict.py --test_path data/tox21.csv --checkpoint_dir tox21_checkpoints --preds_path tox21_preds.csv
# Out:
# Loading training args
# Loading data
# 7831it [00:00, 159388.15it/s]
# 100% 7831/7831 [00:00<00:00, 348246.81it/s]
# Validating SMILES
# [17:22:11] WARNING: not removing hydrogen atom without neighbors
# Test size = 7,831
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Predicting with an ensemble of 1 models
#   0% 0/1 [00:00<?, ?it/s]Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Moving model to cuda
#
#   0% 0/157 [00:00<?, ?it/s]
#   1% 1/157 [00:00<00:46,  3.37it/s]
#   2% 3/157 [00:00<00:21,  7.18it/s]
#   4% 7/157 [00:00<00:12, 11.87it/s]
#  10% 15/157 [00:00<00:05, 24.53it/s]
#  12% 19/157 [00:00<00:05, 27.23it/s]
#  15% 24/157 [00:01<00:04, 32.62it/s]
#  18% 29/157 [00:01<00:03, 36.22it/s]
#  22% 34/157 [00:01<00:03, 37.12it/s]
#  24% 38/157 [00:01<00:03, 34.64it/s]
#  27% 42/157 [00:01<00:03, 32.89it/s]
#  32% 50/157 [00:01<00:03, 34.74it/s]
#  34% 54/157 [00:02<00:03, 28.16it/s]
#  38% 59/157 [00:02<00:04, 21.32it/s]
#  43% 67/157 [00:02<00:03, 29.91it/s]
#  45% 71/157 [00:02<00:02, 28.70it/s]
#  50% 78/157 [00:02<00:02, 31.12it/s]
#  55% 86/157 [00:03<00:02, 33.31it/s]
#  59% 92/157 [00:03<00:01, 37.86it/s]
#  62% 97/157 [00:03<00:01, 37.10it/s]
#  66% 103/157 [00:03<00:01, 40.72it/s]
#  69% 108/157 [00:03<00:01, 36.98it/s]
#  72% 113/157 [00:03<00:01, 39.30it/s]
#  75% 118/157 [00:03<00:01, 37.19it/s]
#  78% 122/157 [00:04<00:01, 32.35it/s]
#  83% 130/157 [00:04<00:00, 36.00it/s]
#  85% 134/157 [00:04<00:00, 34.49it/s]
#  90% 141/157 [00:04<00:00, 41.53it/s]
#  95% 149/157 [00:04<00:00, 48.96it/s]
# 100% 1/1 [00:07<00:00,  7.18s/it]
# Saving predictions to tox21_preds.csv
# Elapsed time = 0:00:08

# %% [markdown]
# ### Usage: Chemprop Fingerprint

# %%
import csv
from typing import List, Optional, Union

import torch
from tqdm import tqdm

from chemprop.args import PredictArgs, TrainArgs
from chemprop.data import get_data, get_data_from_smiles, MoleculeDataLoader, MoleculeDataset
from chemprop.utils import load_args, load_checkpoint, makedirs, timeit, load_scalers, update_prediction_args
from chemprop.data import MoleculeDataLoader, MoleculeDataset
from chemprop.features import set_reaction, set_explicit_h
from chemprop.models import MoleculeModel

# %%
@timeit()
def molecule_fingerprint(args: PredictArgs, smiles: List[List[str]] = None) -> List[List[Optional[float]]]:
    """
    Loads data and a trained model and uses the model to encode fingerprint vectors for the data.

    :param args: A :class:`~chemprop.args.PredictArgs` object containing arguments for
                 loading data and a model and making predictions.
    :param smiles: List of list of SMILES to make predictions on.
    :return: A list of fingerprint vectors (list of floats)
    """

    print('Loading training args')
    train_args = load_args(args.checkpoint_paths[0])

    # Update args with training arguments
    update_prediction_args(predict_args=args, train_args=train_args, validate_feature_sources=False)
    args: Union[PredictArgs, TrainArgs]

    #set explicit H option and reaction option
    set_explicit_h(train_args.explicit_h)
    set_reaction(train_args.reaction, train_args.reaction_mode)

    print('Loading data')
    if smiles is not None:
        full_data = get_data_from_smiles(
            smiles=smiles,
            skip_invalid_smiles=False,
            features_generator=args.features_generator
        )
    else:
        full_data = get_data(path=args.test_path, smiles_columns=args.smiles_columns, target_columns=[], ignore_columns=[], skip_invalid_smiles=False,
                             args=args, store_row=True)

    print('Validating SMILES')
    full_to_valid_indices = {}
    valid_index = 0
    for full_index in range(len(full_data)):
        if all(mol is not None for mol in full_data[full_index].mol):
            full_to_valid_indices[full_index] = valid_index
            valid_index += 1

    test_data = MoleculeDataset([full_data[i] for i in sorted(full_to_valid_indices.keys())])

    # Edge case if empty list of smiles is provided
    if len(test_data) == 0:
        return [None] * len(full_data)

    print(f'Test size = {len(test_data):,}')

    # Create data loader
    test_data_loader = MoleculeDataLoader(
        dataset=test_data,
        batch_size=args.batch_size,
        num_workers=args.num_workers
    )

    # Load model
    print(f'Encoding smiles into a fingerprint vector from a single model')
    if len(args.checkpoint_paths) != 1:
        raise ValueError("Fingerprint generation only supports one model, cannot use an ensemble")

    model = load_checkpoint(args.checkpoint_paths[0], device=args.device)
    scaler, features_scaler, atom_descriptor_scaler, bond_feature_scaler = load_scalers(args.checkpoint_paths[0])

    # Normalize features
    if args.features_scaling or train_args.atom_descriptor_scaling or train_args.bond_feature_scaling:
        test_data.reset_features_and_targets()
        if args.features_scaling:
            test_data.normalize_features(features_scaler)
        if train_args.atom_descriptor_scaling and args.atom_descriptors is not None:
            test_data.normalize_features(atom_descriptor_scaler, scale_atom_descriptors=True)
        if train_args.bond_feature_scaling and args.bond_features_size > 0:
            test_data.normalize_features(bond_feature_scaler, scale_bond_features=True)

    # Make fingerprints
    model_preds = model_fingerprint(
        model=model,
        data_loader=test_data_loader
    )

    # Save predictions
    print(f'Saving predictions to {args.preds_path}')
    assert len(test_data) == len(model_preds)
    makedirs(args.preds_path, isfile=True)

    # Copy predictions over to full_data
    total_hidden_size = args.hidden_size * args.number_of_molecules
    for full_index, datapoint in enumerate(full_data):
        valid_index = full_to_valid_indices.get(full_index, None)
        preds = model_preds[valid_index] if valid_index is not None else ['Invalid SMILES'] * total_hidden_size

        fingerprint_columns=[f'fp_{i}' for i in range(total_hidden_size)]
        for i in range(len(fingerprint_columns)):
            datapoint.row[fingerprint_columns[i]] = preds[i]

    # Write predictions
    with open(args.preds_path, 'w') as f:
        writer = csv.DictWriter(f, fieldnames=args.smiles_columns+fingerprint_columns,extrasaction='ignore')
        writer.writeheader()
        for datapoint in full_data:
            writer.writerow(datapoint.row)

    return model_preds

def model_fingerprint(model: MoleculeModel,
            data_loader: MoleculeDataLoader,
            disable_progress_bar: bool = False) -> List[List[float]]:
    """
    Encodes the provided molecules into the latent fingerprint vectors, according to the provided model.

    :param model: A :class:`~chemprop.models.model.MoleculeModel`.
    :param data_loader: A :class:`~chemprop.data.data.MoleculeDataLoader`.
    :param disable_progress_bar: Whether to disable the progress bar.
    :return: A list of fingerprint vector lists.
    """
    model.eval()

    fingerprints = []

    for batch in tqdm(data_loader, disable=disable_progress_bar, leave=False):
        # Prepare batch
        batch: MoleculeDataset
        mol_batch, features_batch, atom_descriptors_batch = batch.batch_graph(), batch.features(), batch.atom_descriptors()

        # Make predictions
        with torch.no_grad():
            batch_fp = model.fingerprint(mol_batch, features_batch, atom_descriptors_batch)

        # Collect vectors
        batch_fp = batch_fp.data.cpu().tolist()

        fingerprints.extend(batch_fp)

    return fingerprints

def chemprop_fingerprint() -> None:
    """
    Parses Chemprop predicting arguments and returns the latent representation vectors for
    provided molecules, according to a previously trained model.
    """
    molecule_fingerprint(args=PredictArgs().parse_args())

# %%
# !python fingerprint.py --test_path data/tox21.csv --checkpoint_dir tox21_checkpoints --preds_path tox21_fingerprint.csv
# Out:
# Loading training args
# Loading data
# 7831it [00:00, 157366.03it/s]
# 100% 7831/7831 [00:00<00:00, 343997.77it/s]
# Validating SMILES
# [17:27:27] WARNING: not removing hydrogen atom without neighbors
# Test size = 7,831
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Encoding smiles into a fingerprint vector from a single model
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "ffn.1.weight".
# Loading pretrained parameter "ffn.1.bias".
# Loading pretrained parameter "ffn.4.weight".
# Loading pretrained parameter "ffn.4.bias".
# Moving model to cuda
# Saving predictions to tox21_fingerprint.csv
# Elapsed time = 0:00:12

# %% [markdown]
# ### Usage: Chemprop Interpret

# %%
import math
from typing import Callable, Dict, List, Set, Tuple

import numpy as np
from rdkit import Chem

from chemprop.args import InterpretArgs
from chemprop.data import get_data_from_smiles, get_header, get_smiles, MoleculeDataLoader, MoleculeDataset
from chemprop.train import predict
from chemprop.utils import load_args, load_checkpoint, load_scalers, timeit

MIN_ATOMS = 15
C_PUCT = 10

# %%
class ChempropModel:
    """A :class:`ChempropModel` is a wrapper around a :class:`~chemprop.models.model.MoleculeModel` for interpretation."""

    def __init__(self, args: InterpretArgs) -> None:
        """
        :param args: A :class:`~chemprop.args.InterpretArgs` object containing arguments for interpretation.
        """
        self.args = args
        self.train_args = load_args(args.checkpoint_paths[0])

        # If features were used during training, they must be used when predicting
        if ((self.train_args.features_path is not None or self.train_args.features_generator is not None)
                and args.features_generator is None):
            raise ValueError('Features were used during training so they must be specified again during prediction '
                             'using the same type of features as before (with --features_generator <generator> '
                             'and using --no_features_scaling if applicable).')

        if self.train_args.atom_descriptors_size > 0 or self.train_args.atom_features_size > 0 or self.train_args.bond_features_size > 0:
            raise NotImplementedError('The interpret function does not yet work with additional atom or bond features')

        self.scaler, self.features_scaler, self.atom_descriptor_scaler, self.bond_feature_scaler = load_scalers(args.checkpoint_paths[0])
        self.checkpoints = [load_checkpoint(checkpoint_path, device=args.device) for checkpoint_path in args.checkpoint_paths]

    def __call__(self, smiles: List[str], batch_size: int = 500) -> List[List[float]]:
        """
        Makes predictions on a list of SMILES.

        :param smiles: A list of SMILES to make predictions on.
        :param batch_size: The batch size.
        :return: A list of lists of floats containing the predicted values.
        """
        test_data = get_data_from_smiles(smiles=smiles, skip_invalid_smiles=False, features_generator=self.args.features_generator)
        valid_indices = [i for i in range(len(test_data)) if test_data[i].mol is not None]
        test_data = MoleculeDataset([test_data[i] for i in valid_indices])

        if self.train_args.features_scaling:
            test_data.normalize_features(self.features_scaler)
        if self.train_args.atom_descriptor_scaling and self.args.atom_descriptors is not None:
            test_data.normalize_features(self.atom_descriptor_scaler, scale_atom_descriptors=True)
        if self.train_args.bond_feature_scaling and self.args.bond_features_size > 0:
            test_data.normalize_features(self.bond_feature_scaler, scale_bond_features=True)

        test_data_loader = MoleculeDataLoader(dataset=test_data, batch_size=batch_size)

        sum_preds = []
        for model in self.checkpoints:
            model_preds = predict(
                model=model,
                data_loader=test_data_loader,
                scaler=self.scaler,
                disable_progress_bar=True
            )
            sum_preds.append(np.array(model_preds))

        # Ensemble predictions
        sum_preds = sum(sum_preds)
        avg_preds = sum_preds / len(self.checkpoints)

        return avg_preds

class MCTSNode:
    """A :class:`MCTSNode` represents a node in a Monte Carlo Tree Search."""

    def __init__(self, smiles: str, atoms: List[int], W: float = 0, N: int = 0, P: float = 0) -> None:
        """
        :param smiles: The SMILES for the substructure at this node.
        :param atoms: A list of atom indices represented by this node.
        :param W: The W value of this node.
        :param N: The N value of this node.
        :param P: The P value of this node.
        """
        self.smiles = smiles
        self.atoms = set(atoms)
        self.children = []
        self.W = W
        self.N = N
        self.P = P

    def Q(self) -> float:
        return self.W / self.N if self.N > 0 else 0

    def U(self, n: int) -> float:
        return C_PUCT * self.P * math.sqrt(n) / (1 + self.N)

def find_clusters(mol: Chem.Mol) -> Tuple[List[Tuple[int, ...]], List[List[int]]]:
    """
    Finds clusters within the molecule.

    :param mol: An RDKit molecule.
    :return: A tuple containing a list of atom tuples representing the clusters
             and a list of lists of atoms in each cluster.
    """
    n_atoms = mol.GetNumAtoms()
    if n_atoms == 1:  # special case
        return [(0,)], [[0]]

    clusters = []
    for bond in mol.GetBonds():
        a1 = bond.GetBeginAtom().GetIdx()
        a2 = bond.GetEndAtom().GetIdx()
        if not bond.IsInRing():
            clusters.append((a1, a2))

    ssr = [tuple(x) for x in Chem.GetSymmSSSR(mol)]
    clusters.extend(ssr)

    atom_cls = [[] for _ in range(n_atoms)]
    for i in range(len(clusters)):
        for atom in clusters[i]:
            atom_cls[atom].append(i)

    return clusters, atom_cls

def __extract_subgraph(mol: Chem.Mol, selected_atoms: Set[int]) -> Tuple[Chem.Mol, List[int]]:
    """
    Extracts a subgraph from an RDKit molecule given a set of atom indices.

    :param mol: An RDKit molecule from which to extract a subgraph.
    :param selected_atoms: The atoms which form the subgraph to be extracted.
    :return: A tuple containing an RDKit molecule representing the subgraph
             and a list of root atom indices from the selected indices.
    """
    selected_atoms = set(selected_atoms)
    roots = []
    for idx in selected_atoms:
        atom = mol.GetAtomWithIdx(idx)
        bad_neis = [y for y in atom.GetNeighbors() if y.GetIdx() not in selected_atoms]
        if len(bad_neis) > 0:
            roots.append(idx)

    new_mol = Chem.RWMol(mol)

    for atom_idx in roots:
        atom = new_mol.GetAtomWithIdx(atom_idx)
        atom.SetAtomMapNum(1)
        aroma_bonds = [bond for bond in atom.GetBonds() if bond.GetBondType() == Chem.rdchem.BondType.AROMATIC]
        aroma_bonds = [bond for bond in aroma_bonds if
                       bond.GetBeginAtom().GetIdx() in selected_atoms and bond.GetEndAtom().GetIdx() in selected_atoms]
        if len(aroma_bonds) == 0:
            atom.SetIsAromatic(False)

    remove_atoms = [atom.GetIdx() for atom in new_mol.GetAtoms() if atom.GetIdx() not in selected_atoms]
    remove_atoms = sorted(remove_atoms, reverse=True)
    for atom in remove_atoms:
        new_mol.RemoveAtom(atom)

    return new_mol.GetMol(), roots

def extract_subgraph(smiles: str, selected_atoms: Set[int]) -> Tuple[str, List[int]]:
    """
    Extracts a subgraph from a SMILES given a set of atom indices.

    :param smiles: A SMILES from which to extract a subgraph.
    :param selected_atoms: The atoms which form the subgraph to be extracted.
    :return: A tuple containing a SMILES representing the subgraph
             and a list of root atom indices from the selected indices.
    """
    # try with kekulization
    mol = Chem.MolFromSmiles(smiles)
    Chem.Kekulize(mol)
    subgraph, roots = __extract_subgraph(mol, selected_atoms)
    try:
        subgraph = Chem.MolToSmiles(subgraph, kekuleSmiles=True)
        subgraph = Chem.MolFromSmiles(subgraph)
    except Exception:
        subgraph = None

    mol = Chem.MolFromSmiles(smiles)  # de-kekulize
    if subgraph is not None and mol.HasSubstructMatch(subgraph):
        return Chem.MolToSmiles(subgraph), roots

    # If fails, try without kekulization
    subgraph, roots = __extract_subgraph(mol, selected_atoms)
    subgraph = Chem.MolToSmiles(subgraph)
    subgraph = Chem.MolFromSmiles(subgraph)

    if subgraph is not None:
        return Chem.MolToSmiles(subgraph), roots
    else:
        return None, None

def mcts_rollout(node: MCTSNode,
                 state_map: Dict[str, MCTSNode],
                 orig_smiles: str,
                 clusters: List[Set[int]],
                 atom_cls: List[Set[int]],
                 nei_cls: List[Set[int]],
                 scoring_function: Callable[[List[str]], List[float]]) -> float:
    """
    A Monte Carlo Tree Search rollout from a given :class:`MCTSNode`.

    :param node: The :class:`MCTSNode` from which to begin the rollout.
    :param state_map: A mapping from SMILES to :class:`MCTSNode`.
    :param orig_smiles: The original SMILES of the molecule.
    :param clusters: Clusters of atoms.
    :param atom_cls: Atom indices in the clusters.
    :param nei_cls: Neighboring clusters.
    :param scoring_function: A function for scoring subgraph SMILES using a Chemprop model.
    :return: The score of this MCTS rollout.
    """
    cur_atoms = node.atoms
    if len(cur_atoms) <= MIN_ATOMS:
        return node.P

    # Expand if this node has never been visited
    if len(node.children) == 0:
        cur_cls = set([i for i, x in enumerate(clusters) if x <= cur_atoms])
        for i in cur_cls:
            leaf_atoms = [a for a in clusters[i] if len(atom_cls[a] & cur_cls) == 1]
            if len(nei_cls[i] & cur_cls) == 1 or len(clusters[i]) == 2 and len(leaf_atoms) == 1:
                new_atoms = cur_atoms - set(leaf_atoms)
                new_smiles, _ = extract_subgraph(orig_smiles, new_atoms)
                if new_smiles in state_map:
                    new_node = state_map[new_smiles]  # merge identical states
                else:
                    new_node = MCTSNode(new_smiles, new_atoms)
                if new_smiles:
                    node.children.append(new_node)

        state_map[node.smiles] = node
        if len(node.children) == 0:
            return node.P  # cannot find leaves

        scores = scoring_function([[x.smiles] for x in node.children])
        for child, score in zip(node.children, scores):
            child.P = score

    sum_count = sum(c.N for c in node.children)
    selected_node = max(node.children, key=lambda x: x.Q() + x.U(sum_count))
    v = mcts_rollout(selected_node, state_map, orig_smiles, clusters, atom_cls, nei_cls, scoring_function)
    selected_node.W += v
    selected_node.N += 1

    return v

def mcts(smiles: str,
         scoring_function: Callable[[List[str]], List[float]],
         n_rollout: int,
         max_atoms: int,
         prop_delta: float) -> List[MCTSNode]:
    """
    Runs the Monte Carlo Tree Search algorithm.

    :param smiles: The SMILES of the molecule to perform the search on.
    :param scoring_function: A function for scoring subgraph SMILES using a Chemprop model.
    :param n_rollout: THe number of MCTS rollouts to perform.
    :param max_atoms: The maximum number of atoms allowed in an extracted rationale.
    :param prop_delta: The minimum required property value for a satisfactory rationale.
    :return: A list of rationales each represented by a :class:`MCTSNode`.
    """
            
    mol = Chem.MolFromSmiles(smiles)
    if mol.GetNumAtoms() > 50:
        n_rollout = 1

    clusters, atom_cls = find_clusters(mol)
    nei_cls = [0] * len(clusters)
    for i, cls in enumerate(clusters):
        nei_cls[i] = [nei for atom in cls for nei in atom_cls[atom]]
        nei_cls[i] = set(nei_cls[i]) - {i}
        clusters[i] = set(list(cls))
    for a in range(len(atom_cls)):
        atom_cls[a] = set(atom_cls[a])

    root = MCTSNode(smiles, set(range(mol.GetNumAtoms())))
    state_map = {smiles: root}
    for _ in range(n_rollout):
        mcts_rollout(root, state_map, smiles, clusters, atom_cls, nei_cls, scoring_function)

    rationales = [node for _, node in state_map.items() if len(node.atoms) <= max_atoms and node.P >= prop_delta]

    return rationales

@timeit()
def interpret(args: InterpretArgs) -> None:
    """
    Runs interpretation of a Chemprop model using the Monte Carlo Tree Search algorithm.

    :param args: A :class:`~chemprop.args.InterpretArgs` object containing arguments for interpretation.
    """

    if args.number_of_molecules != 1:
        raise ValueError("Interpreting is currently only available for single-molecule models.")
    
    global C_PUCT, MIN_ATOMS

    chemprop_model = ChempropModel(args)

    def scoring_function(smiles: List[str]) -> List[float]:
        return chemprop_model(smiles)[:, args.property_id - 1]

    C_PUCT = args.c_puct
    MIN_ATOMS = args.min_atoms

    all_smiles = get_smiles(path=args.data_path, smiles_columns=args.smiles_columns)
    header = get_header(path=args.data_path)

    property_name = header[args.property_id] if len(header) > args.property_id else 'score'
    print(f'smiles,{property_name},rationale,rationale_score')

    for smiles in all_smiles:
        score = scoring_function([smiles])[0]
        if score > args.prop_delta:
            rationales = mcts(
                smiles=smiles[0],
                scoring_function=scoring_function,
                n_rollout=args.rollout,
                max_atoms=args.max_atoms,
                prop_delta=args.prop_delta
            )
        else:
            rationales = []

        if len(rationales) == 0:
            print(f'{smiles},{score:.3f},,')
        else:
            min_size = min(len(x.atoms) for x in rationales)
            min_rationales = [x for x in rationales if len(x.atoms) == min_size]
            rats = sorted(min_rationales, key=lambda x: x.P, reverse=True)
            print(f'{smiles},{score:.3f},{rats[0].smiles},{rats[0].P:.3f}')

def chemprop_interpret() -> None:
    """Runs interpretation of a Chemprop model.

    This is the entry point for the command line command :code:`chemprop_interpret`.
    """
    interpret(args=InterpretArgs().parse_args())

# %%
# !python interpret.py --data_path data/tox21.csv --checkpoint_dir tox21_checkpoints/fold_0/ --property_id 1
# Out:
# Streaming output truncated to the last 5000 lines.
# [18:37:15] Aromatic bonds on non aromatic atom 8
# [18:37:16] Aromatic bonds on non aromatic atom 7
# [18:37:16] Aromatic bonds on non aromatic atom 7
# [18:37:16] Aromatic bonds on non aromatic atom 7
# [18:37:17] Aromatic bonds on non aromatic atom 4
# [18:37:17] Aromatic bonds on non aromatic atom 5
# [18:37:17] Aromatic bonds on non aromatic atom 7
# [18:37:17] Aromatic bonds on non aromatic atom 8
# [18:37:17] Aromatic bonds on non aromatic atom 8
# [18:37:17] Aromatic bonds on non aromatic atom 7
# [18:37:17] Aromatic bonds on non aromatic atom 8
# [18:37:19] Aromatic bonds on non aromatic atom 7
# [18:37:19] Aromatic bonds on non aromatic atom 8
# [18:37:19] Aromatic bonds on non aromatic atom 8
# [18:37:19] Aromatic bonds on non aromatic atom 7
# [18:37:20] Aromatic bonds on non aromatic atom 4
# [18:37:20] Aromatic bonds on non aromatic atom 6
# [18:37:20] Aromatic bonds on non aromatic atom 8
# [18:37:20] Aromatic bonds on non aromatic atom 7
# [18:37:21] Aromatic bonds on non aromatic atom 7
# [18:37:21] Aromatic bonds on non aromatic atom 7
# [18:37:22] Aromatic bonds on non aromatic atom 7
# [18:37:22] Aromatic bonds on non aromatic atom 4
# [18:37:23] Aromatic bonds on non aromatic atom 8
# [18:37:24] Aromatic bonds on non aromatic atom 7
# ['C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1C[C@@H](O)[C@@H]2O'],0.609,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1C[CH2:1][C@@H]2O,0.683
# ['C=CC1(C)OC(=O)N(c2cc(Cl)cc(Cl)c2)C1=O'],0.009,,
# ['CC(C)(C)CC(C)(C)c1ccc(O)cc1'],0.001,,
# ['C[C@]12CC[C@@H]3c4ccc(O)cc4C[C@@H](CCCCCCCCCS(=O)CCCC(F)(F)C(F)(F)F)[C@H]3[C@@H]1CC[C@@H]2O'],0.141,,
# ['CC(=O)NC(Cc1ccccc1)C(=O)O'],0.026,,
# ['C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@@]21C'],0.959,C#C[C@]1(O)CC[C@@H]2[C@]1(C)CC[CH2:1][CH2:1]2,0.682
# ['C#CC(O)(/C=C\\Cl)CC'],0.009,,
# ['CCN(CC)S(=O)(=O)c1ccc(C(=O)O)cc1'],0.013,,
# ['CCC1(C)CC(=O)NC1=O'],0.015,,
# ['BrCCCCCCBr'],0.009,,
# ['O=c1[nH]c(=O)c2[nH]c(=O)[nH]c2[nH]1'],0.018,,
# ['CC(C)CC(=O)C1C(=O)c2ccccc2C1=O'],0.009,,
# ['O=C([O-])c1cc2cc(Cc3cccnc3)ccc2o1'],0.021,,
# ['NC(=O)Nc1ccccc1'],0.029,,
# ['CCCOc1ccccc1-c1nc2[nH]nnc2c(=O)[nH]1'],0.008,,
# ['O=P([O-])(O)C(Cl)(Cl)P(=O)([O-])O'],0.000,,
# ['O=C(NCCNCC(O)COc1ccc(O)cc1)N1CCOCC1'],0.035,,
# ['CCCCOC(CC)OC(C)COC(O)CC'],0.010,,
# ['CCN(Cc1ccncc1)C(=O)C(CO)c1ccccc1'],0.011,,
# ['CC(C)(C)C1CCC(O)CC1'],0.002,,
# ['O=c1[nH]cnc2c1ncn2[C@H]1CC[C@@H](CO)O1'],0.008,,
# ['CCc1nc(C)c[nH]1'],0.004,,
# ['Cc1ccc(Cl)c(O)c1'],0.010,,
# ['CC1(C)C(=O)C(C)(C)C1=O'],0.008,,
# ['NC(=O)C1c2ccccc2CCc2ccccc21'],0.016,,
# ['NCCOCCOCCN'],0.029,,
# [18:37:57] Aromatic bonds on non aromatic atom 6
# [18:37:57] Aromatic bonds on non aromatic atom 5
# [18:37:57] Aromatic bonds on non aromatic atom 6
# [18:37:57] Aromatic bonds on non aromatic atom 5
# [18:37:59] Aromatic bonds on non aromatic atom 9
# [18:37:59] Aromatic bonds on non aromatic atom 9
# [18:37:59] Aromatic bonds on non aromatic atom 6
# [18:38:01] Aromatic bonds on non aromatic atom 9
# [18:38:02] Aromatic bonds on non aromatic atom 5
# [18:38:02] Aromatic bonds on non aromatic atom 12
# [18:38:02] Aromatic bonds on non aromatic atom 11
# [18:38:02] Aromatic bonds on non aromatic atom 10
# [18:38:03] Aromatic bonds on non aromatic atom 9
# [18:38:03] Aromatic bonds on non aromatic atom 10
# [18:38:04] Aromatic bonds on non aromatic atom 10
# [18:38:04] Aromatic bonds on non aromatic atom 10
# [18:38:04] Aromatic bonds on non aromatic atom 11
# [18:38:06] Aromatic bonds on non aromatic atom 11
# [18:38:06] Aromatic bonds on non aromatic atom 10
# [18:38:06] Aromatic bonds on non aromatic atom 9
# [18:38:07] Aromatic bonds on non aromatic atom 12
# [18:38:07] Aromatic bonds on non aromatic atom 11
# [18:38:07] Aromatic bonds on non aromatic atom 11
# [18:38:07] Aromatic bonds on non aromatic atom 10
# [18:38:07] Aromatic bonds on non aromatic atom 10
# [18:38:08] Aromatic bonds on non aromatic atom 11
# [18:38:08] Aromatic bonds on non aromatic atom 11
# [18:38:08] Aromatic bonds on non aromatic atom 12
# [18:38:10] Aromatic bonds on non aromatic atom 10
# [18:38:11] Aromatic bonds on non aromatic atom 10
# [18:38:11] Aromatic bonds on non aromatic atom 5
# [18:38:11] Aromatic bonds on non aromatic atom 10
# [18:38:11] Aromatic bonds on non aromatic atom 9
# [18:38:12] Aromatic bonds on non aromatic atom 11
# [18:38:12] Aromatic bonds on non aromatic atom 9
# [18:38:14] Aromatic bonds on non aromatic atom 12
# [18:38:14] Aromatic bonds on non aromatic atom 11
# [18:38:14] Aromatic bonds on non aromatic atom 12
# [18:38:15] Aromatic bonds on non aromatic atom 10
# [18:38:15] Aromatic bonds on non aromatic atom 10
# [18:38:15] Aromatic bonds on non aromatic atom 11
# [18:38:16] Aromatic bonds on non aromatic atom 11
# [18:38:17] Aromatic bonds on non aromatic atom 10
# [18:38:17] Aromatic bonds on non aromatic atom 11
# [18:38:17] Aromatic bonds on non aromatic atom 9
# [18:38:17] Aromatic bonds on non aromatic atom 10
# [18:38:18] Aromatic bonds on non aromatic atom 9
# ['C#C[C@]1(O)CC[C@H]2[C@@H]3CCc4cc(OC5CCCC5)ccc4[C@H]3CC[C@@]21C'],0.554,C#C[C@]1(O)CC[C@@H]2[C@]1(C)CC[CH2:1][CH2:1]2,0.682
# ['CC[C@H](C)[C@@H]1NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C@@H](N)CSSC[C@@H](C(=O)N2CCC[C@H]2C(=O)N[C@@H](CC(C)C)C(=O)NCC(N)=O)NC(=O)[C@H](CC(N)=O)NC(=O)[C@H](CCC(N)=O)NC1=O'],0.043,,
# ['CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1'],0.004,,
# ['O=C(O)Cn1c2ccccc2c(=O)c2ccccc21'],0.054,,
# ['O=C(NC(=O)c1c(F)cccc1F)Nc1ccc(Cl)c(Oc2ncc(C(F)(F)F)cc2Cl)c1'],0.034,,
# ['CN1CCN(C(=O)O[C@H]2c3nccnc3C(=O)N2c2ccc(Cl)cn2)CC1'],0.006,,
# ['CCCCCCCCCCCCc1ccccc1'],0.011,,
# ['C=CC1=C(C(=O)O)N2C(=O)[C@@H](NC(=O)/C(=N/O)c3csc(N)n3)[C@H]2SC1'],0.011,,
# ['O=C1CCc2ccc(OCCCCN3CCN(c4cccc(Cl)c4Cl)CC3)cc2N1'],0.060,,
# ['CCOC(=O)C1=C(C)NC(C)=C(C(=O)OC)C1c1cccc([N+](=O)[O-])c1'],0.009,,
# ['Cc1cc(OI)c(C(C)C)cc1-c1cc(C(C)C)c(OI)cc1C'],0.006,,
# ['CCOP(OCC)OCC'],0.004,,
# ['CC(C)CC(=O)CC(C)CC(C)C'],0.003,,
# ['CCc1nn(CCCN2CCN(c3cccc(Cl)c3)CC2)c(=O)n1CCOc1ccccc1'],0.028,,
# ['O=[N+]([O-])c1ccc2ncccc2c1'],0.012,,
# ['O=[N+]([O-])c1cccc2cccnc12'],0.010,,
# ['CC(C)n1c(/C=C/[C@@H](O)C[C@@H](O)CC(=O)O)c(-c2ccc(F)cc2)c2ccccc21'],0.017,,
# ['C=O'],0.006,,
# ['O=c1[nH]cc(F)c(=O)[nH]1'],0.012,,
# ['C[C@]12Cc3nonc3C[C@@H]1CC[C@@H]1[C@@H]2CC[C@@]2(C)[C@H]1CC[C@]2(C)O'],0.539,C[C@]1(O)CC[C@H]2[C@@H]3CC[CH2:1][C:1][C@H]3CC[C@@]21C,0.612
# ['Cn1c(CCCC(=O)O)nc2cc(N(CCCl)CCCl)ccc21'],0.050,,
# ['CN[C@@H]1[C@@H](O)[C@@H](O[C@H]2[C@H](N)C[C@H](N)[C@@H](O[C@H]3OC(CN)=CC[C@H]3N)[C@H]2O)OC[C@@]1(C)O'],0.094,,
# ['O=C(NNCS(=O)(=O)[O-])c1ccncc1'],0.013,,
# ['CCCCCCCCCC(=O)NO'],0.017,,
# ['CCC(C)C(N)C(=O)O'],0.013,,
# ['CC(C)c1cc2c(cc1S(=O)(=O)O)[C@@]1(C)CCC[C@@](C)(C(=O)O)[C@@H]1CC2'],0.027,,
# ['C[N+](C)(C)CC[N+]1(C)Cc2c(Cl)c(Cl)c(Cl)c(Cl)c2C1'],0.007,,
# ['CCCCCCC(C)(C)S'],0.003,,
# ['Cc1nnc2n1-c1ccc(Cl)cc1C(c1ccccc1)=NC2'],0.013,,
# ['CCc1ccccc1CC'],0.005,,
# ['CCOP(=O)(NC(C)C)Oc1ccc(SC)c(C)c1'],0.013,,
# ['COC(=O)c1ccccc1S(=O)(=O)NC(=O)N(C)c1nc(C)nc(OC)n1'],0.006,,
# ['CCOC(=O)COC(=O)c1ccccc1C(=O)OCC'],0.011,,
# ['Cn1cc(-c2ccccc2)c(=O)c(-c2cccc(C(F)(F)F)c2)c1'],0.020,,
# ['c1ccc2c(c1)Cc1ccccc1-2'],0.032,,
# ['c1ccc2c(c1)-c1cccc3cccc-2c13'],0.053,,
# ['CC(=O)CC(C)(C)C1CCCCC1'],0.001,,
# ['CC1(O)CSC(C)(O)CS1'],0.003,,
# ['CC(C)Oc1cccc(NC(=O)c2ccccc2C(F)(F)F)c1'],0.018,,
# ['CC(C)C(O)(c1ccc(OC(F)(F)F)cc1)c1cncnc1'],0.007,,
# ['CC1(C)CCC[C@@]2(C)[C@H]1CC[C@@]1(C)OC(=O)C[C@H]21'],0.005,,
# ['O=C1O[C@H]([C@@H](O)CO)C([O-])=C1O.O=C1O[C@H]([C@@H](O)CO)C([O-])=C1O'],0.019,,
# ['C/C=C(\\C)C(=O)OCCc1ccccc1'],0.013,,
# ['CN1[C@H]2CC[C@@H]1C[C@H](OC(=O)C(O)c1ccccc1)C2'],0.026,,
# ['CCNc1nc(NC(C)CC)nc(OC)n1'],0.006,,
# ['CCNc1nc(NCC)nc(SC)n1'],0.009,,
# ['C#CC(C)N(C)C(=O)Nc1ccc(Cl)cc1'],0.021,,
# ['CC(=O)OC/C=C(/C)CCC=C(C)C'],0.007,,
# ['CCCC(=O)C(C)=O'],0.008,,
# ['Cc1ccnc2ccccc12'],0.006,,
# ['O=C(O)CCc1ccccc1'],0.011,,
# ['COc1ccccc1OC'],0.002,,
# ['CCC/C=C/CO'],0.003,,
# ['COc1cccc(OC)c1'],0.005,,
# ['CCCCCCCCCCCCCCCCC'],0.009,,
# ['C=C[C@@]1(C)CC(=O)[C@@]2(O)[C@](C)(O1)[C@@H](OC(C)=O)[C@@H](O)[C@H]1C(C)(C)CC[C@H](O)[C@@]12C'],0.207,,
# ['O=S(=O)(O)c1ccc2[nH]c(-c3ccccc3)nc2c1'],0.024,,
# ['CCC(C)c1nccnc1OC'],0.001,,
# ['Cc1cc(C(=C2C=CC(=Nc3ccc(S(=O)(=O)[O-])cc3S(=O)(=O)O)C=C2)c2ccc(Nc3ccc(S(=O)(=O)[O-])cc3)cc2)ccc1N'],0.025,,
# ['CC1(C)CC(=O)CC(C)(C)N1[O]'],0.004,,
# ['OCC1CC2CC1C1CCC(CO)C21'],0.011,,
# ['C=CCOC(=O)c1ccc(C(=O)OCC=C)c(C(=O)OCC=C)c1'],0.024,,
# ['CCC(C)(CCC(C)C)C(=O)[O-].CCC(C)(CCC(C)C)C(=O)[O-]'],0.003,,
# ['CCOC(=O)/C=C(\\C)O[Ti](O/C(C)=C/C(=O)OCC)(OC(C)C)OC(C)C'],0.002,,
# ['CC1(C)C(O)C(C)(C)C1O'],0.006,,
# ['CCC1(c2ccccc2)C(=O)N(COC)C(=O)N(COC)C1=O'],0.004,,
# ['O=C1OC(=O)c2cccc3cccc1c23'],0.017,,
# ['CN1CCC(=C2c3ccccc3Sc3ccccc32)CC1'],0.018,,
# ['CN(C)[C@@H]1C(O)=C(C(=O)NCN[C@@H](CCCCN)C(=O)O)C(=O)[C@@]2(O)C(O)=C3C(=O)c4c(O)cccc4[C@@](C)(O)C3C[C@@H]12'],0.059,,
# ['CCOC(=O)CCC(=O)O[C@H]1[C@H](O[C@@H]2[C@@H](C)[C@H](O[C@H]3C[C@@](C)(OC)[C@@H](O)[C@H](C)O3)[C@@H](C)C(=O)O[C@H](CC)[C@@](C)(O)[C@H](O)[C@@H](C)C(=O)[C@H](C)C[C@@]2(C)O)O[C@H](C)C[C@@H]1N(C)C'],0.051,,
# ['O=C(O)CC(C(=O)O)S(=O)(=O)O'],0.031,,
# ['CO[C@H]1[C@@H](O)[C@H](N)[C@@H](O[C@H]2O[C@H]([C@H](C)N)CC[C@H]2N)[C@H](O)[C@@H]1N(C)C(=O)CN'],0.113,,
# ['CCC(=O)O[C@H]1[C@H](O[C@@H]2[C@@H](C)[C@H](O[C@H]3C[C@@](C)(OC)[C@@H](O)[C@H](C)O3)[C@@H](C)C(=O)O[C@H](CC)[C@@](C)(O)[C@H](O)[C@@H](C)C(=O)[C@H](C)C[C@@]2(C)O)O[C@H](C)C[C@@H]1N(C)C'],0.050,,
# ['CC(C)NCC(O)COc1ccc(CC(N)=O)cc1'],0.035,,
# ['CCCNC(C)(C)COC(=O)c1ccccc1'],0.013,,
# [18:38:56] Aromatic bonds on non aromatic atom 7
# [18:38:56] Aromatic bonds on non aromatic atom 7
# [18:38:56] Aromatic bonds on non aromatic atom 4
# [18:38:56] Aromatic bonds on non aromatic atom 5
# [18:38:58] Aromatic bonds on non aromatic atom 7
# [18:38:58] Aromatic bonds on non aromatic atom 7
# [18:39:00] Aromatic bonds on non aromatic atom 8
# [18:39:00] Aromatic bonds on non aromatic atom 7
# [18:39:00] Aromatic bonds on non aromatic atom 8
# [18:39:02] Aromatic bonds on non aromatic atom 7
# [18:39:02] Aromatic bonds on non aromatic atom 4
# [18:39:02] Aromatic bonds on non aromatic atom 6
# [18:39:02] Aromatic bonds on non aromatic atom 8
# [18:39:03] Aromatic bonds on non aromatic atom 7
# [18:39:09] Aromatic bonds on non aromatic atom 7
# ['C[C@]12CC[C@@H]3c4ccc(OC(=O)c5ccccc5)cc4CC[C@H]3[C@@H]1CC[C@@H]2O'],0.574,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1CC[C@@H]2O,0.683
# [18:39:10] Aromatic bonds on non aromatic atom 8
# [18:39:11] Aromatic bonds on non aromatic atom 7
# [18:39:11] Aromatic bonds on non aromatic atom 7
# [18:39:11] Aromatic bonds on non aromatic atom 7
# [18:39:11] Aromatic bonds on non aromatic atom 7
# [18:39:13] Aromatic bonds on non aromatic atom 8
# [18:39:13] Aromatic bonds on non aromatic atom 7
# [18:39:13] Aromatic bonds on non aromatic atom 7
# [18:39:13] Aromatic bonds on non aromatic atom 7
# [18:39:14] Aromatic bonds on non aromatic atom 7
# [18:39:14] Aromatic bonds on non aromatic atom 7
# [18:39:14] Aromatic bonds on non aromatic atom 7
# [18:39:14] Aromatic bonds on non aromatic atom 7
# [18:39:15] Aromatic bonds on non aromatic atom 7
# [18:39:15] Aromatic bonds on non aromatic atom 7
# [18:39:16] Aromatic bonds on non aromatic atom 8
# [18:39:16] Aromatic bonds on non aromatic atom 7
# [18:39:16] Aromatic bonds on non aromatic atom 7
# [18:39:17] Aromatic bonds on non aromatic atom 7
# [18:39:17] Aromatic bonds on non aromatic atom 7
# [18:39:17] Aromatic bonds on non aromatic atom 7
# [18:39:17] Aromatic bonds on non aromatic atom 7
# [18:39:18] Aromatic bonds on non aromatic atom 7
# [18:39:18] Aromatic bonds on non aromatic atom 7
# [18:39:18] Aromatic bonds on non aromatic atom 4
# [18:39:18] Aromatic bonds on non aromatic atom 6
# [18:39:19] Aromatic bonds on non aromatic atom 5
# [18:39:19] Aromatic bonds on non aromatic atom 7
# [18:39:19] Aromatic bonds on non aromatic atom 8
# [18:39:19] Aromatic bonds on non aromatic atom 8
# [18:39:19] Aromatic bonds on non aromatic atom 7
# [18:39:19] Aromatic bonds on non aromatic atom 8
# [18:39:19] Aromatic bonds on non aromatic atom 8
# [18:39:19] Aromatic bonds on non aromatic atom 7
# [18:39:19] Aromatic bonds on non aromatic atom 8
# [18:39:19] Aromatic bonds on non aromatic atom 8
# [18:39:20] Aromatic bonds on non aromatic atom 7
# [18:39:20] Aromatic bonds on non aromatic atom 7
# [18:39:22] Aromatic bonds on non aromatic atom 8
# [18:39:22] Aromatic bonds on non aromatic atom 8
# [18:39:22] Aromatic bonds on non aromatic atom 7
# [18:39:22] Aromatic bonds on non aromatic atom 7
# [18:39:23] Aromatic bonds on non aromatic atom 7
# [18:39:23] Aromatic bonds on non aromatic atom 8
# [18:39:24] Aromatic bonds on non aromatic atom 8
# [18:39:24] Aromatic bonds on non aromatic atom 8
# [18:39:24] Aromatic bonds on non aromatic atom 8
# [18:39:24] Aromatic bonds on non aromatic atom 8
# [18:39:25] Aromatic bonds on non aromatic atom 7
# [18:39:25] Aromatic bonds on non aromatic atom 8
# [18:39:26] Aromatic bonds on non aromatic atom 8
# [18:39:26] Aromatic bonds on non aromatic atom 7
# [18:39:26] Aromatic bonds on non aromatic atom 8
# [18:39:26] Aromatic bonds on non aromatic atom 7
# [18:39:26] Aromatic bonds on non aromatic atom 8
# [18:39:26] Aromatic bonds on non aromatic atom 7
# [18:39:26] Aromatic bonds on non aromatic atom 8
# [18:39:27] Aromatic bonds on non aromatic atom 7
# [18:39:27] Aromatic bonds on non aromatic atom 8
# [18:39:29] Aromatic bonds on non aromatic atom 7
# [18:39:29] Aromatic bonds on non aromatic atom 8
# [18:39:29] Aromatic bonds on non aromatic atom 8
# [18:39:31] Aromatic bonds on non aromatic atom 7
# [18:39:31] Aromatic bonds on non aromatic atom 8
# [18:39:32] Aromatic bonds on non aromatic atom 8
# [18:39:32] Aromatic bonds on non aromatic atom 7
# [18:39:32] Aromatic bonds on non aromatic atom 8
# [18:39:33] Aromatic bonds on non aromatic atom 7
# [18:39:33] Aromatic bonds on non aromatic atom 7
# [18:39:33] Aromatic bonds on non aromatic atom 8
# [18:39:34] Aromatic bonds on non aromatic atom 7
# [18:39:34] Aromatic bonds on non aromatic atom 8
# [18:39:35] Aromatic bonds on non aromatic atom 7
# [18:39:35] Aromatic bonds on non aromatic atom 8
# [18:39:37] Aromatic bonds on non aromatic atom 7
# [18:39:37] Aromatic bonds on non aromatic atom 8
# [18:39:37] Aromatic bonds on non aromatic atom 8
# [18:39:37] Aromatic bonds on non aromatic atom 7
# [18:39:37] Aromatic bonds on non aromatic atom 8
# [18:39:38] Aromatic bonds on non aromatic atom 7
# [18:39:38] Aromatic bonds on non aromatic atom 7
# [18:39:38] Aromatic bonds on non aromatic atom 4
# [18:39:39] Aromatic bonds on non aromatic atom 8
# [18:39:39] Aromatic bonds on non aromatic atom 7
# [18:39:39] Aromatic bonds on non aromatic atom 8
# ['C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C@@H]2OC(=O)CCC1CCCC1'],0.571,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1CC[C@@H]2[OH:1],0.683
# ['CC(=O)OC[C@H]1O[C@H](O[C@]2(COC(C)=O)O[C@H](COC(C)=O)[C@@H](OC(C)=O)[C@@H]2OC(C)=O)[C@H](OC(C)=O)[C@@H](OC(C)=O)[C@@H]1OC(C)=O'],0.068,,
# ['OCC(O)c1ccccc1'],0.011,,
# ['CC1=CC(=O)c2ccccc2C1=O'],0.053,,
# ['Cc1cc(O)ccc1Cl'],0.013,,
# ['Oc1c(Cl)cc(Cl)c(Cl)c1Cl'],0.030,,
# ['c1ccc(CC2=NCCN2)cc1'],0.015,,
# ['COC(=O)[C@@H](N)Cc1ccc(O)c(O)c1'],0.021,,
# ['CCc1cccc(N(C)C(=N)Nc2cccc3ccccc23)c1'],0.047,,
# ['CCOC(=O)c1cnc2c(cnn2CC)c1NN=C(C)C'],0.011,,
# ['CCCCCCCCCCCCCCCCCCOC[C@H](COP(=O)([O-])OCC[N+](C)(C)C)OC'],0.007,,
# ['NCCCC(N)(C(=O)O)C(F)F'],0.045,,
# ['C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](OS(=O)(=O)[O-])CC[C@@]43C)[C@@H]1CCC2=O'],0.570,C[C@]12CC[C@H]3[C@@H](CC=[CH:1][C:1]3)[C@@H]1CCC2=O,0.521
# ['CCc1cc(Cl)c(OC)c(C(=O)NC[C@@H]2CCCN2CC)c1O'],0.031,,
# ['CCCCCCCCCCCCCCC[C@H](O)[C@@H](N)CO'],0.019,,
# ['CCCCCCC(O)CO'],0.009,,
# ['C=C(C)C(=O)OCc1ccccc1'],0.010,,
# ['C=C(C)C(=O)OCC1CCCO1'],0.005,,
# ['C=CC(=O)OCCCCCC'],0.015,,
# ['Cc1ccn2nc(S(=O)(=O)Nc3c(F)cccc3F)nc2n1'],0.007,,
# ['CCCN(CCCl)c1c([N+](=O)[O-])cc(C(F)(F)F)cc1[N+](=O)[O-]'],0.012,,
# ['CCCSP(=O)(OCC)SCCC'],0.001,,
# ['CCOc1ccc(C(C)(C)COCc2cccc(Oc3ccccc3)c2)cc1'],0.010,,
# ['COP(=S)(OC)Oc1ccc([N+](=O)[O-])c(C)c1'],0.005,,
# ['CCOP(=S)(OCC)OC(Cl)C(Cl)(Cl)Cl'],0.000,,
# ['O=C1c2ccccc2C(=O)C1C(=O)C(c1ccccc1)c1ccc(Cl)cc1'],0.008,,
# ['CC(C)(C)N(NC(=O)c1ccc(Cl)cc1)C(=O)c1ccccc1'],0.005,,
# ['O=C(O)/C=C/c1ccc(Cn2ccnc2)cc1'],0.028,,
# ['CCOC(=O)O[C@]1(C(=O)COC(=O)CC)CC[C@H]2[C@@H]3CCC4=CC(=O)C=C[C@]4(C)[C@H]3[C@@H](O)C[C@@]21C'],0.918,C[C@]12C=C[CH2:1]C=C1CC[C@@H]1[C@@H]2[CH2:1]C[C:1][CH2:1]1,0.706
# ['CS(=O)(=O)c1ccc([C@@H](O)[C@@H](CF)NC(=O)C(Cl)Cl)cc1'],0.020,,
# ['CC(=O)[C@@]1(O)CC[C@H]2[C@@H]3C[C@H](C)C4=CC(=O)CC[C@]4(C)[C@H]3CC[C@@]21C'],0.968,C[C@]12CC[CH2:1][CH2:1][C@@H]1CC[C@]2(O)[CH2:1]C,0.644
# ['C[C@@H]1CN([C@H]2CC[C@](C#N)(c3ccc(F)cc3)CC2)CC[C@]1(C(=O)O)c1ccccc1'],0.028,,
# ['O=C(O)c1cc(O)c2c(c1)[C@H]([C@H]1c3cc(C(=O)O)cc(O)c3C(=O)c3c(O[C@@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@H]4O)cccc31)c1cccc(O[C@@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@H]3O)c1C2=O'],0.061,,
# ['O=C(Oc1ccccc1C(=O)O)c1ccccc1O'],0.019,,
# ['OCc1cc(C(O)CNCCCCCCOCCCCc2ccccc2)ccc1O'],0.021,,
# ['CCC(=O)OC(=O)CC'],0.017,,
# ['Cc1c(C)c2c(c(C)c1O)CCC(C)(COc1ccc(CC3SC(=O)NC3=O)cc1)O2'],0.018,,
# ['Cc1ccc(/C(=C\\CN2CCCC2)c2ccccn2)cc1'],0.007,,
# ['COc1cc(C(=O)N2CCOCC2)cc(OC)c1OC'],0.008,,
# ['COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC'],0.008,,
# ['Cc1cc2cc3c(C)cc(=O)oc3c(C)c2o1'],0.063,,
# ['CCOP(=S)(OCC)Oc1cnc2ccccc2n1'],0.005,,
# ['Nc1ccc(C=Cc2ccc(N)cc2S(=O)(=O)O)c(S(=O)(=O)O)c1'],0.056,,
# ['NC1CCC(CC2CCC(N)CC2)CC1'],0.010,,
# ['N#C/C(N)=C(/N)C#N'],0.009,,
# ['NCCCCCCN'],0.021,,
# ['C[C@H]1[C@H](c2ccc(Cl)cc2)SC(=O)N1C(=O)NC1CCCCC1'],0.009,,
# ['CCCC[Sn](CCCC)(CCCC)O[Sn](CCCC)(CCCC)CCCC'],0.000,,
# ['CC(CCl)OC(C)CCl'],0.004,,
# ['OCC(CO)(CBr)CBr'],0.004,,
# ['Cc1c(COC(=O)C2C(/C=C(\\Cl)C(F)(F)F)C2(C)C)cccc1-c1ccccc1'],0.004,,
# ['CC1(C)C(=O)N(Br)C(=O)N1Br'],0.005,,
# ['ClCCOCCCl'],0.011,,
# ['O=C(O)CN(CCN(CC(=O)O)CC(=O)O)CC(=O)O'],0.006,,
# ['Nc1c2c(nc3ccccc13)CCCC2'],0.042,,
# ['CNC(=O)c1ccccc1'],0.017,,
# ['CN1C(=O)c2ccc([N+](=O)[O-])cc2C1=O'],0.014,,
# ['Cc1ccc(O)c(-n2nc3ccccc3n2)c1'],0.011,,
# ['CCCCCCCCCCCCCCCl'],0.010,,
# ['Cc1cc(O)c(C(C)(C)C)cc1C(C)(C)C'],0.000,,
# ['COc1ccc(Cl)cc1C'],0.005,,
# ['Oc1ccc(Cl)cc1C1CCCC1'],0.009,,
# ['Cc1cc(Cl)ccc1N'],0.013,,
# ['O=C1CCCc2c(O)cccc21'],0.042,,
# ['CCN1CCCC1CN'],0.018,,
# ['CC(=O)O[C@@H]1CC2C3CCc4cc(OC(=O)c5ccccc5)ccc4C3CCC2(C)[C@H]1OC(C)=O'],0.047,,
# ['Oc1cccc2[nH]ccc12'],0.025,,
# ['O=C(OCC(O)CO)c1ccccc1Nc1ccnc2c(C(F)(F)F)cccc12'],0.023,,
# ['COc1cc2nc(Cl)nc(N)c2cc1OC'],0.014,,
# ['O=C(O)c1ccccc1NCCc1ccccc1'],0.025,,
# ['CC(=O)c1cc2ccccc2s1'],0.053,,
# ['NC(=O)NS(=O)(=O)c1ccc(Cl)cc1'],0.008,,
# ['Cc1occc(=O)c1O'],0.007,,
# ['CCC(CC)Nc1ccc(C)c(C)c1'],0.013,,
# ['CC(=O)O[C@]1(C(C)=O)CC[C@H]2[C@@H]3C[C@H](C)C4=CC(=O)CC[C@]4(C)[C@H]3CC[C@@]21C'],0.927,C[C@]12CC[CH2:1][CH2:1][C@@H]1CC[C@]2([OH:1])[CH:1]=O,0.830
# ['O=C(CCCN1CC=C(n2c(=O)[nH]c3ccccc32)CC1)c1ccc(F)cc1'],0.024,,
# ['CCCCN=C=O'],0.006,,
# ['C1CCCNCC1'],0.004,,
# ['OCCSCCO'],0.003,,
# ['P#[In]'],0.002,,
# ['CCN(CC)c1ccc2c(-c3ccccc3C(=O)O)c3ccc(N(CC)CC)cc3[o+]c2c1'],0.040,,
# ['O=C(NCc1cccnc1)Nc1ccc([N+](=O)[O-])cc1'],0.028,,
# ['Cc1cnc2c(C(=O)O)c(Cl)ccc2c1'],0.032,,
# ['CCOc1ccc2c(c1)C(C)CC(C)(C)N2'],0.005,,
# ['CC(=O)NCc1c(I)c(NC(C)=O)c(I)c(C(=O)O)c1I'],0.044,,
# ['CON(C)C(=O)Nc1ccc(Br)c(Cl)c1'],0.039,,
# ['O=C(CCCCC(=O)Nc1c(I)cc(I)c(C(=O)O)c1I)Nc1c(I)cc(I)c(C(=O)O)c1I'],0.048,,
# ['O=C(O)c1c(Cl)ccc(Cl)c1Cl'],0.035,,
# ['O=C(O)CC(Cl)C(=O)O'],0.017,,
# ['N#CCCl'],0.005,,
# ['Cc1cccc2sc3nncn3c12'],0.010,,
# ['CC(=O)c1cc(C)oc1C'],0.011,,
# ['C=C(C)C1CC=C(C)C(OC(C)=O)C1'],0.018,,
# ['C=C1CCC=C(C)CC[C@@H]2[C@@H]1CC2(C)C'],0.007,,
# ['CCCC(C)(COC(N)=O)COC(=O)NC(C)C'],0.007,,
# ['C=C(C)C1CC=C(C)C(O)C1'],0.014,,
# ['CCCCCCCCCCCCCCCO'],0.010,,
# ['[Mn+2]'],0.002,,
# ['CCC(C)Cl'],0.005,,
# ['CCCCO'],0.005,,
# ['CC1=CC(=O)CC(C)(C)C1'],0.002,,
# ['Nc1cccc(C(F)(F)F)c1'],0.017,,
# ['NNC(=O)c1ccncc1'],0.015,,
# ['O=C(O)c1ccncc1'],0.006,,
# ['NC(=O)c1ccncc1'],0.008,,
# ['CC(C)CON=O'],0.005,,
# ['OC[C@H]1O[C@H](OC[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)CO)[C@H](O)[C@@H](O)[C@@H]1O'],0.019,,
# ['FC(F)OC(Cl)C(F)(F)F'],0.002,,
# ['c1ccc(C[n+]2cccc3ccccc32)cc1'],0.018,,
# ['CCCCN1C(=O)c2ccccc2C1=O'],0.010,,
# ['O=C1OC2(c3ccccc31)c1cc(Br)c(O)c(Br)c1Oc1c2cc(Br)c(O)c1Br'],0.019,,
# ['Cc1cc(C)c(C(=O)P(=O)(C(=O)c2c(C)cc(C)cc2C)c2ccccc2)c(C)c1'],0.005,,
# ['CC(C)(C)C(=O)/C=C/c1ccc(Cl)cc1'],0.006,,
# ['CCCCCCCCOCCC#N'],0.008,,
# ['CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccc(O)cc3)C(=O)N2[C@H]1C(=O)O'],0.027,,
# ['Cc1cc(C(C)(C)c2ccc(O)c(C)c2)ccc1O'],0.005,,
# ['CC(c1ccc(O)cc1)c1ccc(O)cc1'],0.014,,
# ['CCCCC#N'],0.003,,
# ['COc1ccc(C(=O)c2cccc(O)c2)c(OC)c1'],0.038,,
# ['CCCCCOC(=O)c1ccc(O)cc1'],0.020,,
# ['CCn1cc[n+](C)c1.N#C[S-]'],0.004,,
# ['CCCCCCCCCOC(=O)c1ccc(O)cc1'],0.018,,
# ['O=C1/C(=C2\\Nc3ccccc3C2=O)Nc2ccccc21'],0.024,,
# ['Oc1ccc(C2(c3ccc(O)cc3)CC3CC2C2CCCC32)cc1'],0.027,,
# ['C[C@H]1[C@H]2[C@@H](O[C@]13CC[C@@H](C)CO3)[C@@H](O)[C@H]1[C@@H]3CC[C@H]4C[C@@H](O[C@@H]5O[C@H](CO)[C@H](O[C@@H]6O[C@H](CO)[C@@H](O)[C@H](O[C@@H]7OC[C@@H](O)[C@H](O)[C@H]7O)[C@H]6O[C@@H]6O[C@H](CO)[C@@H](O)[C@H](O[C@@H]7O[C@H](CO)[C@@H](O)[C@H](O)[C@H]7O)[C@H]6O)[C@H](O)[C@H]5O)[C@H](O)C[C@]4(C)[C@H]3CC[C@@]12C'],0.058,,
# ['Nc1ccc(F)cc1F'],0.022,,
# ['CCCCC(=O)N(C)C'],0.007,,
# ['CN(C)c1nc(=O)n(C2CCCCC2)c(=O)n1C'],0.004,,
# ['CCCCCCOC(=O)c1ccccc1C(=O)OCCCCCC'],0.011,,
# ['COc1ccc2c(c1OC)C(=O)O[C@@H]2[C@H]1c2c(cc3c(c2OC)OCO3)CCN1C'],0.005,,
# ['CO[C@@H]1[C@@H](OC(N)=O)[C@@H](O)[C@H](Oc2ccc3c([O-])c(NC(=O)c4ccc(O)c(CC=C(C)C)c4)c(=O)oc3c2C)OC1(C)C'],0.030,,
# ['CC(CCc1ccccc1)NC(C)C(O)c1ccc(O)cc1'],0.023,,
# ['C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@@H]4[C@H]3CC[C@@]21C'],0.964,C#C[C@]1(O)CC[C@@H]2[C@]1(C)CC[CH2:1][CH2:1]2,0.682
# ['O=C1O[C@H]([C@H](O)CO)C([O-])=C1O'],0.018,,
# [18:44:02] Aromatic bonds on non aromatic atom 8
# [18:44:02] Aromatic bonds on non aromatic atom 7
# [18:44:02] Aromatic bonds on non aromatic atom 7
# [18:44:02] Aromatic bonds on non aromatic atom 7
# [18:44:03] Aromatic bonds on non aromatic atom 7
# [18:44:03] Aromatic bonds on non aromatic atom 8
# [18:44:04] Aromatic bonds on non aromatic atom 8
# [18:44:05] Aromatic bonds on non aromatic atom 7
# [18:44:05] Aromatic bonds on non aromatic atom 7
# [18:44:05] Aromatic bonds on non aromatic atom 4
# [18:44:05] Aromatic bonds on non aromatic atom 5
# [18:44:06] Aromatic bonds on non aromatic atom 7
# [18:44:06] Aromatic bonds on non aromatic atom 4
# [18:44:06] Aromatic bonds on non aromatic atom 6
# [18:44:07] Aromatic bonds on non aromatic atom 7
# [18:44:07] Aromatic bonds on non aromatic atom 7
# [18:44:08] Aromatic bonds on non aromatic atom 4
# ['C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C@@H]2O'],0.799,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1CC[C@@H]2O,0.683
# ['Clc1ccc2c(c1)C(c1ccccc1)=NCc1nncn1-2'],0.010,,
# ['Cc1cc2c(s1)Nc1ccccc1N=C2N1CCN(C)CC1'],0.032,,
# ['CCc1cc(C(N)=S)ccn1'],0.017,,
# [18:44:10] Aromatic bonds on non aromatic atom 12
# [18:44:11] Aromatic bonds on non aromatic atom 11
# [18:44:11] Aromatic bonds on non aromatic atom 10
# [18:44:11] Aromatic bonds on non aromatic atom 9
# [18:44:11] Aromatic bonds on non aromatic atom 9
# [18:44:12] Aromatic bonds on non aromatic atom 6
# [18:44:12] Aromatic bonds on non aromatic atom 5
# [18:44:12] Aromatic bonds on non aromatic atom 5
# [18:44:13] Aromatic bonds on non aromatic atom 11
# [18:44:13] Aromatic bonds on non aromatic atom 11
# [18:44:13] Aromatic bonds on non aromatic atom 12
# [18:44:13] Aromatic bonds on non aromatic atom 10
# [18:44:13] Aromatic bonds on non aromatic atom 10
# [18:44:13] Aromatic bonds on non aromatic atom 11
# [18:44:13] Aromatic bonds on non aromatic atom 9
# [18:44:13] Aromatic bonds on non aromatic atom 10
# [18:44:14] Aromatic bonds on non aromatic atom 12
# [18:44:15] Aromatic bonds on non aromatic atom 11
# [18:44:15] Aromatic bonds on non aromatic atom 10
# [18:44:15] Aromatic bonds on non aromatic atom 9
# [18:44:16] Aromatic bonds on non aromatic atom 6
# [18:44:16] Aromatic bonds on non aromatic atom 5
# [18:44:16] Aromatic bonds on non aromatic atom 6
# [18:44:16] Aromatic bonds on non aromatic atom 10
# [18:44:16] Aromatic bonds on non aromatic atom 10
# [18:44:16] Aromatic bonds on non aromatic atom 11
# [18:44:19] Aromatic bonds on non aromatic atom 11
# [18:44:19] Aromatic bonds on non aromatic atom 10
# [18:44:19] Aromatic bonds on non aromatic atom 10
# [18:44:20] Aromatic bonds on non aromatic atom 11
# [18:44:20] Aromatic bonds on non aromatic atom 11
# [18:44:20] Aromatic bonds on non aromatic atom 10
# [18:44:20] Aromatic bonds on non aromatic atom 10
# [18:44:20] Aromatic bonds on non aromatic atom 9
# [18:44:21] Aromatic bonds on non aromatic atom 11
# [18:44:21] Aromatic bonds on non aromatic atom 9
# [18:44:21] Aromatic bonds on non aromatic atom 11
# [18:44:21] Aromatic bonds on non aromatic atom 11
# [18:44:23] Aromatic bonds on non aromatic atom 10
# [18:44:23] Aromatic bonds on non aromatic atom 9
# [18:44:23] Aromatic bonds on non aromatic atom 10
# [18:44:25] Aromatic bonds on non aromatic atom 11
# [18:44:25] Aromatic bonds on non aromatic atom 10
# [18:44:26] Aromatic bonds on non aromatic atom 9
# [18:44:26] Aromatic bonds on non aromatic atom 11
# [18:44:26] Aromatic bonds on non aromatic atom 10
# [18:44:27] Aromatic bonds on non aromatic atom 9
# [18:44:27] Aromatic bonds on non aromatic atom 9
# [18:44:28] Aromatic bonds on non aromatic atom 10
# [18:44:28] Aromatic bonds on non aromatic atom 11
# ['C#C[C@]1(O)CC[C@H]2[C@@H]3CCc4cc(O)ccc4[C@H]3CC[C@@]21C'],0.767,C#C[C@]1(O)CC[C@@H]2[C@]1(C)CC[CH2:1][CH2:1]2,0.682
# ['CC/C(=C(\\c1ccc(O)cc1)c1ccc(OCCN(C)C)cc1)c1ccccc1'],0.008,,
# ['CN/C(=N\\[N+](=O)[O-])NCc1cnc(Cl)s1'],0.009,,
# ['CC[C@H](c1ccc(O)cc1)[C@@H](CC)c1ccc(O)cc1'],0.008,,
# ['CC(=O)OCC(CCn1cnc2cnc(N)nc21)COC(C)=O'],0.008,,
# ['NC(N)=Nc1nc(CSCC/C(N)=N\\S(N)(=O)=O)cs1'],0.010,,
# ['CCOC(=O)/C=C(C)/C=C/C=C(C)/C=C/c1c(C)cc(OC)c(C)c1C'],0.017,,
# ['C=C1C[C@@H]2[C@H](CC[C@]3(C)C(=O)CC[C@@H]23)[C@@]2(C)C=CC(=O)C=C12'],0.866,C[C@]12C=CC(=O)C=C1[CH2:1]C[CH2:1][CH2:1]2,0.680
# ['COc1cc([C@@H]2c3cc4c(cc3C(O[C@@H]3O[C@@H]5CO[C@@H](C)O[C@H]5[C@H](O)[C@H]3O)C3COC(=O)[C@@H]32)OCO4)cc(OC)c1O'],0.021,,
# ['Cn1c(=O)c2c(ncn2CCOC(=O)C(C)(C)Oc2ccc(Cl)cc2)n(C)c1=O'],0.012,,
# ['CCOC(=O)c1cncn1C(C)c1ccccc1'],0.006,,
# ['CCc1cc2c(s1)-n1c(C)nnc1CN=C2c1ccccc1Cl'],0.021,,
# ['Cn1c(=O)c2c(ncn2CCO)n(C)c1=O'],0.007,,
# ['Cc1ccccc1NC(=N)Nc1ccccc1C'],0.047,,
# ['CO[C@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O'],0.028,,
# ['CC(C)(C)c1ccc(O)c(C(C)(C)C)c1'],0.000,,
# ['CNC(=O)Oc1cccc(N=CN(C)C)c1'],0.039,,
# ['O=C1OCCO1'],0.002,,
# ['C=C(CC(=O)O)C(=O)O'],0.016,,
# ['CC(C)C(=O)OC(=O)C(C)C'],0.020,,
# ['O=C1NCCN1c1ncc([N+](=O)[O-])s1'],0.022,,
# ['Nc1nc2cc(Cl)ccc2o1'],0.031,,
# ['CN(CCCCCCCCCCN(C)C(=O)Oc1ccccc1[N+](C)(C)C)C(=O)Oc1ccccc1[N+](C)(C)C'],0.006,,
# ['COc1cc(NC(C)CCCN)c2ncccc2c1'],0.025,,
# ['Cc1ccc(Cl)cc1N'],0.017,,
# ['Cc1ccc(N)cc1Cl'],0.023,,
# ['CC(O)CCl'],0.010,,
# ['Nc1ccc(N)c(Cl)c1'],0.086,,
# ['Nc1ccc(Cl)cc1N'],0.073,,
# ['Nc1ccc(Cl)c(N)c1'],0.060,,
# ['CCCCN(CCC(=O)OCC)C(C)=O'],0.017,,
# ['O=[N+]([O-])c1ccccc1Cl'],0.009,,
# ['COC(=O)C=C(C)N'],0.011,,
# ['COc1cnc(OC)n2nc(NS(=O)(=O)c3c(OCC(F)F)cccc3C(F)(F)F)nc12'],0.007,,
# ['CC(=O)CCC(=O)[O-].CC(=O)CCC(=O)[O-]'],0.010,,
# ['O=C([O-])[O-].[Sr+2]'],0.001,,
# ['O=C(O)[C@@H]1CSCN1'],0.006,,
# ['CC(C)CCCC(C)N'],0.004,,
# ['CC(=O)N[C@@H](CCC(=O)O)C(=O)O'],0.029,,
# ['C=CC(=O)OC(C)(C)C'],0.001,,
# ['OCc1ccccn1'],0.006,,
# ['Cn1ccc2cc3c(cc21)CCN3C(=O)Nc1cccnc1'],0.044,,
# ['CC1(C)CC(O)CC(C)(C)N1'],0.003,,
# ['Cc1ccccn1'],0.002,,
# ['Cc1cccnc1'],0.001,,
# ['OC1CCCCC1'],0.002,,
# ['Cc1ccncc1'],0.001,,
# ['CC(C)OC(C)C'],0.002,,
# ['O=C(O)COc1ccc2ccccc2c1'],0.025,,
# ['CCCCOC(=O)C(C)O'],0.015,,
# ['CNC(=S)NC'],0.001,,
# ['CCCCCCCCCC[N+](C)(C)[O-]'],0.007,,
# ['O=C1CCC(=O)N1Cl'],0.014,,
# ['CCCCNS(=O)(=O)c1ccc(C)cc1'],0.012,,
# ['CCN(CCN)c1cccc(C)c1'],0.031,,
# ['CC(COC(=O)c1ccccc1)OC(=O)c1ccccc1'],0.009,,
# ['O=C([O-])CNc1ccccc1'],0.016,,
# ['Cc1ccc2c(c1)C(=O)OC2=O'],0.007,,
# ['CC(C)(N)C#N'],0.003,,
# ['CNC(C)Cc1ccccc1OC'],0.008,,
# ['NCCN1CCOCC1'],0.014,,
# ['COP(=S)(OC)Oc1ccc(S(N)(=O)=O)cc1'],0.004,,
# ['CC1CC(C)C(=O)C1=O'],0.013,,
# ['CC(=O)SCc1ccco1'],0.007,,
# ['Cc1ccc(C(C)NC(=O)[C@@H](NC(=O)OC(C)C)C(C)C)cc1'],0.014,,
# ['c1coc(Cn2cccc2)c1'],0.008,,
# ['Brc1c(Br)c(Br)c(Br)c(Br)c1Br'],0.315,,
# ['CCCCCCCCCCC=CC#N'],0.012,,
# ['COC(=O)c1sccc1S(=O)(=O)NC(=O)Nc1nc(C)nc(OC)n1'],0.008,,
# ['CCCCCCC'],0.004,,
# ['ClC1=C(Cl)C2(Cl)C3C4OC4C(Cl)C3C1(Cl)C2(Cl)Cl'],0.000,,
# ['COC(=O)C(C)Oc1ccc(Oc2ncc(C(F)(F)F)cc2Cl)cc1'],0.015,,
# ['CC1=NN(c2cc(Cl)c(S(=O)(=O)[O-])cc2Cl)C(=O)C1/N=N/c1ccc(S(=O)(=O)[O-])cc1'],0.010,,
# ['COc1ccccc1/N=N/c1c(S(=O)(=O)[O-])cc2cc(S(=O)(=O)[O-])cc(NC(C)=O)c2c1O'],0.014,,
# ['CC1(C)[C@@H](O[C@H]2O[C@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]2O[C@@H]2O[C@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]2O)CC[C@@]2(C)[C@H]1CC[C@]1(C)[C@@H]2C(=O)C=C2[C@@H]3C[C@@](C)(C(=O)O)CC[C@]3(C)CC[C@]21C'],0.090,,
# ['ClCCOCCOCCCl'],0.011,,
# ['COC(Cc1ccccc1)OC'],0.006,,
# ['Cc1c(C(=O)O)c(O)cc2c1C(=O)c1c(O)c([C@@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@H]3O)c(O)c(O)c1C2=O'],0.083,,
# ['Nc1c(/N=N/c2ccc(-c3ccc(/N=N/c4cc(S(=O)(=O)[O-])c5ccccc5c4N)cc3)cc2)cc(S(=O)(=O)[O-])c2ccccc12'],0.055,,
# ['Cc1cc(-c2ccc(/N=N/c3ccc4c(S(=O)(=O)[O-])cc(S(=O)(=O)[O-])c(N)c4c3O)c(C)c2)ccc1/N=N/c1ccc2c(S(=O)(=O)[O-])cc(S(=O)(=O)[O-])c(N)c2c1O'],0.030,,
# ['O=C([O-])c1c(Cl)c(Cl)c(Cl)c(Cl)c1-c1c2cc(I)c(=O)c(I)c-2oc2c(I)c([O-])c(I)cc12'],0.047,,
# ['O=c1[nH]c2cc(Cl)ccc2o1'],0.019,,
# ['NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl'],0.027,,
# ['CN(C)CC/C=C1\\c2ccccc2Sc2ccc(Cl)cc21'],0.008,,
# ['CCC(=O)O[C@]1(C(=O)CCl)[C@@H](C)C[C@H]2[C@@H]3C[C@H](F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@@]21C'],0.961,C[C@]12C=CC(=O)C=C1[CH2:1]C[CH2:1][C:1]2,0.608
# ['O=C([O-])c1cc(O)c2c3nc4ccccc4oc-3cc(=O)c2n1'],0.071,,
# ['CCC(C)(Oc1ccc(C2(c3ccc(OC(C)(CC)C(=O)O)cc3)CCCCC2)cc1)C(=O)O'],0.020,,
# ['C(=C\\c1ccccc1)\\c1ccccc1'],0.031,,
# ['Cc1cccc(C)c1NC(=O)CC12CCCN1CCC2'],0.026,,
# ['CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C'],0.007,,
# ['C[C@]12CC[C@H]3[C@@H](CC=C4C[C@@H](O)CC[C@@]43C)[C@@H]1CC[C@@H]2O'],0.804,C[C@]12CC[C@H]3[C@@H](CC=[CH:1][C:1]3)[C@@H]1CC[C@@H]2O,0.606
# ['CC[N+](C)(C)c1cccc(O)c1'],0.003,,
# ['COC(=O)c1ccccc1O'],0.006,,
# ['Cc1ccc2ccc3cccc4ccc1c2c34'],0.035,,
# ['Nc1cc(-c2ccncc2)c[nH]c1=O'],0.020,,
# ['Cc1ccc2cccnc2c1'],0.007,,
# ['CC(C)(C#N)c1cc(Cn2cncn2)cc(C(C)(C)C#N)c1'],0.002,,
# ['CC(C)Cc1nccs1'],0.001,,
# ['Nc1cc(Cl)c(NC2=NCCN2)c(Cl)c1'],0.059,,
# ['CCN(CC)CCNC(=O)c1ccc(NC(C)=O)cc1'],0.050,,
# ['O=C(Oc1ccccc1)c1ccccc1C(=O)Oc1ccccc1'],0.019,,
# ['COP(=O)(OC)OC(c1ccc(Cl)cc1)P(=O)(OC)OC'],0.003,,
# ['CC1(N)CCC(C(C)(C)N)CC1'],0.006,,
# ['Cn1nc(N)c2cn([C@@H]3O[C@H](CO)[C@@H](O)[C@H]3O)c3ncnc1c23'],0.030,,
# ['CCC(CC)(CC(=O)Nc1cccc(/C=C/c2nc(C3CCC3)cs2)c1)C(=O)O'],0.062,,
# ['Cc1cc2nc3c(=O)[nH]c(=O)nc-3n(C[C@H](O)[C@H](O)[C@H](O)CO)c2cc1C'],0.044,,
# ['OC(CN1CCC(Cc2ccc(F)cc2)CC1)c1ccc(Cl)cc1'],0.017,,
# ['Cc1c[nH]c2ccccc12'],0.010,,
# ['c1cc2c3c(cccc3c1)CC2'],0.028,,
# ['CC/C(=N\\OC/C=C/Cl)C1=C(O)CC(C2CCOCC2)CC1=O'],0.006,,
# ['CCOP(=O)(OCC)OC(=CCl)c1ccc(Cl)cc1Cl'],0.010,,
# ['NC(=O)CF'],0.008,,
# ['CC(C)(C)Cl'],0.000,,
# ['CC(C)O[Ti](OCCN(CCO)CCO)(OCCN(CCO)CCO)OC(C)C'],0.009,,
# ['CCCCCCCCCCCCSC'],0.007,,
# ['O=C1NC(c2ccccc2)(c2ccccc2)C(=O)N1COP(=O)(O)O'],0.011,,
# ['O=C1CCCN1CCO'],0.019,,
# ['CN(C)C=Nc1c(I)cc(I)c(CCC(=O)[O-])c1I'],0.019,,
# ['CC(=O)Nc1c(I)c(C(=O)[O-])c(I)c(N(C)C(C)=O)c1I'],0.029,,
# ['CCCCC(CC)COC(=O)OOC(C)(C)C'],0.004,,
# ['CCCCNC1CC(C)(C)NC(C)(C)C1'],0.007,,
# ['CCCCC(CC)CO[PH](=O)OCC(CC)CCCC'],0.011,,
# ['O=C(C(=O)c1ccc(Br)cc1)c1ccc(Br)cc1'],0.018,,
# ['Clc1ccc(C(Cn2ccnc2)OCc2csc3c(Cl)cccc23)c(Cl)c1'],0.009,,
# ['CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)c(F)c21'],0.092,,
# ['C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(S[C@@H]3CN[C@H](C(=O)N(C)C)C3)[C@H](C)[C@H]12'],0.032,,
# ['O=C(NCC(O)CO)c1c(I)c(C(=O)NCC(O)CO)c(I)c(N(CCO)C(=O)CO)c1I'],0.047,,
# ['CC(=O)N(CC(O)CN(C(C)=O)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I)c1c(I)c(C(=O)NCC(O)CO)c(I)c(C(=O)NCC(O)CO)c1I'],0.047,,
# ['O=C(O)COC(=O)Cc1ccccc1Nc1c(Cl)cccc1Cl'],0.038,,
# ['O=S(=O)(O)c1ccccc1O'],0.006,,
# ['CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](O)[C@H]1OC[C@H](O)[C@H]1O'],0.021,,
# ['CCC1CCC(CCC(=O)O)C1'],0.007,,
# ['CC(=O)Oc1cc2c(s1)CCN(C(C(=O)C1CC1)c1ccccc1F)C2'],0.024,,
# ['Nc1ccccc1S(=O)(=O)c1ccccc1'],0.008,,
# ['CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N1[C@H](C(=O)O)C[C@@H]2CCC[C@@H]21'],0.051,,
# ['O=C(c1ccc(OCCN2CCCCC2)cc1)c1c(-c2ccc(O)cc2)sc2cc(O)ccc12'],0.065,,
# ['CCOc1cc(CC(=O)N[C@@H](CC(C)C)c2ccccc2N2CCCCC2)ccc1C(=O)O'],0.025,,
# ['COC(=O)[C@H]1[C@H]2C[C@@H]3c4[nH]c5cc(OC)ccc5c4CCN3C[C@H]2C[C@@H](OC(=O)C=Cc2cc(OC)c(OC)c(OC)c2)[C@@H]1OC'],0.031,,
# ['NC(=O)c1ncn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)n1'],0.037,,
# ['CC1=C(/C=C/C(C)=C/C=C/C(C)=C/CO)C(C)(C)CCC1'],0.003,,
# ['CCCCCCCC(=O)CC[C@H]1[C@H](O)C[C@H](O)[C@@H]1C/C=C\\CCCC(=O)OC(C)C'],0.041,,
# ['CCN1CCCC1CNC(=O)c1cc(S(=O)(=O)CC)ccc1OC'],0.022,,
# ['CCCCCCCCCCCCCCCCCCN(C)C'],0.009,,
# ['CCCCOCCOCCOC(C)=O'],0.011,,
# ['O=C1CCCCO1'],0.003,,
# ['CCCCOC(=O)CC#N'],0.007,,
# ['COc1ccc(C(CN(C)C)C2(O)CCCCC2)cc1'],0.009,,
# ['CC(=O)O[C@H]1C[C@@H]2CC[C@@H]3[C@H](CC[C@@]4(C)[C@H]3C[C@H]([N+]3(C)CCCCC3)[C@@H]4OC(C)=O)[C@@]2(C)C[C@@H]1N1CCCCC1'],0.063,,
# ['N[C@@H](Cc1ccc(O)cc1)C(=O)O'],0.031,,
# ['CCCC(CCC)C(=O)O'],0.008,,
# ['O=C(Cc1ccccc1)c1ccccc1'],0.015,,
# ['CC(C)(C)NCCO'],0.007,,
# ['C=CC(N)CCC(=O)O'],0.016,,
# ['CCN(CC)CCOC(=O)c1ccc(N)cc1'],0.028,,
# ['CC(=O)C1CCOC1=O'],0.008,,
# ['Nc1cc(N)cc(C(=O)O)c1'],0.061,,
# ['N#CC(Br)(Br)C(N)=O'],0.001,,
# ['N#Cc1c(Cl)cccc1Cl'],0.016,,
# ['c1ccc2occc2c1'],0.007,,
# ['Nc1nc(N)nc(-c2ccccc2)n1'],0.021,,
# ['O=C(O)c1ccccc1'],0.007,,
# ['O=C(c1ccccc1)C(O)c1ccccc1'],0.018,,
# ['O=C1C=CC(=O)C=C1'],0.116,,
# ['c1ccc2sc(SSc3nc4ccccc4s3)nc2c1'],0.004,,
# ['c1ccc2[nH]nnc2c1'],0.001,,
# ['ClC(Cl)(Cl)c1ccccc1'],0.004,,
# ['NNC(=O)c1ccccc1'],0.028,,
# ['CS(=O)(=O)Nc1ccc([N+](=O)[O-])cc1Oc1ccccc1'],0.019,,
# ['FC1(F)C(F)(F)C(F)(F)C2(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C2(F)C1(F)F'],0.000,,
# ['CCCC/C=C/C=C\\C=O'],0.024,,
# ['CC(C)=CCCC(C)CC(=O)O'],0.005,,
# ['CCc1nccnc1CC'],0.003,,
# ['COc1ccc(O)cc1'],0.011,,
# ['c1ccc(Nc2cccc3ccccc23)cc1'],0.055,,
# ['N#Cc1ccncc1'],0.003,,
# ['C[C@@H](N)[C@@H](O)c1ccccc1'],0.025,,
# ['NCCCN1CCOCC1'],0.011,,
# ['CC(C)c1ccc2c(c1)CC[C@@H]1[C@]2(C)CCC[C@@]1(C)CN'],0.021,,
# ['O=[N+]([O-])c1cc[n+]([O-])cc1'],0.009,,
# ['CC1(C)CC(=O)CC(C)(C)N1'],0.003,,
# ['O=C(O)C(O)C(O)C(=O)O'],0.023,,
# ['CC(C)CCCC(C)CCCC(C)CCCCC(C)CCCC(C)CCCC(C)C'],0.003,,
# ['Sc1ccccc1'],0.004,,
# ['O=c1c2ccccc2c(=O)c2c1cc(Cl)c1[nH]c3c([nH]c12)c(Cl)cc1c(=O)c2ccccc2c(=O)c13'],0.085,,
# ['COc1ccc2nc(NC(=O)Nc3ccccc3)sc2c1'],0.115,,
# ['CCC(C(=O)OCCOCCN(CC)CC)c1ccccc1.O=C(O)CC(O)(CC(=O)O)C(=O)O'],0.021,,
# ['CN1CCN(c2cc3c(nn2)Oc2ccccc2N3C)CC1'],0.007,,
# ['O=C(N/N=C/c1ccccc1O)c1ccncc1'],0.023,,
# ['Cc1ccc(S(=O)(=O)NC(=O)NC2CCCCC2)cc1'],0.007,,
# ['CC(O)C(=O)O.CCOc1ccc2nc3cc(N)ccc3c(N)c2c1'],0.061,,
# ['NS(=O)(=O)c1ccc(NC(=O)CCC(=O)O)cc1'],0.031,,
# ['COc1ccc(S(=O)(=O)Nc2nnc(CC(C)C)s2)cc1'],0.005,,
# ['O=C(Nc1ncc([N+](=O)[O-])s1)c1cccs1'],0.039,,
# ['CC(C)(O)C(=O)O'],0.008,,
# ['CC[C@@H]1C[C@H](N(Cc2cc(C(F)(F)F)cc(C(F)(F)F)c2)C(C)=O)c2cc(C(F)(F)F)ccc2N1C(=O)OC(C)C'],0.015,,
# ['CC(C)(O)c1ccc(CNC(=O)c2cccnc2Oc2ccc(F)cc2)cc1'],0.015,,
# ['CNCc1ccc(NC(=O)c2c[nH]c3c2C(=O)CCC3)cc1'],0.064,,
# ['CC(Cc1ccc(OCC(=O)O)cc1)NCC(O)c1csc(C(F)(F)F)n1'],0.021,,
# ['Cc1nccn1-c1ccc(Sc2cccc(C3(C(N)=O)CCOCC3)c2)cc1'],0.011,,
# ['Cc1cc(CCN2CCN(c3nsc4ccccc34)CC2)cc2c1NC(=O)CC2(C)C'],0.023,,
# ['O=c1[nH]c2ccc(S(=O)CCN3CCC(Cc4ccc(F)cc4)CC3)cc2o1'],0.025,,
# ['Nc1cc(Cl)c(O)c(Cl)c1'],0.047,,
# ['O=C1CCC(C2CCCCC2)CC1'],0.007,,
# ['OC1CCC(C2CCCCC2)CC1'],0.004,,
# ['O=C(Nc1ccccc1)c1cc([N+](=O)[O-])ccc1Cl'],0.032,,
# ['O=C(O)c1ccc([Hg]Cl)cc1'],0.010,,
# ['Cc1c(C(=O)NCCO)[n+]([O-])c2ccccc2[n+]1[O-]'],0.034,,
# ['OC(Cn1cncn1)(c1ccc(F)cc1)c1ccccc1F'],0.008,,
# ['CCCCOP(=O)(O)OCCCC'],0.014,,
# ['NC(=O)c1ccc([N+](=O)[O-])cc1'],0.023,,
# ['CCCO[Si](OCCC)(OCCC)OCCC'],0.001,,
# ['CCCCC[C@H](O)/C=C/[C@H]1[C@H](O)CC(=O)[C@@H]1CCCCCCC(=O)O'],0.038,,
# ['CCCCCCNC(=O)n1cc(F)c(=O)[nH]c1=O'],0.025,,
# ['CCCCCCCCCCCC[n+]1ccc2ccccc2c1'],0.019,,
# ['CCCC(=O)Cl'],0.010,,
# ['CCCCCCCCCl'],0.010,,
# ['Oc1ccccc1Cl'],0.007,,
# ['CC(Cl)C(=O)O'],0.011,,
# ['O=C(O)CCCl'],0.007,,
# ['O=[Cd]'],0.006,,
# ['COc1ccc(OC)c(C(O)CNC(=O)CN)c1'],0.027,,
# ['CSc1cnccn1'],0.000,,
# ['C=CC(C)(CCC=C(C)C)OC(=O)C(C)C'],0.007,,
# ['CCCCCCCCCCOC(=O)c1ccccc1C(=O)OCCCCCCCC'],0.012,,
# ['CC(C)OC=O'],0.003,,
# ['N#Cc1cccc(C#N)c1'],0.033,,
# ['CCOC(=O)/C=C/C(=O)OCC'],0.019,,
# ['CCC(C)COC(C)=O'],0.008,,
# ['c1ccc(Cc2ccccc2)cc1'],0.010,,
# ['C[C@H]1CNCCc2ccc(Cl)cc21'],0.021,,
# ['Cc1nnc(C(=O)NC(C)(C)c2nc(C(=O)NCc3ccc(F)cc3)c(O)c(=O)n2C)o1'],0.015,,
# ['O=S(=O)(c1ccccc1)c1ccccc1'],0.005,,
# ['CCC(C)OC(=O)c1ccc(O)cc1'],0.015,,
# ['Cc1ccc(NC(=O)N(C)C)cc1NC(=O)N(C)C'],0.034,,
# ['[O-][n+]1ccccc1SSc1cccc[n+]1[O-]'],0.006,,
# ['C=COCC1CCC(COC=C)CC1'],0.007,,
# ['N#Cc1c(F)cccc1F'],0.027,,
# ['CC(O)CN1CCN(CC(=O)[O-])CCN(CC(=O)[O-])CCN(CC(=O)[O-])CC1.[Gd+3]'],0.005,,
# ['S=C=S'],0.001,,
# ['Nc1c(NC/C=C\\COc2cc(CN3CCCCC3)ccn2)c(=O)c1=O'],0.019,,
# ['CN1[C@H]2CC[C@@H]1C[C@H](NC(=O)n1c(=O)[nH]c3ccccc31)C2'],0.025,,
# ['C1CCc2nnnn2CC1'],0.000,,
# ['CC(C(=O)O)c1ccc(/C=C2\\CCCCC2=O)cc1'],0.034,,
# ['CCCCCOc1ccc(C2SC(=O)NC2=O)cc1OCC'],0.009,,
# ['CC[N+](CC)(CC)CCOC(=O)C(C1CCCC1)C1CCCC1'],0.005,,
# ['CCCCCCCCCCCCCCCCCCNC(=O)OC1CCN(C(=O)OC[C@H](COC(=O)N(Cc2cccc[n+]2CC)C(=O)c2ccccc2OC)OC)CC1'],0.021,,
# ['CCOC(=O)c1ccc(OCCN2C[C@H](O)[C@@H](O)[C@H](O)[C@H]2CO)cc1'],0.032,,
# ['CCC(C)N(C)C(=O)c1cc2ccccc2c(-c2ccccc2Cl)n1'],0.032,,
# ['Cc1ccc(/C=N/n2c(-c3ccccc3)csc2=S)cc1'],0.028,,
# ['CN(CCCN1c2ccccc2CCc2ccccc21)CC(=O)c1ccc(Cl)cc1'],0.017,,
# ['CN(C)CCOC(c1ccc(Cl)cc1)c1ccccn1'],0.008,,
# ['NC[C@@H]1O[C@H](O[C@@H]2[C@@H](CO)O[C@@H](O[C@@H]3[C@@H](O)[C@H](N)C[C@H](N)[C@H]3O[C@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@H]3N)[C@@H]2O)[C@H](N)[C@@H](O)[C@@H]1O'],0.088,,
# ['Clc1ccc(C(Cl)(Cl)Cl)cn1'],0.004,,
# ['CCC1=C[C@@H]2CN(C1)Cc1c([nH]c3ccccc13)[C@@](C(=O)OC)(c1cc3c(cc1OC)N(C)[C@H]1[C@@](O)(C(=O)OC)[C@H](OC(C)=O)[C@]4(CC)C=CCN5CC[C@]31[C@@H]54)C2'],0.035,,
# ['c1ccc(P(c2ccccc2)c2ccccc2)cc1'],0.005,,
# ['c1ccc(OP(Oc2ccccc2)Oc2ccccc2)cc1'],0.005,,
# ['CC(CCl)OP(=O)(OC(C)CCl)OC(C)CCl'],0.002,,
# ['ClCCOP(OCCCl)OCCCl'],0.003,,
# ['CCOC(=O)OCC'],0.005,,
# ['CCN(C(=O)N(CC)c1ccccc1)c1ccccc1'],0.015,,
# ['C=CC(=O)OCCOCCOC(=O)C=C'],0.021,,
# ['CCOCCOCCOCC'],0.009,,
# ['CCOP(=S)(OCC)SCCSCC'],0.001,,
# ['COCCOCCO'],0.007,,
# ['C1CN2CCN1CC2'],0.006,,
# ['COc1ccc(OC)cc1'],0.005,,
# ['CCCCCCCC/C=C\\CCCCCCCCO'],0.007,,
# ['CC(C)OC(=O)C(C)(C)Oc1ccc(C(=O)c2ccc(Cl)cc2)cc1'],0.015,,
# ['ClC(Cl)(Cl)Br'],0.041,,
# ['CC(C)(C)NC[C@H](O)COc1cccc2c1CCCC2=O'],0.023,,
# ['CC(C(=O)O)c1cccc(C(=O)c2ccccc2)c1'],0.031,,
# ['C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@@H]3CC[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@@]21C'],0.128,,
# ['C=C(C)[C@H]1CC=C(C)CC1'],0.010,,
# ['Nc1nc(=O)[nH]cc1F'],0.009,,
# ['O=C(O)Cc1sc(-c2ccccc2)nc1-c1ccc(Cl)cc1'],0.047,,
# ['CC(C)=CCC1C(=O)N(c2ccccc2)N(c2ccccc2)C1=O'],0.010,,
# ['O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1F'],0.033,,
# ['O=CC1CC=CCC1'],0.006,,
# ['CS(=O)(=O)c1ccc(C(=O)C2C(=O)CCCC2=O)c([N+](=O)[O-])c1'],0.016,,
# ['CC1=C(/C=C/C(C)=C/C=C\\C(C)=C\\C(=O)O)C(C)(C)CCC1'],0.006,,
# ['SCc1ccccc1'],0.009,,
# ['N#Cc1cccnc1'],0.003,,
# ['O=S(=O)([O-])C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.000,,
# ['CCC1(CC)C(=O)C=CNC1=O'],0.014,,
# ['O=C(OCC(COC(=O)c1ccccc1)(COC(=O)c1ccccc1)COC(=O)c1ccccc1)c1ccccc1'],0.008,,
# ['COc1c2occc2c(OC)c2c(=O)cc(C)oc12'],0.019,,
# ['Nc1ccc(S(=O)(=O)Nc2ccc(Cl)nn2)cc1'],0.010,,
# ['O=C(O)CO'],0.004,,
# ['O=CC=O'],0.011,,
# ['CC1CCC(C(C)C)C(O)C1'],0.003,,
# ['CN(C)CCOC(C)(c1ccccc1)c1ccccn1.O=C(O)CCC(=O)O'],0.010,,
# ['Sc1nc2ccccc2s1'],0.027,,
# ['NCCc1ccc(O)c(O)c1'],0.020,,
# ['O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23'],0.052,,
# ['Cc1cnc(NC(=O)C2=C(O)c3ccccc3S(=O)(=O)N2C)s1'],0.018,,
# ['Nc1nc(N)nc(N)n1'],0.007,,
# ['CC[C@H]1CN2CCc3cc(OC)c(OC)cc3[C@@H]2C[C@@H]1C[C@H]1NCCc2cc(OC)c(OC)cc21'],0.017,,
# ['O=S(=O)([O-])CCS'],0.003,,
# ['CCn1cc[n+](C)c1C.O=S(=O)([N-]S(=O)(=O)C(F)(F)F)C(F)(F)F'],0.001,,
# ['CCCCCCCCCCCCSCCOCCO'],0.008,,
# ['N=C(N)n1cccn1'],0.005,,
# ['FC(F)(F)COCC(F)(F)F'],0.015,,
# ['Cc1c(I)c(=O)n(-c2ccccc2)n1C'],0.016,,
# ['CCC(C(N)=O)N1CCCC1=O'],0.017,,
# ['CC(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)O'],0.037,,
# ['OCC(O)CS'],0.005,,
# ['CC(=O)c1ccc2ccc3ccccc3c2c1'],0.055,,
# ['Nc1ccc(NCCO)c([N+](=O)[O-])c1'],0.049,,
# ['Cc1cc(C)c(S(=O)(=O)[O-])cc1N=Nc1cc(S(=O)(=O)[O-])c2ccccc2c1O'],0.015,,
# ['COc1ccccc1N1CCN(CCCCNC(=O)c2ccc(-c3ccc(C(C)=O)cc3)cc2)CC1'],0.040,,
# ['[Be+2]'],0.001,,
# ['COCCOCCOCCOCCO'],0.008,,
# ['Cc1cccc(Oc2ccccc2)c1'],0.014,,
# ['CCCCCCCCCCCCCCCCCCCl'],0.011,,
# ['O=C(CC(C(=O)OC1CCCCC1)S(=O)(=O)[O-])OC1CCCCC1'],0.009,,
# ['CC/C(C)=N/O[Si](C)(O/N=C(\\C)CC)O/N=C(\\C)CC'],0.003,,
# ['CC(C)(C)C(=O)C(Cl)Cl'],0.003,,
# ['CCCOc1nn(C(=O)[N-]S(=O)(=O)c2ccccc2C(=O)OC)c(=O)n1C'],0.008,,
# ['CCCCCCC(CCCCCCCCCCC(=O)OCC(COC(C)=O)OC(C)=O)OC(C)=O'],0.021,,
# ['CC(C)CCCCCCOC(=O)C1CCCCC1C(=O)OCCCCCCC(C)C'],0.010,,
# ['c1ccc2cnccc2c1'],0.004,,
# ['C=CC(C)(CCC=C(C)C)OC=O'],0.006,,
# ['Cc1nc(-c2ccccn2)ncc1C(=O)Nn1cc(C)c2cc(F)ccc21'],0.024,,
# ['CCCCCCCCCCCCOC(C)=O'],0.015,,
# ['CC1C(C)(C)C2=C(C(=O)CCC2)C1(C)C'],0.001,,
# ['CC(=O)OCCCc1ccccc1'],0.015,,
# ['COc1ccc(COC=O)cc1'],0.008,,
# ['Oc1ccc(Cl)c2c1CCC2'],0.033,,
# ['CC(C)=CCC/C(C)=C/CC/C(C)=C/CO'],0.008,,
# ['O=C(NC(=O)c1c(F)cccc1F)Nc1cc(Cl)c(Oc2ncc(C(F)(F)F)cc2Cl)c(Cl)c1'],0.032,,
# ['CC(C)OC(=O)C(O)(c1ccc(Cl)cc1)c1ccc(Cl)cc1'],0.016,,
# ['OC[C@H](O)[C@@H](O)[C@H](O[C@@H]1O[C@H](CO)[C@H](O)[C@H](O)[C@H]1O)[C@H](O)CO'],0.030,,
# ['FC1(F)C(F)(F)C(F)(F)C2(F)C(F)(C1(F)F)C(F)(F)C(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C12F'],0.000,,
# ['CC1(C)O[C@@H]2CO[C@@]3(COS(N)(=O)=O)OC(C)(C)O[C@H]3[C@@H]2O1'],0.001,,
# ['CC(C)CC(C)CC(C)CC(C)COC(=O)c1ccccc1C(=O)OCC(C)CC(C)CC(C)CC(C)C'],0.004,,
# ['F[B-](F)(F)F'],0.045,,
# ['c1ccc2sc(SN3CCOCC3)nc2c1'],0.007,,
# ['CC(C)(C)NCC(O)c1cc(Cl)c(N)c(Cl)c1'],0.026,,
# ['C=C(Nc1ccc(OCC)cc1)Nc1ccc(OCC)cc1'],0.051,,
# ['C[N+]12CCC(CC1)C(OC(=O)C(O)(c1ccccc1)c1ccccc1)C2'],0.021,,
# ['Oc1c(I)cc(Cl)c2cccnc12'],0.017,,
# ['CC(C)/N=c1/cc2n(-c3ccc(Cl)cc3)c3ccccc3nc-2cc1Nc1ccc(Cl)cc1'],0.038,,
# ['C=CCOC(=O)CCCCCC'],0.010,,
# ['O=C(Nc1cccc(C(F)(F)F)c1)c1cc(Br)cc(Br)c1O'],0.023,,
# ['COc1cc(C(=O)NCCCCCC(=O)O)cc(OC)c1OC'],0.019,,
# ['O=S(=O)(Cl)Cl'],0.004,,
# ['C=C(Cl)CSC(=S)N(CC)CC'],0.001,,
# ['OC[C@H]1O[C@H](O[C@]2(CO)O[C@H](CO)[C@@H](O)[C@@H]2O)[C@H](O)[C@@H](O)[C@@H]1O'],0.044,,
# ['O=S(=O)([O-])[S-]'],0.000,,
# ['CC(=O)NS(=O)(=O)c1ccc(N)cc1'],0.011,,
# ['C=C1C(C)(C)[C@@]2(Cl)C(Cl)[C@]1(Cl)C(Cl)(Cl)C2(Cl)Cl'],0.000,,
# ['CN(N=O)C(=O)N[C@H]1[C@@H](O)O[C@H](CO)[C@@H](O)[C@@H]1O'],0.077,,
# ['O=C1CCC(=O)O1'],0.004,,
# ['c1ccc(C2CO2)cc1'],0.004,,
# ['Nc1ccc(S(=O)(=O)Nc2nccs2)cc1'],0.010,,
# ['C=Cc1ccccc1'],0.014,,
# ['Cc1cc(=O)oc2cc(O)ccc12'],0.058,,
# ['C=CC(C)=O'],0.003,,
# ['CC(CCc1ccc(O)cc1)NCCc1ccc(O)c(O)c1'],0.024,,
# ['CCCCC(CC)COC(=O)CC(C(=O)OCC(CC)CCCC)S(=O)(=O)[O-]'],0.011,,
# ['CCCCCCOc1ccccc1C(N)=O'],0.015,,
# ['CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc([N+](=O)[O-])cc2)cc1'],0.019,,
# ['CC[C@@H](C(=O)[C@@H](C)[C@@H](O)[C@H](C)CCc1ccc(C)c(O)c1C(=O)[O-])[C@H]1O[C@](CC)([C@H]2CC[C@](O)(CC)[C@H](C)O2)C[C@@H]1C'],0.045,,
# ['O=C1C(O)=C(O)C(=O)C(O)=C1O'],0.008,,
# ['CCCC(=O)O[C@]1(C(=O)CO)CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3[C@@H](O)C[C@@]21C'],0.917,C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2[CH2:1]C[C:1][CH2:1]1,0.787
# ['CC(N)CCCC(C)(C)O'],0.006,,
# ['CCc1cn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)[nH]c1=O'],0.024,,
# ['COc1ccc(-c2cc(=O)c3c(O)cc(O[C@@H]4O[C@H](CO[C@@H]5O[C@@H](C)[C@H](O)[C@@H](O)[C@H]5O)[C@@H](O)[C@H](O)[C@H]4O)cc3o2)cc1O'],0.044,,
# ['CCc1cccc(O)c1'],0.010,,
# ['O=C(c1ccccc1)c1ccc(O)cc1'],0.045,,
# ['Oc1ccc(C(=C(Cl)Cl)c2ccc(O)cc2)cc1'],0.010,,
# ['O=C(O)/C=C/c1ccccc1'],0.035,,
# ['O=C(NCCN1CCOCC1)c1ccc(Cl)cc1'],0.029,,
# ['CCCCCCCCCCCCOCCCN'],0.014,,
# ['CCc1cccc(CC)c1NC(=O)CN(CC(=O)O)CC(=O)O'],0.019,,
# ['COc1ccc(C(=O)CCC(=O)O)c2ccccc12'],0.040,,
# ['O=C(OCCO)c1ccccc1O'],0.011,,
# ['O=C([O-])CC(S[Au])C(=O)[O-]'],0.001,,
# [18:49:22] Aromatic bonds on non aromatic atom 14
# [18:49:22] Aromatic bonds on non aromatic atom 13
# [18:49:22] Aromatic bonds on non aromatic atom 12
# [18:49:23] Aromatic bonds on non aromatic atom 11
# [18:49:23] Aromatic bonds on non aromatic atom 10
# [18:49:23] Aromatic bonds on non aromatic atom 9
# [18:49:23] Aromatic bonds on non aromatic atom 9
# [18:49:24] Aromatic bonds on non aromatic atom 6
# [18:49:25] Aromatic bonds on non aromatic atom 13
# [18:49:25] Aromatic bonds on non aromatic atom 12
# [18:49:25] Aromatic bonds on non aromatic atom 11
# [18:49:25] Aromatic bonds on non aromatic atom 12
# [18:49:25] Aromatic bonds on non aromatic atom 10
# [18:49:25] Aromatic bonds on non aromatic atom 11
# [18:49:26] Aromatic bonds on non aromatic atom 9
# [18:49:26] Aromatic bonds on non aromatic atom 10
# [18:49:27] Aromatic bonds on non aromatic atom 13
# [18:49:27] Aromatic bonds on non aromatic atom 13
# [18:49:27] Aromatic bonds on non aromatic atom 14
# [18:49:27] Aromatic bonds on non aromatic atom 12
# [18:49:27] Aromatic bonds on non aromatic atom 12
# [18:49:27] Aromatic bonds on non aromatic atom 13
# [18:49:27] Aromatic bonds on non aromatic atom 11
# [18:49:27] Aromatic bonds on non aromatic atom 12
# [18:49:29] Aromatic bonds on non aromatic atom 12
# [18:49:29] Aromatic bonds on non aromatic atom 12
# [18:49:29] Aromatic bonds on non aromatic atom 11
# [18:49:30] Aromatic bonds on non aromatic atom 10
# [18:49:30] Aromatic bonds on non aromatic atom 9
# [18:49:30] Aromatic bonds on non aromatic atom 6
# [18:49:31] Aromatic bonds on non aromatic atom 6
# [18:49:31] Aromatic bonds on non aromatic atom 5
# [18:49:31] Aromatic bonds on non aromatic atom 14
# [18:49:31] Aromatic bonds on non aromatic atom 13
# [18:49:31] Aromatic bonds on non aromatic atom 12
# [18:49:32] Aromatic bonds on non aromatic atom 11
# [18:49:32] Aromatic bonds on non aromatic atom 10
# [18:49:32] Aromatic bonds on non aromatic atom 9
# [18:49:33] Aromatic bonds on non aromatic atom 12
# [18:49:33] Aromatic bonds on non aromatic atom 12
# [18:49:33] Aromatic bonds on non aromatic atom 13
# [18:49:34] Aromatic bonds on non aromatic atom 12
# [18:49:34] Aromatic bonds on non aromatic atom 9
# [18:49:36] Aromatic bonds on non aromatic atom 11
# [18:49:36] Aromatic bonds on non aromatic atom 12
# [18:49:37] Aromatic bonds on non aromatic atom 13
# [18:49:37] Aromatic bonds on non aromatic atom 11
# [18:49:38] Aromatic bonds on non aromatic atom 13
# [18:49:38] Aromatic bonds on non aromatic atom 12
# [18:49:38] Aromatic bonds on non aromatic atom 12
# [18:49:39] Aromatic bonds on non aromatic atom 12
# [18:49:39] Aromatic bonds on non aromatic atom 13
# [18:49:41] Aromatic bonds on non aromatic atom 10
# [18:49:41] Aromatic bonds on non aromatic atom 11
# [18:49:41] Aromatic bonds on non aromatic atom 9
# [18:49:41] Aromatic bonds on non aromatic atom 13
# [18:49:41] Aromatic bonds on non aromatic atom 13
# [18:49:42] Aromatic bonds on non aromatic atom 13
# [18:49:42] Aromatic bonds on non aromatic atom 5
# [18:49:43] Aromatic bonds on non aromatic atom 5
# [18:49:43] Aromatic bonds on non aromatic atom 12
# [18:49:43] Aromatic bonds on non aromatic atom 13
# [18:49:44] Aromatic bonds on non aromatic atom 12
# [18:49:44] Aromatic bonds on non aromatic atom 11
# ['CCC(=O)O[C@H]1CC[C@H]2[C@@H]3CCc4cc(O)ccc4[C@H]3CC[C@]12C'],0.566,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1CC[C@@H]2[OH:1],0.683
# ['O=C(O)c1cc2ccccc2c(Cc2c(O)c(C(=O)O)cc3ccccc23)c1O'],0.056,,
# ['CCOc1ccc(C[C@H]2NC(=O)CCSSC[C@@H](C(=O)N3CCC[C@H]3C(=O)N[C@@H](CCCN)C(=O)NCC(N)=O)NC(=O)[C@H](CC(N)=O)NC(=O)[C@H]([C@@H](C)O)NC(=O)[C@H]([C@@H](C)CC)NC2=O)cc1'],0.040,,
# ['CCCC1([C@H](O)C/C=C/[C@H]2[C@H](O)CC(=O)[C@@H]2CCCCCCC(=O)OC)CCC1'],0.035,,
# ['CSCC[C@H](NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)CCNC(=O)OC(C)(C)C)C(=O)N[C@@H](CC(=O)O)C(=O)N[C@@H](Cc1ccccc1)C(N)=O'],0.030,,
# ['O=C1c2ccccc2C(=O)C1c1ccc(Br)cc1'],0.013,,
# ['C1CNCCN1.C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](C[C@H](O)[C@@]21C)[C@@]1(C)CC[C@@H](O)C[C@H]1C[C@H]3O'],0.115,,
# ['CN1[C@H]2CC[C@@H]1C[C@H](OC(c1ccccc1)c1ccccc1)C2'],0.015,,
# ['CC(C)(C)c1ccc(CN2CCN(C(c3ccccc3)c3ccc(Cl)cc3)CC2)cc1'],0.006,,
# ['OC(CCN1CCCCC1)(c1ccccc1)c1ccccc1'],0.018,,
# ['O=C(O)CCc1nc2ccccc2[nH]1'],0.022,,
# ['CN1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn(CCF)c3c2F)CC1'],0.069,,
# ['CC(C)=O'],0.007,,
# ['NC(=O)[C@@H]1CCCN1C(=O)[C@H](Cc1cnc[nH]1)NC(=O)[C@@H]1CCC(=O)N1'],0.045,,
# [18:49:49] Aromatic bonds on non aromatic atom 20
# [18:49:49] Can't kekulize mol.  Unkekulized atoms: 17 18 19 20 22
#
# [18:49:49] Aromatic bonds on non aromatic atom 19
# [18:49:49] Can't kekulize mol.  Unkekulized atoms: 26 27 28 29 31
#
# [18:49:49] Aromatic bonds on non aromatic atom 18
# [18:49:49] Can't kekulize mol.  Unkekulized atoms: 25 26 27 28 30
#
# [18:49:50] Aromatic bonds on non aromatic atom 18
# [18:49:50] Can't kekulize mol.  Unkekulized atoms: 25 26 27 28 30
#
# [18:49:50] Aromatic bonds on non aromatic atom 18
# [18:49:50] Can't kekulize mol.  Unkekulized atoms: 17 18 19 20 22
#
# [18:49:50] Aromatic bonds on non aromatic atom 18
# [18:49:50] Can't kekulize mol.  Unkekulized atoms: 18 19 20 21 23
#
# [18:49:50] Aromatic bonds on non aromatic atom 18
# [18:49:50] Can't kekulize mol.  Unkekulized atoms: 17 18 19 20 22
#
# [18:49:51] Aromatic bonds on non aromatic atom 18
# [18:49:51] Can't kekulize mol.  Unkekulized atoms: 10 11 12 13 15
#
# [18:49:51] Aromatic bonds on non aromatic atom 16
# [18:49:51] Can't kekulize mol.  Unkekulized atoms: 10 11 12 13 15
#
# [18:49:51] Aromatic bonds on non aromatic atom 15
# [18:49:51] Can't kekulize mol.  Unkekulized atoms: 10 11 12 13 15
#
# [18:49:51] Aromatic bonds on non aromatic atom 14
# ...
# [20:09:41] Aromatic bonds on non aromatic atom 0
# [20:09:41] Aromatic bonds on non aromatic atom 0
# [20:09:44] Aromatic bonds on non aromatic atom 0
# [20:09:44] Aromatic bonds on non aromatic atom 0
# [20:09:44] Aromatic bonds on non aromatic atom 0
# [20:09:45] Aromatic bonds on non aromatic atom 0
# [20:09:45] Aromatic bonds on non aromatic atom 0
# [20:09:45] Aromatic bonds on non aromatic atom 0
# [20:09:45] Aromatic bonds on non aromatic atom 0
# [20:09:45] Aromatic bonds on non aromatic atom 0
# [20:09:45] Aromatic bonds on non aromatic atom 0
# [20:09:48] Aromatic bonds on non aromatic atom 0
# [20:09:48] Aromatic bonds on non aromatic atom 0
# [20:09:48] Aromatic bonds on non aromatic atom 0
# [20:09:49] Aromatic bonds on non aromatic atom 0
# [20:09:49] Aromatic bonds on non aromatic atom 0
# [20:09:49] Aromatic bonds on non aromatic atom 0
# [20:09:50] Aromatic bonds on non aromatic atom 0
# [20:09:50] Aromatic bonds on non aromatic atom 0
# [20:09:50] Aromatic bonds on non aromatic atom 5
# [20:09:50] Aromatic bonds on non aromatic atom 4
# [20:09:52] Aromatic bonds on non aromatic atom 0
# [20:09:53] Aromatic bonds on non aromatic atom 0
# [20:09:53] Aromatic bonds on non aromatic atom 0
# [20:09:55] Aromatic bonds on non aromatic atom 0
# [20:09:56] Aromatic bonds on non aromatic atom 0
# [20:09:56] Aromatic bonds on non aromatic atom 0
# [20:09:56] Aromatic bonds on non aromatic atom 0
# [20:09:58] Aromatic bonds on non aromatic atom 0
# [20:10:01] Aromatic bonds on non aromatic atom 0
# [20:10:03] Aromatic bonds on non aromatic atom 0
# [20:10:03] Aromatic bonds on non aromatic atom 0
# [20:10:13] Aromatic bonds on non aromatic atom 0
# [20:10:16] Aromatic bonds on non aromatic atom 0
# ['CCC(=O)Oc1ccc2c(c1)CC[C@@H]1[C@@H]2CC[C@]2(C)[C@@H](OC(=O)CC)CC[C@@H]12'],0.637,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1CC[C@@H]2[OH:1],0.683
# ['CCN(CC)CCNC(=O)c1cc(S(C)(=O)=O)ccc1OC'],0.017,,
# ['FC(F)(F)c1ccccc1-n1ccnc1'],0.007,,
# ['N#CC(C#N)=Cc1cc(O)c(O)c(O)c1'],0.009,,
# ['N#CC(C#N)=Cc1ccc(O)c(O)c1'],0.014,,
# ['O=C(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.000,,
# ['O=C(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.001,,
# ['O=C(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.000,,
# ['O=C(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.000,,
# ['O=S(=O)(O)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.000,,
# ['COC(=O)[C@@H]1CC2=CC(=O)CC[C@]2(C)[C@@]23O[C@@H]2C[C@@]2(C)[C@@H](CC[C@@]24CCC(=O)O4)[C@H]13'],0.791,C[C@]12CC[CH2:1]C=C1C[CH2:1][C@@H]1[C@@]23O[C@@H]3C[C:1][CH2:1]1,0.511
# ['CC(C)CC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@@H](CC(C)C)[C@@H](O)CC(=O)N[C@@H](C)C(=O)N[C@@H](CC(C)C)[C@@H](O)CC(=O)O)C(C)C)C(C)C'],0.025,,
# ['CN(C)CCc1ccc(O)cc1'],0.009,,
# ['CC1(C)S[C@@H]2[C@H](N)C(=O)N2[C@H]1C(=O)O'],0.023,,
# ['c1cc2c(c(N3CCNCC3)c1)OCCO2'],0.017,,
# ['CC1(CN2CCC(n3c(=O)[nH]c4ccccc43)CC2)OCc2ccccc2-n2cccc21'],0.015,,
# ['CN1C(=O)[C@@H](NC(=O)c2cc3ccccc3[nH]2)N=C(c2ccccc2)c2ccccc21'],0.043,,
# ['O=c1[nH]c2cc(C(F)(F)F)c(N3CCOCC3)cc2n(CP(=O)(O)O)c1=O'],0.035,,
# ['COC1=CC=C2[C@H]3Cc4ccc(OC)c5c4[C@@]2(CCN3C)[C@H]1O5'],0.020,,
# ['FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F'],0.000,,
# ['Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1'],0.002,,
# ['CC(=O)Nc1ccc(S(=O)(=O)Cl)cc1'],0.016,,
# ['Cc1ccc([N+](=O)[O-])cc1Cl'],0.011,,
# ['COCC(=O)Nc1cc(Sc2ccccc2)ccc1N=C(NC(=O)OC)NC(=O)OC'],0.043,,
# ['CC(C)[C@@]1(NC(=O)[C@@H]2C[C@@H]3c4cccc5[nH]cc(c45)C[C@H]3N(C)C2)O[C@@]2(O)[C@@H]3CCCN3C(=O)[C@H](Cc3ccccc3)N2C1=O'],0.030,,
# ['C[C@@H](CO)NC(=O)[C@@H]1C=C2c3cccc4[nH]cc(c34)C[C@H]2N(C)C1'],0.033,,
# ['CCN(CC)C(=O)N[C@@H]1C=C2c3cccc4[nH]cc(c34)C[C@@H]2N(C)C1'],0.026,,
# ['C=CCN1CCc2nc(N)sc2CC1'],0.012,,
# ['CN(C(=O)Cc1ccccc1)[C@H]1CC[C@@]2(CCCO2)C[C@@H]1N1CCCC1'],0.017,,
# ['CN1C[C@@H](NS(=O)(=O)N(C)C)C[C@@H]2c3cccc4c3c(cn4C)C[C@H]21'],0.022,,
# ['C=CCN1CC[C@]23c4c5ccc(O)c4O[C@H]2C(=O)CC[C@@]3(O)[C@H]1C5.CI'],0.143,,
# ['CC(C)(C)NSc1nc2ccccc2s1'],0.005,,
# ['C=CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O'],0.005,,
# ['CC1=CC(=O)CCC1'],0.020,,
# ['CC(C)c1ccccc1C(C)C'],0.001,,
# ['O=C=NC1CCC(CC2CCC(N=C=O)CC2)CC1'],0.015,,
# ['CCCCOCC(C)O'],0.012,,
# ['C=C(C)C(=O)OCC[N+](C)(C)C'],0.002,,
# ['c1ccc2sc(SN(C3CCCCC3)C3CCCCC3)nc2c1'],0.007,,
# ['CC(C)C(=O)OCC(C)(C)C(O)C(C)C'],0.010,,
# ['Cc1cccc(Cl)c1'],0.006,,
# ['C1=CCCC=CCCC=CCC1'],0.003,,
# ['C=C(C)C#N'],0.002,,
# ['COP(N)(=O)SC'],0.002,,
# ['CCCCSP(=O)(SCCCC)SCCCC'],0.001,,
# ['COCC(=O)N(c1c(C)cccc1C)C(C)C(=O)OC'],0.014,,
# ['C[N+]1(C)CCCCC1'],0.001,,
# ['Cn1cc(C2=C(c3cn(C4CCN(Cc5ccccn5)CC4)c4ccccc34)C(=O)NC2=O)c2ccccc21'],0.014,,
# ['O=C(NOC[C@H](O)CO)c1ccc(F)c(F)c1Nc1ccc(I)cc1F'],0.043,,
# ['O=C1CN=C(c2ccccc2)c2cc(Cl)ccc2N1CC1CC1'],0.021,,
# ['Nc1c(Cl)c(Cl)c(Cl)c(Cl)c1Cl'],0.082,,
# ['CCOC(=O)CCC(C)=O'],0.012,,
# ['C[C@]12C[C@H](O)[C@H]3[C@@H](CCC4=CC(=O)C=C[C@@]43C)[C@@H]1CC[C@]2(O)C(=O)CO'],0.990,C[C@]12C=CC(=O)C=C1CC[CH2:1][CH2:1]2,0.680
# ['C[C@]12CC(=O)[C@H]3[C@@H](CCC4=CC(=O)C=C[C@@]43C)[C@@H]1CC[C@]2(O)C(=O)CO'],0.981,C[C@]12C=CC(=O)C=C1CC[CH2:1][CH2:1]2,0.680
# ['CNC(=O)CSP(=O)(OC)OC'],0.003,,
# ['CCCN(CCC)S(=O)(=O)c1ccc(C(=O)O)cc1'],0.014,,
# ['C=C(C)[C@@H]1CCC2=CCC[C@@H](C)[C@]2(C)C1'],0.051,,
# ['C=CC(C)=CCC=C(C)C'],0.005,,
# ['C=C(C)[C@@H]1CCC2=CC(=O)C[C@@H](C)[C@]2(C)C1'],0.084,,
# ['CCOC(=O)CC(C)C'],0.003,,
# ['CCCCCCCCCCCCN(CCCCCCCCCCCC)CCCCCCCCCCCC'],0.011,,
# ['CC1=CCCC(C)(C)C12CCC(C)O2'],0.002,,
# ['c1cc(C(c2ccc(OCC3CO3)cc2)c2ccc(OCC3CO3)cc2)ccc1OCC1CO1'],0.008,,
# ['CC1(CO)CN(c2ccccc2)NC1=O'],0.022,,
# ['C=C(C)C(=O)OCCCCCCCCCCOC(=O)C(=C)C'],0.010,,
# ['CCC(=O)OCc1ccccc1'],0.012,,
# ['Cc1cccc(Nc2ccccc2)c1'],0.036,,
# ['O=S(=O)([O-])CC(O)CCl'],0.005,,
# ['C=CCOCC(CC)(CO)COCC=C'],0.004,,
# ['NS(=O)(=O)c1ccccc1Cl'],0.010,,
# ['CCC(C)(CCC(C)C)C(=O)O[Sn](C)(C)OC(=O)C(C)(CC)CCC(C)C'],0.001,,
# ['CC(C)(C)C1CCCCC1O'],0.001,,
# ['CC(C)CP(=S)([S-])CC(C)C'],0.000,,
# ['COc1ccc(CC2c3cc(OC)c(OC)cc3CC[N+]2(C)CCC(=O)OCCCCCOC(=O)CC[N+]2(C)CCc3cc(OC)c(OC)cc3C2Cc2ccc(OC)c(OC)c2)cc1OC.O=S(=O)([O-])c1ccccc1.O=S(=O)([O-])c1ccccc1'],0.007,,
# ['CCOc1c(N2CCOCC2)cnn(C)c1=O'],0.005,,
# ['CN1CCC(=C2c3ccccc3CCc3cccnc32)CC1'],0.017,,
# ['CC(=O)OC[C@H]1O[C@@H](n2ncc(=O)[nH]c2=O)[C@H](OC(C)=O)[C@@H]1OC(C)=O'],0.026,,
# ['CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N1CCC[C@H]1C(=O)O'],0.038,,
# ['CN(C)C(=O)Nc1ccc(Cl)cc1'],0.023,,
# ['Cc1ccc(S(=O)(=O)N=C=O)cc1'],0.006,,
# ['NC(=O)c1ccccc1O'],0.019,,
# ['O=C1C[C@@H]2OCC=C3CN4CC[C@]56c7ccccc7N1[C@H]5[C@H]2[C@H]3C[C@H]46.O=C1C[C@@H]2OCC=C3CN4CC[C@]56c7ccccc7N1[C@H]5[C@H]2[C@H]3C[C@H]46'],0.071,,
# ['O=c1oc2ccccc2c(O)c1Cc1c(O)c2ccccc2oc1=O'],0.044,,
# ['O=C1NCC2(CCN(CCc3ccccc3)CC2)O1'],0.016,,
# ['CCOC(=O)Nc1ccc(NCc2ccc(F)cc2)nc1N'],0.064,,
# ['CC(C)[N+]1(C)C2CCC1CC(OC(=O)C(CO)c1ccccc1)C2'],0.013,,
# ['N=C(N)NCc1cccc(I)c1.N=C(N)NCc1cccc(I)c1'],0.015,,
# ['CC(C)NC(C)Cc1ccc(I)cc1'],0.014,,
# ['Clc1cc(C(Cl)(Cl)Cl)cnc1Cl'],0.005,,
# ['Cc1cn[nH]c1'],0.001,,
# ['NC(=O)c1ncn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c1O'],0.055,,
# ['C#CCN(C)CCCOc1ccc(Cl)cc1Cl'],0.015,,
# ['CCCCCCCCCCCC#N'],0.009,,
# ['N#Cc1c(Cl)c(Cl)c(Cl)c(C#N)c1Cl'],0.028,,
# ['Cc1ccc(C)c(O)c1C'],0.009,,
# ['C=C(C)C(=O)OCCOCC'],0.008,,
# ['CC(C)[C@@H]1CC[C@@H](C)C[C@H]1O'],0.008,,
# ['O=C=Nc1ccc(Cl)c(Cl)c1'],0.033,,
# ['COP(=S)(OC)Oc1nc(Cl)c(Cl)cc1Cl'],0.004,,
# ['C#CCOC(=O)[C@@H](C)Oc1ccc(Oc2ncc(Cl)cc2F)cc1'],0.015,,
# ['CC1(C)CON(Cc2ccccc2Cl)C1=O'],0.008,,
# ['CCSC(=O)N(CC)C1CCCCC1'],0.007,,
# ['COC(=O)C(C)Oc1ccc(Oc2ccc(Cl)cc2Cl)cc1'],0.019,,
# ['CCNC(=O)NC(=O)/C(C#N)=N/OC'],0.016,,
# ['Cc1cc(C2CC2)nc(Nc2ccccc2)n1'],0.037,,
# ['COc1cc2nc(N(C)CCCNC(=O)C3CCCO3)nc(N)c2cc1OC'],0.017,,
# ['CN(C)C(=O)Oc1cc(OC(=O)N(C)C)cc(C(O)CNC(C)(C)C)c1'],0.035,,
# ['CCC(=O)O[C@]1(C(=O)SCF)[C@H](C)C[C@H]2C3C[C@H](F)C4=CC(=O)C=C[C@]4(C)[C@@]3(F)[C@@H](O)C[C@@]21C'],0.925,C[C@]12C=CC(=O)C=C1[CH2:1]C[CH2:1][C:1]2,0.608
# ['C[C@@]12CCC[C@H]1[C@@H]1CC[C@H]3C[C@@H](O)CC[C@]3(C)[C@H]1CC2'],0.053,,
# ['CC(=O)SC[C@@H](Cc1ccccc1)C(=O)NCC(=O)OCc1ccccc1'],0.019,,
# ['CCCN1CCC[C@@H]2Cc3n[nH]cc3C[C@H]21'],0.011,,
# ['CCC[C@@]1(CCc2ccccc2)CC(O)=C([C@H](CC)c2cccc(NS(=O)(=O)c3ccc(C(F)(F)F)cn3)c2)C(=O)O1'],0.011,,
# ['CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(=O)N2CCCC[C@H]2C(=O)O[C@H]([C@H](C)C[C@@H]2CC[C@@H](O)[C@H](OC)C2)CC(=O)[C@H](C)C=C(C)[C@@H](O)[C@@H](OC)C(=O)[C@H](C)C[C@H](C)C=CC=CC=C1C'],0.043,,
# ['CCC(C)(C)C(=O)O[C@H]1C[C@@H](C)C=C2C=C[C@H](C)[C@H](CC[C@@H]3C[C@@H](O)CC(=O)O3)[C@H]21'],0.083,,
# ['CC(C)=CCOc1ccc(/C=C/C(=O)c2ccc(OCC=C(C)C)cc2OCC(=O)O)cc1'],0.036,,
# ['O=C1NC(=O)[C@@]2(CCOc3ccc(F)cc32)N1'],0.014,,
# ['C/C=C(/CC[C@@H](C)[C@H]1CC[C@H]2C3=CC[C@H]4[C@H](C)[C@@H](O)CC[C@]4(C)[C@H]3CC[C@@]21C)C(C)C'],0.041,,
# ['OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO'],0.010,,
# ['CCCCCCCCCCCCOS(=O)(=O)O.OCCN(CCO)CCO'],0.015,,
# ['[O-]c1ccccc1'],0.007,,
# ['c1ccc2c(c1)c1cccc3ccc4cccc2c4c31'],0.042,,
# ['C=CCNCC=C'],0.009,,
# ['CCCCC/C=C/C=C/C=O'],0.022,,
# ['C1CCC2CCCCC2C1'],0.002,,
# ['CCCCCCCCCC'],0.006,,
# ['C=C(C)C(=O)OCCCCCCCCCC'],0.009,,
# ['C=CC(=O)NC(C)(C)CC(C)=O'],0.005,,
# ['CC(=O)CC(C)(C)O'],0.003,,
# ['CN(C)C(=O)C1(N2CCCCC2)CCN(CCC2(c3ccc(Cl)c(Cl)c3)CN(C(=O)c3ccccc3)CCO2)CC1'],0.018,,
# ['O=C([O-])C(Cl)Cl'],0.003,,
# ['O=C([O-])Cc1ccccc1Nc1c(Cl)cccc1Cl'],0.028,,
# ['Clc1cc(Cl)c(Cl)nc1Cl'],0.019,,
# ['NNC(=S)NN'],0.003,,
# ['NC(=O)Nc1ccc(Cl)cc1'],0.035,,
# ['[O-][n+]1ccc(Cl)cc1'],0.016,,
# ['CCCCC/C=C\\CCC=O'],0.009,,
# ['CN1C(=O)CC(=O)N(c2ccccc2)c2cc(Cl)ccc21'],0.024,,
# ['CCc1occc(=O)c1O'],0.008,,
# ['CC1=C(O)C(=O)C(C)O1'],0.007,,
# ['COc1ccc(CCO)cc1'],0.009,,
# ['CCCC(C)C(O)CC'],0.007,,
# ['Oc1ccc(/C=C/c2cc(O)cc(O)c2)cc1'],0.070,,
# ['O=C1C[N+]([O-])=C(c2ccccc2)c2cc(Cl)ccc2N1'],0.021,,
# ['O=C(/C=C/c1cccc(F)c1)NC1CC1'],0.069,,
# ['O=C(O)Cc1csc(-c2ccc(Cl)cc2)n1'],0.039,,
# ['O=C(Nc1ccc(Br)cc1)c1cc(Br)c(Br)s1'],0.040,,
# ['O=C(O)Cc1cn(-c2ccccc2)nc1-c1ccc(Cl)cc1'],0.033,,
# ['Cc1cccc(C)c1NC(=O)CN1CCCC1'],0.016,,
# ['NS(=O)(=O)c1ccc(Cl)c(S(N)(=O)=O)c1'],0.008,,
# ['COc1ccc(C=CC(=O)c2ccc(OC)cc2OC)cc1'],0.031,,
# ['O=C(NCN1CCOCC1)c1cnccn1'],0.005,,
# ['COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)C[C@@H]3O[C@H]1C[C@H](N)[C@H](O[C@@H]2CCCCO2)[C@H](C)O1'],0.085,,
# ['CCCCCCC(=O)O[C@H]1CC[C@H]2[C@@H]3CC[C@H]4CC(=O)C=C(C)[C@]4(C)[C@H]3CC[C@]12C'],0.527,C[C@]12CC[C@H]3[C@@H](CC[CH2:1][C:1]3)[C@@H]1CC[C@@H]2[OH:1],0.666
# ['C=C/C(C)=C/C/C=C(\\C)CCC=C(C)C'],0.004,,
# ['CCC(=O)OCCOc1ccccc1'],0.015,,
# ['CC(=O)CCC1=C(C)CCCC1(C)C'],0.005,,
# ['COc1cc(C=O)ccc1OC(=O)C(C)C'],0.020,,
# ['CN1N=C(C(N)=O)CCC1=O'],0.012,,
# ['C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@@]43C)[C@@H]1CC[C@@H]2C(=O)O'],0.897,C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2CC[C:1][CH2:1]1,0.787
# ['Cc1sccc1Br'],0.011,,
# ['O=C(CCCl)NCCc1ccccc1'],0.030,,
# ['[O-][n+]1cccc(/C(Cl)=N/OC[C@H](O)CN2CCCCC2)c1'],0.019,,
# ['CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2c-1nc1ccccc1c2/C=N/OC(C)(C)C'],0.022,,
# ['C=CCNc1nc(NCC=C)nc(N2CCN(C(c3ccc(F)cc3)c3ccc(F)cc3)CC2)n1'],0.019,,
# ['CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c([N+](=O)[O-])cccc3nc2-1'],0.053,,
# ['CCCCCCCCCCCCCCOS(=O)(=O)[O-]'],0.009,,
# ['S=c1[nH]c2ccccc2[nH]1'],0.041,,
# ['CC(=O)N[C@@H]1C(O[C@H]2O[C@H](C(=O)O)C(O)[C@H](O)[C@H]2O)[C@H](O)[C@@H](CO)O[C@H]1O[C@@H]1C(C(=O)O)O[C@@H](O[C@H]2[C@H](O)[C@@H](CO)OC(O)[C@@H]2NC(C)=O)[C@H](O)[C@H]1O'],0.045,,
# ['S=C1NC=NC2N=CNC12'],0.015,,
# ['CCCCCCOC(=O)CCCCC(=O)OCCCCCC'],0.017,,
# ['CCCCCCCCCC(=O)OC'],0.010,,
# ['OC/C=C/CO'],0.004,,
# ['Cc1c(Cl)cccc1Nc1ncccc1C(=O)O'],0.037,,
# ['OCc1c[nH]c2ccccc12'],0.015,,
# ['Cc1cccc(Nc2cc(Cl)nc(SCC(=O)O)n2)c1C'],0.029,,
# ['CNCC(O)c1ccc(O)cc1'],0.021,,
# ['O=CCCl'],0.016,,
# ['O=C(CCl)c1ccccc1'],0.017,,
# ['COP(=S)(OC)Oc1ccc([N+](=O)[O-])cc1Cl'],0.005,,
# ['COC(=O)c1ccccc1C(=O)O'],0.009,,
# ['CC(=O)Nc1ccc(C(=O)CCl)cc1'],0.071,,
# ['CCCCOC(=O)c1ccccc1C(=O)O'],0.014,,
# ['Nc1ccc(Cl)cc1'],0.012,,
# ['c1ccc(CCCc2ccccn2)cc1'],0.011,,
# ['CCOC(=O)c1cn2nc(OP(=S)(OCC)OCC)cc2nc1C'],0.008,,
# ['CCC(C)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1OC(=O)C=C(C)C'],0.007,,
# ['CCC(C)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1OC(=O)OC(C)C'],0.006,,
# ['CCN(CC)c1c([N+](=O)[O-])cc(C(F)(F)F)c(N)c1[N+](=O)[O-]'],0.011,,
# ['CC1(C)[C@@H]2CC[C@@]1(C)[C@H](OC(=O)CSC#N)C2'],0.002,,
# ['CC(C)N(C(=O)SCC(Cl)=CCl)C(C)C'],0.002,,
# ['CC(=O)OCC1=C(C(=O)O)N2C(=O)[C@@H](N)[C@H]2SC1'],0.012,,
# ['COC(=O)Nc1nc2ccccc2[nH]1'],0.056,,
# ['O=C1CCCCC1Cl'],0.022,,
# ['CC1(C)[C@@H]2CC[C@@]1(C)C(=O)C2'],0.005,,
# ['NC(N)=O.OO'],0.001,,
# ['CCCCCCCC(=O)Cl'],0.015,,
# ['CCCCCOC(C)=O'],0.010,,
# ['CCCCCCCCCCCCCC'],0.008,,
# ['CCCCCCCCCCCCC'],0.008,,
# ['OCCCCCCO'],0.007,,
# ['C=CCCCCCCCCCCCCCC'],0.009,,
# ['CCCCCCCCCCCCCCC'],0.008,,
# ['CSc1ccc(Cl)cc1'],0.003,,
# ['Clc1ccc2ccccc2c1'],0.014,,
# ['Cc1ccccc1Cl'],0.006,,
# ['CS(=O)(=O)c1ccc(Cl)cc1'],0.004,,
# ['Oc1ccc2ccc3cccc4ccc1c2c34'],0.054,,
# ['CC(C)COC(=O)c1ccc(O)cc1'],0.016,,
# ['Cn1c(N)nc2c3cccnc3ccc21'],0.019,,
# ['NC(=O)CI'],0.003,,
# ['IC(I)I'],0.003,,
# ['COc1ccc2c(c1)c(CC(=O)O)c(C)n2C(=O)c1ccc(Cl)cc1'],0.037,,
# ['C=CCOCC(CO)(COCC=C)COCC=C'],0.003,,
# ['CCc1ccc(O)c(C(C)(C)C)c1'],0.001,,
# ['Cc1c(C)c([N+](=O)[O-])c(C(C)(C)C)c([N+](=O)[O-])c1C'],0.002,,
# ['C#CCN(C)[C@H](C)Cc1ccccc1'],0.010,,
# ['O=C1CN(N=Cc2ccc(-c3ccc([N+](=O)[O-])cc3)o2)C(=O)[N-]1'],0.042,,
# ['CCN(CCC#N)c1ccccc1'],0.016,,
# ['COC(=O)CCCC(=O)O'],0.009,,
# ['OC[C@H](Cc1cccc(O)c1)[C@H](CO)Cc1cccc(O)c1'],0.017,,
# ['COc1cc(Cl)ccc1Oc1ccc(Cl)cc1Cl'],0.011,,
# ['Cc1ccc(O)c(C(=O)c2ccccc2)c1'],0.027,,
# ['O=C(c1ccccc1)c1cccc(O)c1'],0.041,,
# ['O=C(c1ccccc1)c1ccccc1O'],0.029,,
# ['CN1CCc2cc3c(cc2C1O)OCO3'],0.011,,
# ['CCCCCCCCCCCCOC(=O)c1ccc(O)cc1'],0.017,,
# ['O=C(Oc1ccccc1)c1ccc(O)cc1'],0.030,,
# ['CCCC(c1cc(C(C)(C)C)c(O)cc1C)c1cc(C(C)(C)C)c(O)cc1C'],0.001,,
# ['O=c1[nH]cnc2nc[nH]c12'],0.002,,
# ['C=C1CC[C@H]2[C@@](C)(CC[C@@H](O)[C@@]2(C)CO)[C@@H]1C/C=C1/C(=O)OC[C@H]1O'],0.037,,
# ['CN1CC(=O)NC1=N'],0.013,,
# ['CC1(C)O[C@H]2CC(=O)OC[C@@]23[C@H]1CC(=O)[C@]1(C)[C@@H]3CC[C@@]2(C)[C@H](c3ccoc3)OC(=O)[C@H]3O[C@]321'],0.068,,
# ['OC[C@H]1O[C@@H](O[C@@H]2[C@@H](CO)O[C@@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O'],0.038,,
# ['CN(C)CCN(Cc1ccccc1)c1ccccn1.O=C(O)CC(O)(CC(=O)O)C(=O)O'],0.017,,
# ['C=CCC1(C(C)CCC)C(=O)N=C([S-])NC1=O'],0.004,,
# ['Clc1ccccc1'],0.004,,
# ['CCOC(=O)C(O)(c1ccc(Cl)cc1)c1ccc(Cl)cc1'],0.023,,
# ['CCCCCCCCCCC[C@@H](C[C@@H]1OC(=O)[C@H]1CCCCCC)OC(=O)C(CC(C)C)NC=O'],0.016,,
# ['CCC1CO1'],0.003,,
# ['FC(F)OC(F)(F)C(F)Cl'],0.003,,
# ['C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C(CCC(=O)C4)[C@H]3CC[C@@]21C'],0.896,C#C[C@]1(O)CC[C@@H]2[C@]1(C)CC[CH2:1][CH2:1]2,0.682
# ['O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl'],0.000,,
# ['ClC1=C(Cl)[C@]2(Cl)[C@H]3[C@H]([C@@H]4C[C@H]3[C@H]3O[C@@H]43)[C@@]1(Cl)C2(Cl)Cl'],0.006,,
# ['ClCC1CO1'],0.002,,
# ['O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1cc(O)c(O)c(O)c1)c1cc(O)c(O)c(O)c1'],0.024,,
# ['CC(C)NCC1CCc2cc(CO)c([N+](=O)[O-])cc2N1'],0.038,,
# ['CCCn1cnc2c1c(=O)n(CCCCC(C)=O)c(=O)n2C'],0.015,,
# ['c1cnc(N2CCN(Cc3ccc4c(c3)OCO4)CC2)nc1'],0.004,,
# ['Cc1ccc(=O)n(-c2ccccc2)c1'],0.019,,
# ['Cc1nc2ccccn2c(=O)c1CCN1CCC(C(=O)c2ccc(F)cc2)CC1'],0.018,,
# ['O=c1[nH]c2ccccc2n1CCCN1CCN(C(c2ccccc2)c2ccccc2)CC1'],0.017,,
# ['NC(=O)CN1CC(O)CC1=O'],0.015,,
# ['CCC(=O)c1ccc2c(c1)N(CCCN(C)C)c1ccccc1S2'],0.019,,
# ['CCCn1c(=O)[nH]c(=O)c2[nH]cnc21'],0.007,,
# ['CCCNCC(O)COc1ccccc1C(=O)CCc1ccccc1'],0.032,,
# ['CCOc1nc2cccc(C(=O)O)c2n1Cc1ccc(-c2ccccc2-c2nnn[nH]2)cc1'],0.017,,
# ['CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C'],0.722,C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2CC[C:1][CH2:1]1,0.787
# ['C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@@]43C)[C@@H]1CC[C@@H]2O'],0.959,C[C@]12CC[C@H]3[C@@H](CC[CH2:1][C:1]3)[C@@H]1CC[C@@H]2O,0.666
# [20:18:55] Aromatic bonds on non aromatic atom 8
# [20:18:56] Aromatic bonds on non aromatic atom 7
# [20:18:56] Aromatic bonds on non aromatic atom 7
# [20:18:56] Aromatic bonds on non aromatic atom 7
# [20:18:57] Aromatic bonds on non aromatic atom 7
# [20:18:57] Aromatic bonds on non aromatic atom 8
# [20:18:59] Aromatic bonds on non aromatic atom 8
# [20:18:59] Aromatic bonds on non aromatic atom 7
# [20:18:59] Aromatic bonds on non aromatic atom 7
# [20:19:00] Aromatic bonds on non aromatic atom 4
# [20:19:00] Aromatic bonds on non aromatic atom 5
# [20:19:00] Aromatic bonds on non aromatic atom 7
# [20:19:01] Aromatic bonds on non aromatic atom 4
# [20:19:01] Aromatic bonds on non aromatic atom 6
# [20:19:01] Aromatic bonds on non aromatic atom 7
# [20:19:02] Aromatic bonds on non aromatic atom 7
# [20:19:02] Aromatic bonds on non aromatic atom 4
# ['C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C@H]2O'],0.768,C[C@]12CC[C@H]3[C@@H](CC[CH:1]=[CH:1]3)[C@@H]1CC[C@H]2O,0.582
# ['COc1ccc2c(c1OC)CN1CCc3cc4c(cc3C1C2)OCO4'],0.008,,
# Elapsed time = 2:47:57
