# %% [markdown]
# ## DEEPScreen: high performance drug–target interaction prediction with convolutional neural networks using 2-D structural compound representations
#
# ABSTRACT: The identification of physical interactions between drug candidate compounds and target biomolecules is
# an important process in drug discovery. Since conventional screening procedures are expensive and time
# consuming, computational approaches are employed to provide aid by automatically predicting novel
# drug–target interactions (DTIs). In this study, we propose a large-scale DTI prediction system,
# DEEPScreen, for early stage drug discovery, using deep convolutional neural networks. One of the main
# advantages of DEEPScreen is employing readily available 2-D structural representations of compounds at
# the input level instead of conventional descriptors that display limited performance. DEEPScreen learns
# complex features inherently from the 2-D representations, thus producing highly accurate predictions.
# The DEEPScreen system was trained for 704 target proteins (using curated bioactivity data) and finalized
# with rigorous hyper-parameter optimization tests. We compared the performance of DEEPScreen
# against the state-of-the-art on multiple benchmark datasets to indicate the effectiveness of the
# proposed approach and verified selected novel predictions through molecular docking analysis and
# literature-based validation. Finally, JAK proteins that were predicted by DEEPScreen as new targets of
# a well-known drug cladribine were experimentally demonstrated in vitro on cancer cells through STAT3
# phosphorylation, which is the downstream effector protein. The DEEPScreen system can be exploited in the fields of drug discovery and repurposing for in silico screening of the chemogenomic space, to
# provide novel DTIs which can be experimentally pursued.
#
# Link to paper: https://pubs.rsc.org/en/content/articlepdf/2020/sc/c9sc03414e
#
# Credit: https://github.com/cansyl/DEEPScreen
#
# Google Colab: https://colab.research.google.com/drive/1eW7ji8wxR2RChfP6hlcaJ0WL4EYYiYOD?usp=sharing

# %%
# Clone the repository and cd into directory
# !git clone https://github.com/cansyl/DEEPScreen.git
# %cd DEEPScreen/bin
# Out:
# /content/DEEPScreen/bin

# %%
# Install requirements / dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ### Descriptions of folders and files in the DEEPScreen repository
#
# * **bin** folder includes the source code of DEEPScreen.
#
# * **training_files** folder includes the files directly used in the training and testing of the system:
#     * **chembl27_preprocessed_filtered_bioactivity_dataset.tsv.zip** updated version of ChEMBL preprocessed and filtered dataset contains drug/compound-target interactions from the ChEMBL database (v27) after the application of multiple filtering operations to obtain a clean training set,
#     * **chembl27_training_target_list.txt** list of target chembl ids,
#     * **target_training_datasets** contains a folder (e.g. CHEMBL286) for each target where each target folder contains
#     	* a json file named  **train_val_test_dict.json** which includes train/validation/test compound ids,
#     	* a folder named **imgs** which holds images of compounds.
#
#     * **chembl27_preprocessed_filtered_act_inact_comps_10.0_20.0_blast_comp_0.2.txt** contains the active and inactive compound information for each target protein in ChEMBL, after the similarity-based negative training dataset enrichment process. In this file, there are two lines for each target, in the following format:
#
#         ```
#        CHEMBL286_act	CHEMBL1818056,CHEMBL2115367,CHEMBL344651,CHEMBL62054, ...
#        CHEMBL286_inact	CHEMBL288434,CHEMBL584926,CHEMBL406111,CHEMBL151055, ...
#        ```
#
#        The list of active/inactive compounds separated by commas (i.e., the second tab seperated column: *CHEMBL1818056,C...*) for the correnponding target (i.e., the first column: *CHEMBL286_act*),
#
#     * **chembl27_uniprot_mapping.txt** contains the id mapping between UniProt accessions and ChEMBL ids for proteins, in tab-separated format (Target UniProt accession, Target	ChEMBL id, Target protein name and Target type),
#
# * **result_files** folder contains results of various tests/analyses:
#
# * **2-D images of:**
#    - 409,311 ChEMBL compounds in the train/validation/test datasets of 812 target proteins of DEEPScreen can be downloaded from [here](https://drive.google.com/file/d/1E7ZpLN_fMdXmPJPP7WH3IPWPceleP_3a/view?usp=sharing)
#    - all compounds (~2M) in ChEMBL v27 can be downloaded from [here](https://drive.google.com/file/d/16T8NI1Umf8A0qeLu90Akbx3ic-vdAbUO/view?usp=sharing)
#    - all drugs (~11K) in DrugBank v5.1.7 can be downloaded from [here](https://drive.google.com/file/d/11vSqg1SgX7y25TbX4EzNOjWNkSFVZzek/view?usp=sharing)
#
# ### How to train DEEPScreen models and get performance results
#
# * Clone the Git Repository
#
# * Download the compressed file for the target  that you want to train  [here](https://www.dropbox.com/sh/as18uxmctnf39kc/AADUqZX3XAiQRU6UVp3SsBRXa?dl=0)
#
# * Locate the zipped target file under **training_files/target_training_datasets** and unzip it
#
# * Run the **main_training.py** script as shown below
#
# ### Explanation of Parameters
#
# * **--targetid**: Target to be trained (default: CHEMBL286)
#
# * **--model**: CNN architecture to be used (default: CNNModel1)
#
# * **--fc1**: number of neurons in the first fully-connected layer (default:512)
#
# * **--fc2**: number of neurons in the second fully-connected layer (default:256)
#
# * **--lr**:learning rate (default: 0.001)
#
# * **--bs**: batch size (default: 32)
#
# * **--dropout**: dropout rate (default: 0.1)
#
# * **--epoch**: number of epochs (default: 200)
#
# * **--en**: the name of the experiment (default: my_experiment)
#
# #### To perform training for a target (CHEMBL286 in the below example):

# %%
# !python main_training.py --targetid CHEMBL286 --model CNNModel1 --fc1 256 --fc2 128 --lr 0.01 --bs 64 --dropout 0.25 --epoch 100 --en my_chembl286_training
# Out:
# Namespace(bs=64, dropout=0.25, en='my_chembl286_training', epoch=100, fc1=256, fc2=128, lr=0.01, model='CNNModel1', targetid='CHEMBL286')
# Arguments: CHEMBL286-CNNModel1-256-128-0.01-64-0.25-100-my_chembl286_training
# GPU is available on this device!
# Epoch :0
# Training mode: True
# Epoch 0 training loss: 23.956565976142883
# Validation mode: True
# Epoch :1
# Training mode: True
# Epoch 1 training loss: 12.626873254776001
# Validation mode: True
# Epoch :2
# Training mode: True
# Epoch 2 training loss: 12.199288070201874
# Validation mode: True
# Epoch :3
# Training mode: True
# Epoch 3 training loss: 11.504060626029968
# Validation mode: True
# Epoch :4
# Training mode: True
# Epoch 4 training loss: 11.481438398361206
# Validation mode: True
# Epoch :5
# Training mode: True
# Epoch 5 training loss: 11.039315849542618
# Validation mode: True
# Epoch :6
# Training mode: True
# Epoch 6 training loss: 10.671604573726654
# Validation mode: True
# Epoch :7
# Training mode: True
# Epoch 7 training loss: 10.56933107972145
# Validation mode: True
# Epoch :8
# Training mode: True
# Epoch 8 training loss: 10.551495552062988
# Validation mode: True
# Epoch :9
# Training mode: True
# Epoch 9 training loss: 10.013176590204239
# Validation mode: True
# Epoch :10
# Training mode: True
# Epoch 10 training loss: 9.496221840381622
# Validation mode: True
# Epoch :11
# Training mode: True
# Epoch 11 training loss: 9.687777161598206
# Validation mode: True
# Epoch :12
# Training mode: True
# Epoch 12 training loss: 8.73074159026146
# Validation mode: True
# Epoch :13
# Training mode: True
# Epoch 13 training loss: 7.82943931221962
# Validation mode: True
# Epoch :14
# Training mode: True
# Epoch 14 training loss: 8.752543807029724
# Validation mode: True
# Epoch :15
# Training mode: True
# Epoch 15 training loss: 7.508216083049774
# Validation mode: True
# Epoch :16
# Training mode: True
# Epoch 16 training loss: 7.4552555829286575
# Validation mode: True
# Epoch :17
# Training mode: True
# Epoch 17 training loss: 7.257830366492271
# Validation mode: True
# Epoch :18
# Training mode: True
# Epoch 18 training loss: 7.074468940496445
# Validation mode: True
# Epoch :19
# Training mode: True
# Epoch 19 training loss: 6.532995268702507
# Validation mode: True
# Epoch :20
# Training mode: True
# Epoch 20 training loss: 7.065445214509964
# Validation mode: True
# Epoch :21
# Training mode: True
# Epoch 21 training loss: 6.4770083874464035
# Validation mode: True
# Epoch :22
# Training mode: True
# Epoch 22 training loss: 6.974603116512299
# Validation mode: True
# Epoch :23
# Training mode: True
# Epoch 23 training loss: 6.414362967014313
# Validation mode: True
# Epoch :24
# Training mode: True
# Epoch 24 training loss: 6.877576544880867
# Validation mode: True
# Epoch :25
# Training mode: True
# Epoch 25 training loss: 5.935855343937874
# Validation mode: True
# Epoch :26
# Training mode: True
# Epoch 26 training loss: 6.018925234675407
# Validation mode: True
# Epoch :27
# Training mode: True
# Epoch 27 training loss: 6.101633861660957
# Validation mode: True
# Epoch :28
# Training mode: True
# Epoch 28 training loss: 6.57181179523468
# Validation mode: True
# Epoch :29
# Training mode: True
# Epoch 29 training loss: 5.9885923862457275
# Validation mode: True
# Epoch :30
# Training mode: True
# Epoch 30 training loss: 5.864822372794151
# Validation mode: True
# Epoch :31
# Training mode: True
# Epoch 31 training loss: 5.82901956140995
# Validation mode: True
# Epoch :32
# Training mode: True
# Epoch 32 training loss: 5.709087297320366
# Validation mode: True
# Epoch :33
# Training mode: True
# Epoch 33 training loss: 5.30809885263443
# Validation mode: True
# Epoch :34
# Training mode: True
# Epoch 34 training loss: 5.5197499319911
# Validation mode: True
# Epoch :35
# Training mode: True
# Epoch 35 training loss: 5.374382480978966
# Validation mode: True
# Epoch :36
# Training mode: True
# Epoch 36 training loss: 5.429519176483154
# Validation mode: True
# Epoch :37
# Training mode: True
# Epoch 37 training loss: 6.149696916341782
# Validation mode: True
# Epoch :38
# Training mode: True
# Epoch 38 training loss: 6.044919088482857
# Validation mode: True
# Epoch :39
# Training mode: True
# Epoch 39 training loss: 5.838485136628151
# Validation mode: True
# Epoch :40
# Training mode: True
# Epoch 40 training loss: 5.499478846788406
# Validation mode: True
# Epoch :41
# Training mode: True
# Epoch 41 training loss: 6.057364448904991
# Validation mode: True
# Epoch :42
# Training mode: True
# Epoch 42 training loss: 5.8976734429597855
# Validation mode: True
# Epoch :43
# Training mode: True
# Epoch 43 training loss: 5.287231460213661
# Validation mode: True
# Epoch :44
# Training mode: True
# Epoch 44 training loss: 5.891900934278965
# Validation mode: True
# Epoch :45
# Training mode: True
# Epoch 45 training loss: 5.414760634303093
# Validation mode: True
# Epoch :46
# Training mode: True
# Epoch 46 training loss: 4.930256262421608
# Validation mode: True
# Epoch :47
# Training mode: True
# Epoch 47 training loss: 5.1016170755028725
# Validation mode: True
# Epoch :48
# Training mode: True
# Epoch 48 training loss: 4.766558885574341
# Validation mode: True
# Epoch :49
# Training mode: True
# Epoch 49 training loss: 5.179894924163818
# Validation mode: True
# Epoch :50
# Training mode: True
# Epoch 50 training loss: 5.082468539476395
# Validation mode: True
# Epoch :51
# Training mode: True
# Epoch 51 training loss: 4.554917007684708
# Validation mode: True
# Epoch :52
# Training mode: True
# Epoch 52 training loss: 5.1664218455553055
# Validation mode: True
# Epoch :53
# Training mode: True
# Epoch 53 training loss: 4.349059566855431
# Validation mode: True
# Epoch :54
# Training mode: True
# Epoch 54 training loss: 4.514671444892883
# Validation mode: True
# Epoch :55
# Training mode: True
# Epoch 55 training loss: 4.63119113445282
# Validation mode: True
# Epoch :56
# Training mode: True
# Epoch 56 training loss: 4.791685968637466
# Validation mode: True
# Epoch :57
# Training mode: True
# Epoch 57 training loss: 4.872300140559673
# Validation mode: True
# Epoch :58
# Training mode: True
# Epoch 58 training loss: 5.208743944764137
# Validation mode: True
# Epoch :59
# Training mode: True
# Epoch 59 training loss: 5.143277809023857
# Validation mode: True
# Epoch :60
# Training mode: True
# Epoch 60 training loss: 4.513441666960716
# Validation mode: True
# Epoch :61
# Training mode: True
# Epoch 61 training loss: 5.007044851779938
# Validation mode: True
# Epoch :62
# Training mode: True
# Epoch 62 training loss: 5.161338433623314
# Validation mode: True
# Epoch :63
# Training mode: True
# Epoch 63 training loss: 4.6423715353012085
# Validation mode: True
# Epoch :64
# Training mode: True
# Epoch 64 training loss: 4.899865999817848
# Validation mode: True
# Epoch :65
# Training mode: True
# Epoch 65 training loss: 4.4631731659173965
# Validation mode: True
# Epoch :66
# Training mode: True
# Epoch 66 training loss: 4.704347744584084
# Validation mode: True
# Epoch :67
# Training mode: True
# Epoch 67 training loss: 3.7603654935956
# Validation mode: True
# Epoch :68
# Training mode: True
# Epoch 68 training loss: 4.5573859214782715
# Validation mode: True
# Epoch :69
# Training mode: True
# Epoch 69 training loss: 3.7153631150722504
# Validation mode: True
# Epoch :70
# Training mode: True
# Epoch 70 training loss: 4.489043824374676
# Validation mode: True
# Epoch :71
# Training mode: True
# Epoch 71 training loss: 4.16663009673357
# Validation mode: True
# Epoch :72
# Training mode: True
# Epoch 72 training loss: 4.496157854795456
# Validation mode: True
# Epoch :73
# Training mode: True
# Epoch 73 training loss: 4.21333435177803
# Validation mode: True
# Epoch :74
# Training mode: True
# Epoch 74 training loss: 4.241106927394867
# Validation mode: True
# Epoch :75
# Training mode: True
# Epoch 75 training loss: 4.206858813762665
# Validation mode: True
# Epoch :76
# Training mode: True
# Epoch 76 training loss: 4.502562962472439
# Validation mode: True
# Epoch :77
# Training mode: True
# Epoch 77 training loss: 3.9200976490974426
# Validation mode: True
# Epoch :78
# Training mode: True
# Epoch 78 training loss: 3.8010208755731583
# Validation mode: True
# Epoch :79
# Training mode: True
# Epoch 79 training loss: 3.9577786922454834
# Validation mode: True
# Epoch :80
# Training mode: True
# Epoch 80 training loss: 4.269616484642029
# Validation mode: True
# Epoch :81
# Training mode: True
# Epoch 81 training loss: 3.58985211327672
# Validation mode: True
# Epoch :82
# Training mode: True
# Epoch 82 training loss: 3.912354826927185
# Validation mode: True
# Epoch :83
# Training mode: True
# Epoch 83 training loss: 3.8458785712718964
# Validation mode: True
# Epoch :84
# Training mode: True
# Epoch 84 training loss: 3.7553284615278244
# Validation mode: True
# Epoch :85
# Training mode: True
# Epoch 85 training loss: 3.752799578011036
# Validation mode: True
# Epoch :86
# Training mode: True
# Epoch 86 training loss: 3.9325064420700073
# Validation mode: True
# Epoch :87
# Training mode: True
# Epoch 87 training loss: 4.147929288446903
# Validation mode: True
# Epoch :88
# Training mode: True
# Epoch 88 training loss: 4.0831650495529175
# Validation mode: True
# Epoch :89
# Training mode: True
# Epoch 89 training loss: 3.7128438875079155
# Validation mode: True
# Epoch :90
# Training mode: True
# Epoch 90 training loss: 3.9314874410629272
# Validation mode: True
# Epoch :91
# Training mode: True
# Epoch 91 training loss: 3.8834714591503143
# Validation mode: True
# Epoch :92
# Training mode: True
# Epoch 92 training loss: 3.8004895225167274
# Validation mode: True
# Epoch :93
# Training mode: True
# Epoch 93 training loss: 3.8368996679782867
# Validation mode: True
# Epoch :94
# Training mode: True
# Epoch 94 training loss: 3.722668506205082
# Validation mode: True
# Epoch :95
# Training mode: True
# Epoch 95 training loss: 3.707363061606884
# Validation mode: True
# Epoch :96
# Training mode: True
# Epoch 96 training loss: 3.858893997967243
# Validation mode: True
# Epoch :97
# Training mode: True
# Epoch 97 training loss: 4.229269132018089
# Validation mode: True
# Epoch :98
# Training mode: True
# Epoch 98 training loss: 4.63711853325367
# Validation mode: True
# Epoch :99
# Training mode: True
# Epoch 99 training loss: 4.718650072813034
# Validation mode: True

# %% [markdown]
# #### Output of the scripts
# **main_training.py** creates a folder named **<experiment_name>** (given as argument **--en**)   under **result_files/experiments** folder. Two files are created under **results_files/experiments/<experiment_name>**:
# * **best_val_test_predictions-<hyperparameters_seperated by dash>-<experiment_name>.txt** contains predictions for independent test dataset.
# * **best_val_test_performance_results-<hyperparameters_seperated by dash>-<experiment_name>.txt** which contains the best test performance results. Sample output files for ChEMBL286 target is given under  **results_files/experiments/my_chembl286_training**.
