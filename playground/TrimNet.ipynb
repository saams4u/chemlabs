# %% [markdown]
# ## TrimNet: learning molecular representation from triplet messages for biomedicine
#
# <b>Motivation</b>
#
# Computational methods accelerate drug discovery and play an important role in biomedicine, such as molecular property prediction and compound–protein interaction (CPI) identification. A key challenge is to learn useful molecular representation. In the early years, molecular properties are mainly calculated by quantum mechanics or predicted by traditional machine learning methods, which requires expert knowledge and is often labor-intensive. Nowadays, graph neural networks have received significant attention because of the powerful ability to learn representation from graph data. Nevertheless, current graph-based methods have some limitations that need to be addressed, such as large-scale parameters and insufficient bond information extraction.
#
# <b>Results</b>
#
# In this study, we proposed a graph-based approach and employed a novel triplet message mechanism to learn molecular representation efficiently, named triplet message networks (TrimNet). We show that TrimNet can accurately complete multiple molecular representation learning tasks with significant parameter reduction, including the quantum properties, bioactivity, physiology and CPI prediction. In the experiments, TrimNet outperforms the previous state-of-the-art method by a significant margin on various datasets. Besides the few parameters and high prediction accuracy, TrimNet could focus on the atoms essential to the target properties, providing a clear interpretation of the prediction tasks. These advantages have established TrimNet as a powerful and useful computational tool in solving the challenging problem of molecular representation learning.
#
# Link to paper: https://bit.ly/3idpppO
#
# Credit: https://github.com/yvquanli/TrimNet

# %%
# Clone the repository and cd into directory
# !git clone https://github.com/yvquanli/TrimNet.git
# %cd TrimNet
# Out:
# Cloning into 'TrimNet'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 67 (delta 24), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (67/67), done.
# /content/TrimNet

# %%
# Install dependencies / requirements
# !pip install torch==1.4.0

# !pip install torch-geometric \
  torch-sparse==latest+cu101 \
  torch-scatter==latest+cu101 \
  torch-cluster==latest+cu101 \
  -f https://pytorch-geometric.com/whl/torch-1.4.0.html

# Install RDKit
# !pip install rdkit-pypi==2021.3.1.5

# %% [markdown]
# ### Usage example
# For quantum dataset

# %%
# %cd TrimNet/trimnet_quantum/src

# download dataset from https://s3-us-west-1.amazonaws.com/deepchem.io/datasets/molnet_publish/qm9.zip
# !wget https://s3-us-west-1.amazonaws.com/deepchem.io/datasets/molnet_publish/qm9.zip

# %%
# unzip the file to trimnet_quantum/dataset/raw
# !unzip qm9.zip -d ../dataset/raw

# %%
# !python run.py --depth 3 --seed 1234 --gpu 0
# Out:
# ################################################################################
# ################################################################################
# train set num:1201    valid set num:157    test set num: 155
# total parameters:98018
# ################################################################################
# ################################################################################
# Training start...
# 100% 10/10 [00:00<00:00, 11.16it/s]
# 100% 2/2 [00:00<00:00, 13.24it/s]
# 100% 2/2 [00:00<00:00, 50.73it/s]
# Epoch:0 bace trn_loss:0.744 trn_roc:0.500 trn_prc:0.459 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:0 bace val_loss:0.695 val_roc:0.515 val_prc:0.432 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:0 bace test_loss:0.699 test_roc:0.543 test_prc:0.486 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 0
# 100% 10/10 [00:00<00:00, 27.88it/s]
# 100% 2/2 [00:00<00:00, 69.25it/s]
# 100% 2/2 [00:00<00:00, 72.66it/s]
# Epoch:1 bace trn_loss:0.701 trn_roc:0.524 trn_prc:0.488 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:1 bace val_loss:0.701 val_roc:0.557 val_prc:0.468 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:1 bace test_loss:0.705 test_roc:0.547 test_prc:0.511 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 1
# 100% 10/10 [00:00<00:00, 27.76it/s]
# 100% 2/2 [00:00<00:00, 64.65it/s]
# 100% 2/2 [00:00<00:00, 70.83it/s]
# Epoch:2 bace trn_loss:0.694 trn_roc:0.540 trn_prc:0.486 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:2 bace val_loss:0.697 val_roc:0.574 val_prc:0.462 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:2 bace test_loss:0.655 test_roc:0.571 test_prc:0.560 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 2
# 100% 10/10 [00:00<00:00, 28.09it/s]
# 100% 2/2 [00:00<00:00, 71.25it/s]
# 100% 2/2 [00:00<00:00, 71.84it/s]
# Epoch:3 bace trn_loss:0.674 trn_roc:0.610 trn_prc:0.569 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:3 bace val_loss:0.705 val_roc:0.575 val_prc:0.510 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:3 bace test_loss:0.643 test_roc:0.586 test_prc:0.539 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 3
# 100% 10/10 [00:00<00:00, 27.82it/s]
# 100% 2/2 [00:00<00:00, 70.62it/s]
# 100% 2/2 [00:00<00:00, 71.29it/s]
# Epoch:4 bace trn_loss:0.678 trn_roc:0.621 trn_prc:0.568 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:4 bace val_loss:0.676 val_roc:0.674 val_prc:0.558 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:4 bace test_loss:0.672 test_roc:0.588 test_prc:0.578 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 4
# 100% 10/10 [00:00<00:00, 27.95it/s]
# 100% 2/2 [00:00<00:00, 71.14it/s]
# 100% 2/2 [00:00<00:00, 66.58it/s]
# Epoch:5 bace trn_loss:0.672 trn_roc:0.633 trn_prc:0.567 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:5 bace val_loss:0.674 val_roc:0.707 val_prc:0.561 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:5 bace test_loss:0.682 test_roc:0.566 test_prc:0.584 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 5
# 100% 10/10 [00:00<00:00, 27.89it/s]
# 100% 2/2 [00:00<00:00, 69.40it/s]
# 100% 2/2 [00:00<00:00, 67.37it/s]
# Epoch:6 bace trn_loss:0.661 trn_roc:0.645 trn_prc:0.604 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:6 bace val_loss:0.758 val_roc:0.715 val_prc:0.562 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:6 bace test_loss:0.804 test_roc:0.581 test_prc:0.597 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 6
# 100% 10/10 [00:00<00:00, 27.92it/s]
# 100% 2/2 [00:00<00:00, 71.88it/s]
# 100% 2/2 [00:00<00:00, 72.83it/s]
# Epoch:7 bace trn_loss:0.651 trn_roc:0.674 trn_prc:0.638 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:7 bace val_loss:0.679 val_roc:0.730 val_prc:0.584 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:7 bace test_loss:0.694 test_roc:0.591 test_prc:0.632 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 7
# 100% 10/10 [00:00<00:00, 28.07it/s]
# 100% 2/2 [00:00<00:00, 72.52it/s]
# 100% 2/2 [00:00<00:00, 73.83it/s]
# Epoch:8 bace trn_loss:0.648 trn_roc:0.681 trn_prc:0.620 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:8 bace val_loss:0.669 val_roc:0.725 val_prc:0.605 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:8 bace test_loss:0.659 test_roc:0.627 test_prc:0.623 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 8
# 100% 10/10 [00:00<00:00, 28.33it/s]
# 100% 2/2 [00:00<00:00, 71.69it/s]
# 100% 2/2 [00:00<00:00, 73.21it/s]
# Epoch:9 bace trn_loss:0.642 trn_roc:0.687 trn_prc:0.616 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:9 bace val_loss:0.659 val_roc:0.715 val_prc:0.561 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:9 bace test_loss:0.636 test_roc:0.660 test_prc:0.605 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 28.30it/s]
# 100% 2/2 [00:00<00:00, 71.27it/s]
# 100% 2/2 [00:00<00:00, 67.30it/s]
# Epoch:10 bace trn_loss:0.622 trn_roc:0.710 trn_prc:0.645 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:10 bace val_loss:0.664 val_roc:0.718 val_prc:0.599 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:10 bace test_loss:0.648 test_roc:0.673 test_prc:0.627 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.99it/s]
# 100% 2/2 [00:00<00:00, 71.40it/s]
# 100% 2/2 [00:00<00:00, 71.64it/s]
# Epoch:11 bace trn_loss:0.635 trn_roc:0.705 trn_prc:0.643 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:11 bace val_loss:0.663 val_roc:0.711 val_prc:0.607 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:11 bace test_loss:0.633 test_roc:0.710 test_prc:0.646 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 11
# 100% 10/10 [00:00<00:00, 28.02it/s]
# 100% 2/2 [00:00<00:00, 67.66it/s]
# 100% 2/2 [00:00<00:00, 71.25it/s]
# Epoch:12 bace trn_loss:0.635 trn_roc:0.708 trn_prc:0.641 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:12 bace val_loss:0.695 val_roc:0.699 val_prc:0.593 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:12 bace test_loss:0.619 test_roc:0.679 test_prc:0.644 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 28.28it/s]
# 100% 2/2 [00:00<00:00, 71.31it/s]
# 100% 2/2 [00:00<00:00, 73.64it/s]
# Epoch:13 bace trn_loss:0.617 trn_roc:0.722 trn_prc:0.669 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:13 bace val_loss:0.668 val_roc:0.723 val_prc:0.581 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:13 bace test_loss:0.661 test_roc:0.667 test_prc:0.633 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.82it/s]
# 100% 2/2 [00:00<00:00, 69.98it/s]
# 100% 2/2 [00:00<00:00, 70.20it/s]
# Epoch:14 bace trn_loss:0.614 trn_roc:0.728 trn_prc:0.663 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:14 bace val_loss:0.692 val_roc:0.708 val_prc:0.589 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:14 bace test_loss:0.674 test_roc:0.665 test_prc:0.633 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 28.07it/s]
# 100% 2/2 [00:00<00:00, 69.82it/s]
# 100% 2/2 [00:00<00:00, 70.19it/s]
# Epoch:15 bace trn_loss:0.599 trn_roc:0.740 trn_prc:0.673 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:15 bace val_loss:0.739 val_roc:0.714 val_prc:0.595 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:15 bace test_loss:0.701 test_roc:0.667 test_prc:0.663 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 28.28it/s]
# 100% 2/2 [00:00<00:00, 71.04it/s]
# 100% 2/2 [00:00<00:00, 67.76it/s]
# Epoch:16 bace trn_loss:0.599 trn_roc:0.747 trn_prc:0.675 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:16 bace val_loss:0.759 val_roc:0.705 val_prc:0.594 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:16 bace test_loss:0.722 test_roc:0.655 test_prc:0.626 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 28.25it/s]
# 100% 2/2 [00:00<00:00, 69.79it/s]
# 100% 2/2 [00:00<00:00, 72.94it/s]
# Epoch:17 bace trn_loss:0.594 trn_roc:0.745 trn_prc:0.666 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:17 bace val_loss:0.767 val_roc:0.713 val_prc:0.623 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:17 bace test_loss:0.729 test_roc:0.692 test_prc:0.657 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 17
# 100% 10/10 [00:00<00:00, 28.19it/s]
# 100% 2/2 [00:00<00:00, 68.22it/s]
# 100% 2/2 [00:00<00:00, 72.04it/s]
# Epoch:18 bace trn_loss:0.558 trn_roc:0.777 trn_prc:0.721 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:18 bace val_loss:0.722 val_roc:0.740 val_prc:0.648 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:18 bace test_loss:0.688 test_roc:0.703 test_prc:0.676 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 18
# 100% 10/10 [00:00<00:00, 28.05it/s]
# 100% 2/2 [00:00<00:00, 70.19it/s]
# 100% 2/2 [00:00<00:00, 72.16it/s]
# Epoch:19 bace trn_loss:0.565 trn_roc:0.784 trn_prc:0.716 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:19 bace val_loss:0.776 val_roc:0.707 val_prc:0.600 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:19 bace test_loss:0.693 test_roc:0.693 test_prc:0.672 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.93it/s]
# 100% 2/2 [00:00<00:00, 71.37it/s]
# 100% 2/2 [00:00<00:00, 71.45it/s]
# Epoch:20 bace trn_loss:0.581 trn_roc:0.762 trn_prc:0.702 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:20 bace val_loss:0.750 val_roc:0.729 val_prc:0.651 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:20 bace test_loss:0.729 test_roc:0.707 test_prc:0.668 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Model saved at epoch 20
# 100% 10/10 [00:00<00:00, 28.17it/s]
# 100% 2/2 [00:00<00:00, 71.42it/s]
# 100% 2/2 [00:00<00:00, 66.92it/s]
# Epoch:21 bace trn_loss:0.570 trn_roc:0.779 trn_prc:0.728 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:21 bace val_loss:0.737 val_roc:0.714 val_prc:0.631 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:21 bace test_loss:0.646 test_roc:0.701 test_prc:0.649 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.21it/s]
# 100% 2/2 [00:00<00:00, 70.01it/s]
# 100% 2/2 [00:00<00:00, 72.57it/s]
# Epoch:22 bace trn_loss:0.575 trn_roc:0.775 trn_prc:0.733 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:22 bace val_loss:0.794 val_roc:0.696 val_prc:0.599 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:22 bace test_loss:0.684 test_roc:0.700 test_prc:0.660 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.18it/s]
# 100% 2/2 [00:00<00:00, 69.31it/s]
# 100% 2/2 [00:00<00:00, 72.17it/s]
# Epoch:23 bace trn_loss:0.544 trn_roc:0.788 trn_prc:0.718 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:23 bace val_loss:0.823 val_roc:0.718 val_prc:0.634 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:23 bace test_loss:0.706 test_roc:0.715 test_prc:0.678 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.62it/s]
# 100% 2/2 [00:00<00:00, 71.56it/s]
# 100% 2/2 [00:00<00:00, 72.61it/s]
# Epoch:24 bace trn_loss:0.542 trn_roc:0.802 trn_prc:0.737 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:24 bace val_loss:0.806 val_roc:0.716 val_prc:0.652 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:24 bace test_loss:0.744 test_roc:0.729 test_prc:0.680 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Model saved at epoch 24
# 100% 10/10 [00:00<00:00, 27.94it/s]
# 100% 2/2 [00:00<00:00, 69.21it/s]
# 100% 2/2 [00:00<00:00, 71.92it/s]
# Epoch:25 bace trn_loss:0.541 trn_roc:0.796 trn_prc:0.726 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:25 bace val_loss:0.748 val_roc:0.719 val_prc:0.626 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:25 bace test_loss:0.760 test_roc:0.740 test_prc:0.688 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.21it/s]
# 100% 2/2 [00:00<00:00, 72.76it/s]
# 100% 2/2 [00:00<00:00, 70.54it/s]
# Epoch:26 bace trn_loss:0.551 trn_roc:0.796 trn_prc:0.726 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:26 bace val_loss:0.763 val_roc:0.714 val_prc:0.650 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:26 bace test_loss:0.689 test_roc:0.722 test_prc:0.676 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.03it/s]
# 100% 2/2 [00:00<00:00, 71.51it/s]
# 100% 2/2 [00:00<00:00, 69.66it/s]
# Epoch:27 bace trn_loss:0.539 trn_roc:0.805 trn_prc:0.742 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:27 bace val_loss:0.789 val_roc:0.711 val_prc:0.631 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:27 bace test_loss:0.694 test_roc:0.714 test_prc:0.671 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.28it/s]
# 100% 2/2 [00:00<00:00, 72.06it/s]
# 100% 2/2 [00:00<00:00, 73.51it/s]
# Epoch:28 bace trn_loss:0.528 trn_roc:0.808 trn_prc:0.746 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:28 bace val_loss:0.796 val_roc:0.730 val_prc:0.649 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:28 bace test_loss:0.723 test_roc:0.720 test_prc:0.683 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.15it/s]
# 100% 2/2 [00:00<00:00, 67.56it/s]
# 100% 2/2 [00:00<00:00, 73.30it/s]
# Epoch:29 bace trn_loss:0.537 trn_roc:0.806 trn_prc:0.734 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:29 bace val_loss:0.734 val_roc:0.753 val_prc:0.676 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:29 bace test_loss:0.763 test_roc:0.708 test_prc:0.668 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Model saved at epoch 29
# 100% 10/10 [00:00<00:00, 28.00it/s]
# 100% 2/2 [00:00<00:00, 71.81it/s]
# 100% 2/2 [00:00<00:00, 72.81it/s]
# Epoch:30 bace trn_loss:0.519 trn_roc:0.820 trn_prc:0.764 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:30 bace val_loss:0.750 val_roc:0.734 val_prc:0.626 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# Epoch:30 bace test_loss:0.706 test_roc:0.726 test_prc:0.685 lr_cur:0.00070 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.17it/s]
# 100% 2/2 [00:00<00:00, 70.92it/s]
# 100% 2/2 [00:00<00:00, 72.48it/s]
# Epoch:31 bace trn_loss:0.512 trn_roc:0.824 trn_prc:0.771 lr_cur:0.00049 time elapsed 0.00 hrs (0.2 mins)
# Epoch:31 bace val_loss:0.789 val_roc:0.728 val_prc:0.621 lr_cur:0.00049 time elapsed 0.00 hrs (0.2 mins)
# Epoch:31 bace test_loss:0.731 test_roc:0.713 test_prc:0.671 lr_cur:0.00049 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.10it/s]
# 100% 2/2 [00:00<00:00, 69.63it/s]
# 100% 2/2 [00:00<00:00, 70.98it/s]
# Epoch:32 bace trn_loss:0.506 trn_roc:0.833 trn_prc:0.766 lr_cur:0.00049 time elapsed 0.00 hrs (0.2 mins)
# Epoch:32 bace val_loss:0.839 val_roc:0.712 val_prc:0.595 lr_cur:0.00049 time elapsed 0.00 hrs (0.2 mins)
# Epoch:32 bace test_loss:0.780 test_roc:0.726 test_prc:0.685 lr_cur:0.00049 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.96it/s]
# 100% 2/2 [00:00<00:00, 68.07it/s]
# 100% 2/2 [00:00<00:00, 67.04it/s]
# Epoch:33 bace trn_loss:0.515 trn_roc:0.825 trn_prc:0.770 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:33 bace val_loss:0.859 val_roc:0.710 val_prc:0.607 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:33 bace test_loss:0.733 test_roc:0.735 test_prc:0.694 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 28.13it/s]
# 100% 2/2 [00:00<00:00, 64.50it/s]
# 100% 2/2 [00:00<00:00, 70.18it/s]
# Epoch:34 bace trn_loss:0.490 trn_roc:0.834 trn_prc:0.766 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:34 bace val_loss:0.873 val_roc:0.710 val_prc:0.607 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:34 bace test_loss:0.746 test_roc:0.744 test_prc:0.701 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 70.79it/s]
# 100% 2/2 [00:00<00:00, 71.15it/s]
# Epoch:35 bace trn_loss:0.506 trn_roc:0.834 trn_prc:0.777 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:35 bace val_loss:0.886 val_roc:0.703 val_prc:0.586 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:35 bace test_loss:0.750 test_roc:0.725 test_prc:0.678 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.49it/s]
# 100% 2/2 [00:00<00:00, 71.56it/s]
# 100% 2/2 [00:00<00:00, 71.72it/s]
# Epoch:36 bace trn_loss:0.488 trn_roc:0.842 trn_prc:0.784 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:36 bace val_loss:0.867 val_roc:0.710 val_prc:0.587 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:36 bace test_loss:0.750 test_roc:0.735 test_prc:0.690 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.52it/s]
# 100% 2/2 [00:00<00:00, 68.65it/s]
# 100% 2/2 [00:00<00:00, 64.73it/s]
# Epoch:37 bace trn_loss:0.504 trn_roc:0.832 trn_prc:0.763 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:37 bace val_loss:0.853 val_roc:0.700 val_prc:0.574 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:37 bace test_loss:0.777 test_roc:0.720 test_prc:0.675 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.74it/s]
# 100% 2/2 [00:00<00:00, 65.22it/s]
# 100% 2/2 [00:00<00:00, 70.48it/s]
# Epoch:38 bace trn_loss:0.506 trn_roc:0.831 trn_prc:0.780 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:38 bace val_loss:0.827 val_roc:0.713 val_prc:0.588 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:38 bace test_loss:0.754 test_roc:0.734 test_prc:0.691 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.79it/s]
# 100% 2/2 [00:00<00:00, 65.85it/s]
# 100% 2/2 [00:00<00:00, 70.33it/s]
# Epoch:39 bace trn_loss:0.487 trn_roc:0.846 trn_prc:0.800 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:39 bace val_loss:0.840 val_roc:0.721 val_prc:0.602 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# Epoch:39 bace test_loss:0.763 test_roc:0.736 test_prc:0.688 lr_cur:0.00049 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 28.38it/s]
# 100% 2/2 [00:00<00:00, 67.81it/s]
# 100% 2/2 [00:00<00:00, 70.90it/s]
# Epoch:40 bace trn_loss:0.485 trn_roc:0.841 trn_prc:0.787 lr_cur:0.00049 time elapsed 0.01 hrs (0.3 mins)
# Epoch:40 bace val_loss:0.802 val_roc:0.742 val_prc:0.626 lr_cur:0.00049 time elapsed 0.01 hrs (0.3 mins)
# Epoch:40 bace test_loss:0.751 test_roc:0.732 test_prc:0.676 lr_cur:0.00049 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 28.06it/s]
# 100% 2/2 [00:00<00:00, 70.62it/s]
# 100% 2/2 [00:00<00:00, 73.24it/s]
# Epoch:41 bace trn_loss:0.508 trn_roc:0.832 trn_prc:0.776 lr_cur:0.00049 time elapsed 0.01 hrs (0.3 mins)
# Epoch:41 bace val_loss:0.791 val_roc:0.745 val_prc:0.639 lr_cur:0.00049 time elapsed 0.01 hrs (0.3 mins)
# Epoch:41 bace test_loss:0.737 test_roc:0.731 test_prc:0.671 lr_cur:0.00049 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.93it/s]
# 100% 2/2 [00:00<00:00, 69.14it/s]
# 100% 2/2 [00:00<00:00, 66.92it/s]
# Epoch:42 bace trn_loss:0.497 trn_roc:0.840 trn_prc:0.771 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:42 bace val_loss:0.813 val_roc:0.729 val_prc:0.618 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:42 bace test_loss:0.710 test_roc:0.727 test_prc:0.669 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 64.69it/s]
# 100% 2/2 [00:00<00:00, 71.53it/s]
# Epoch:43 bace trn_loss:0.490 trn_roc:0.844 trn_prc:0.806 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:43 bace val_loss:0.819 val_roc:0.729 val_prc:0.622 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:43 bace test_loss:0.743 test_roc:0.721 test_prc:0.658 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.47it/s]
# 100% 2/2 [00:00<00:00, 67.11it/s]
# 100% 2/2 [00:00<00:00, 71.18it/s]
# Epoch:44 bace trn_loss:0.497 trn_roc:0.838 trn_prc:0.770 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:44 bace val_loss:0.833 val_roc:0.739 val_prc:0.622 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:44 bace test_loss:0.779 test_roc:0.723 test_prc:0.663 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.43it/s]
# 100% 2/2 [00:00<00:00, 70.01it/s]
# 100% 2/2 [00:00<00:00, 70.44it/s]
# Epoch:45 bace trn_loss:0.492 trn_roc:0.844 trn_prc:0.795 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:45 bace val_loss:0.841 val_roc:0.714 val_prc:0.592 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:45 bace test_loss:0.756 test_roc:0.739 test_prc:0.690 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.58it/s]
# 100% 2/2 [00:00<00:00, 69.21it/s]
# 100% 2/2 [00:00<00:00, 67.19it/s]
# Epoch:46 bace trn_loss:0.477 trn_roc:0.847 trn_prc:0.784 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:46 bace val_loss:0.857 val_roc:0.708 val_prc:0.613 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# Epoch:46 bace test_loss:0.720 test_roc:0.753 test_prc:0.718 lr_cur:0.00034 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.73it/s]
# 100% 2/2 [00:00<00:00, 67.58it/s]
# 100% 2/2 [00:00<00:00, 70.39it/s]
# Epoch:47 bace trn_loss:0.487 trn_roc:0.844 trn_prc:0.773 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:47 bace val_loss:0.853 val_roc:0.712 val_prc:0.606 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:47 bace test_loss:0.729 test_roc:0.757 test_prc:0.716 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.92it/s]
# 100% 2/2 [00:00<00:00, 62.63it/s]
# 100% 2/2 [00:00<00:00, 64.72it/s]
# Epoch:48 bace trn_loss:0.476 trn_roc:0.855 trn_prc:0.800 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:48 bace val_loss:0.837 val_roc:0.719 val_prc:0.599 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:48 bace test_loss:0.753 test_roc:0.746 test_prc:0.710 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.72it/s]
# 100% 2/2 [00:00<00:00, 68.88it/s]
# 100% 2/2 [00:00<00:00, 71.16it/s]
# Epoch:49 bace trn_loss:0.482 trn_roc:0.846 trn_prc:0.788 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:49 bace val_loss:0.840 val_roc:0.724 val_prc:0.601 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:49 bace test_loss:0.790 test_roc:0.738 test_prc:0.694 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 71.56it/s]
# 100% 2/2 [00:00<00:00, 72.42it/s]
# Epoch:50 bace trn_loss:0.478 trn_roc:0.853 trn_prc:0.790 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:50 bace val_loss:0.852 val_roc:0.726 val_prc:0.614 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:50 bace test_loss:0.782 test_roc:0.733 test_prc:0.687 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.46it/s]
# 100% 2/2 [00:00<00:00, 67.21it/s]
# 100% 2/2 [00:00<00:00, 67.32it/s]
# Epoch:51 bace trn_loss:0.468 trn_roc:0.859 trn_prc:0.798 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:51 bace val_loss:0.865 val_roc:0.705 val_prc:0.597 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:51 bace test_loss:0.738 test_roc:0.766 test_prc:0.710 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.90it/s]
# 100% 2/2 [00:00<00:00, 64.93it/s]
# 100% 2/2 [00:00<00:00, 70.69it/s]
# Epoch:52 bace trn_loss:0.461 trn_roc:0.860 trn_prc:0.804 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:52 bace val_loss:0.885 val_roc:0.696 val_prc:0.584 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# Epoch:52 bace test_loss:0.720 test_roc:0.771 test_prc:0.715 lr_cur:0.00034 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.93it/s]
# 100% 2/2 [00:00<00:00, 71.41it/s]
# 100% 2/2 [00:00<00:00, 69.54it/s]
# Epoch:53 bace trn_loss:0.465 trn_roc:0.861 trn_prc:0.813 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:53 bace val_loss:0.928 val_roc:0.700 val_prc:0.594 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:53 bace test_loss:0.737 test_roc:0.774 test_prc:0.708 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.57it/s]
# 100% 2/2 [00:00<00:00, 70.07it/s]
# 100% 2/2 [00:00<00:00, 69.26it/s]
# Epoch:54 bace trn_loss:0.470 trn_roc:0.855 trn_prc:0.801 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:54 bace val_loss:0.890 val_roc:0.705 val_prc:0.608 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:54 bace test_loss:0.725 test_roc:0.766 test_prc:0.696 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 28.00it/s]
# 100% 2/2 [00:00<00:00, 70.88it/s]
# 100% 2/2 [00:00<00:00, 65.16it/s]
# Epoch:55 bace trn_loss:0.465 trn_roc:0.857 trn_prc:0.806 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:55 bace val_loss:0.889 val_roc:0.697 val_prc:0.586 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:55 bace test_loss:0.718 test_roc:0.768 test_prc:0.701 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.64it/s]
# 100% 2/2 [00:00<00:00, 63.70it/s]
# 100% 2/2 [00:00<00:00, 66.03it/s]
# Epoch:56 bace trn_loss:0.471 trn_roc:0.857 trn_prc:0.796 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:56 bace val_loss:0.895 val_roc:0.690 val_prc:0.578 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:56 bace test_loss:0.702 test_roc:0.765 test_prc:0.695 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.81it/s]
# 100% 2/2 [00:00<00:00, 69.68it/s]
# 100% 2/2 [00:00<00:00, 70.72it/s]
# Epoch:57 bace trn_loss:0.470 trn_roc:0.859 trn_prc:0.792 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:57 bace val_loss:0.875 val_roc:0.704 val_prc:0.583 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:57 bace test_loss:0.730 test_roc:0.758 test_prc:0.696 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.38it/s]
# 100% 2/2 [00:00<00:00, 67.34it/s]
# 100% 2/2 [00:00<00:00, 68.42it/s]
# Epoch:58 bace trn_loss:0.460 trn_roc:0.856 trn_prc:0.792 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:58 bace val_loss:0.864 val_roc:0.719 val_prc:0.603 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:58 bace test_loss:0.762 test_roc:0.745 test_prc:0.683 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.20it/s]
# 100% 2/2 [00:00<00:00, 70.15it/s]
# 100% 2/2 [00:00<00:00, 66.16it/s]
# Epoch:59 bace trn_loss:0.466 trn_roc:0.851 trn_prc:0.794 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:59 bace val_loss:0.857 val_roc:0.706 val_prc:0.591 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:59 bace test_loss:0.719 test_roc:0.767 test_prc:0.701 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.85it/s]
# 100% 2/2 [00:00<00:00, 64.94it/s]
# 100% 2/2 [00:00<00:00, 70.17it/s]
# Epoch:60 bace trn_loss:0.463 trn_roc:0.861 trn_prc:0.817 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:60 bace val_loss:0.888 val_roc:0.703 val_prc:0.594 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# Epoch:60 bace test_loss:0.723 test_roc:0.778 test_prc:0.715 lr_cur:0.00024 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 26.39it/s]
# 100% 2/2 [00:00<00:00, 70.61it/s]
# 100% 2/2 [00:00<00:00, 66.34it/s]
# Epoch:61 bace trn_loss:0.453 trn_roc:0.866 trn_prc:0.801 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# Epoch:61 bace val_loss:0.891 val_roc:0.705 val_prc:0.601 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# Epoch:61 bace test_loss:0.727 test_roc:0.779 test_prc:0.715 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.60it/s]
# 100% 2/2 [00:00<00:00, 70.66it/s]
# 100% 2/2 [00:00<00:00, 67.26it/s]
# Epoch:62 bace trn_loss:0.447 trn_roc:0.866 trn_prc:0.807 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# Epoch:62 bace val_loss:0.888 val_roc:0.707 val_prc:0.589 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# Epoch:62 bace test_loss:0.727 test_roc:0.777 test_prc:0.713 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.84it/s]
# 100% 2/2 [00:00<00:00, 64.73it/s]
# 100% 2/2 [00:00<00:00, 70.37it/s]
# Epoch:63 bace trn_loss:0.451 trn_roc:0.864 trn_prc:0.802 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# Epoch:63 bace val_loss:0.887 val_roc:0.710 val_prc:0.596 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# Epoch:63 bace test_loss:0.729 test_roc:0.783 test_prc:0.712 lr_cur:0.00024 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 28.20it/s]
# 100% 2/2 [00:00<00:00, 67.24it/s]
# 100% 2/2 [00:00<00:00, 71.17it/s]
# Epoch:64 bace trn_loss:0.463 trn_roc:0.859 trn_prc:0.805 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:64 bace val_loss:0.895 val_roc:0.700 val_prc:0.584 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:64 bace test_loss:0.714 test_roc:0.781 test_prc:0.711 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.63it/s]
# 100% 2/2 [00:00<00:00, 64.50it/s]
# 100% 2/2 [00:00<00:00, 64.56it/s]
# Epoch:65 bace trn_loss:0.439 trn_roc:0.871 trn_prc:0.817 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:65 bace val_loss:0.910 val_roc:0.696 val_prc:0.592 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:65 bace test_loss:0.711 test_roc:0.786 test_prc:0.717 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 68.11it/s]
# 100% 2/2 [00:00<00:00, 69.18it/s]
# Epoch:66 bace trn_loss:0.456 trn_roc:0.861 trn_prc:0.790 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:66 bace val_loss:0.899 val_roc:0.706 val_prc:0.605 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:66 bace test_loss:0.734 test_roc:0.780 test_prc:0.713 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.92it/s]
# 100% 2/2 [00:00<00:00, 68.42it/s]
# 100% 2/2 [00:00<00:00, 69.91it/s]
# Epoch:67 bace trn_loss:0.444 trn_roc:0.866 trn_prc:0.795 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:67 bace val_loss:0.876 val_roc:0.715 val_prc:0.610 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:67 bace test_loss:0.745 test_roc:0.773 test_prc:0.706 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.95it/s]
# 100% 2/2 [00:00<00:00, 68.21it/s]
# 100% 2/2 [00:00<00:00, 71.11it/s]
# Epoch:68 bace trn_loss:0.449 trn_roc:0.867 trn_prc:0.804 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:68 bace val_loss:0.850 val_roc:0.727 val_prc:0.613 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:68 bace test_loss:0.752 test_roc:0.772 test_prc:0.714 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.91it/s]
# 100% 2/2 [00:00<00:00, 67.88it/s]
# 100% 2/2 [00:00<00:00, 63.34it/s]
# Epoch:69 bace trn_loss:0.473 trn_roc:0.855 trn_prc:0.788 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:69 bace val_loss:0.839 val_roc:0.728 val_prc:0.615 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:69 bace test_loss:0.722 test_roc:0.772 test_prc:0.704 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.94it/s]
# 100% 2/2 [00:00<00:00, 69.59it/s]
# 100% 2/2 [00:00<00:00, 72.80it/s]
# Epoch:70 bace trn_loss:0.447 trn_roc:0.865 trn_prc:0.804 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:70 bace val_loss:0.846 val_roc:0.717 val_prc:0.606 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:70 bace test_loss:0.717 test_roc:0.778 test_prc:0.714 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.33it/s]
# 100% 2/2 [00:00<00:00, 71.14it/s]
# 100% 2/2 [00:00<00:00, 70.36it/s]
# Epoch:71 bace trn_loss:0.458 trn_roc:0.865 trn_prc:0.793 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:71 bace val_loss:0.869 val_roc:0.702 val_prc:0.587 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:71 bace test_loss:0.718 test_roc:0.778 test_prc:0.714 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.85it/s]
# 100% 2/2 [00:00<00:00, 68.37it/s]
# 100% 2/2 [00:00<00:00, 72.63it/s]
# Epoch:72 bace trn_loss:0.469 trn_roc:0.856 trn_prc:0.776 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:72 bace val_loss:0.874 val_roc:0.702 val_prc:0.588 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:72 bace test_loss:0.726 test_roc:0.780 test_prc:0.713 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 28.36it/s]
# 100% 2/2 [00:00<00:00, 67.14it/s]
# 100% 2/2 [00:00<00:00, 70.32it/s]
# Epoch:73 bace trn_loss:0.442 trn_roc:0.874 trn_prc:0.814 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:73 bace val_loss:0.864 val_roc:0.708 val_prc:0.593 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:73 bace test_loss:0.745 test_roc:0.774 test_prc:0.714 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.77it/s]
# 100% 2/2 [00:00<00:00, 69.84it/s]
# 100% 2/2 [00:00<00:00, 69.12it/s]
# Epoch:74 bace trn_loss:0.455 trn_roc:0.862 trn_prc:0.790 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:74 bace val_loss:0.852 val_roc:0.721 val_prc:0.598 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# Epoch:74 bace test_loss:0.770 test_roc:0.768 test_prc:0.708 lr_cur:0.00017 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.82it/s]
# 100% 2/2 [00:00<00:00, 71.70it/s]
# 100% 2/2 [00:00<00:00, 72.89it/s]
# Epoch:75 bace trn_loss:0.444 trn_roc:0.864 trn_prc:0.795 lr_cur:0.00012 time elapsed 0.01 hrs (0.5 mins)
# Epoch:75 bace val_loss:0.854 val_roc:0.716 val_prc:0.593 lr_cur:0.00012 time elapsed 0.01 hrs (0.5 mins)
# Epoch:75 bace test_loss:0.748 test_roc:0.773 test_prc:0.710 lr_cur:0.00012 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.89it/s]
# 100% 2/2 [00:00<00:00, 70.98it/s]
# 100% 2/2 [00:00<00:00, 71.58it/s]
# Epoch:76 bace trn_loss:0.455 trn_roc:0.863 trn_prc:0.804 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:76 bace val_loss:0.864 val_roc:0.710 val_prc:0.595 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:76 bace test_loss:0.725 test_roc:0.785 test_prc:0.723 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.95it/s]
# 100% 2/2 [00:00<00:00, 71.64it/s]
# 100% 2/2 [00:00<00:00, 67.02it/s]
# Epoch:77 bace trn_loss:0.449 trn_roc:0.866 trn_prc:0.797 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:77 bace val_loss:0.866 val_roc:0.705 val_prc:0.597 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:77 bace test_loss:0.714 test_roc:0.786 test_prc:0.720 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.94it/s]
# 100% 2/2 [00:00<00:00, 66.56it/s]
# 100% 2/2 [00:00<00:00, 67.44it/s]
# Epoch:78 bace trn_loss:0.446 trn_roc:0.874 trn_prc:0.805 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:78 bace val_loss:0.893 val_roc:0.700 val_prc:0.586 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:78 bace test_loss:0.702 test_roc:0.792 test_prc:0.725 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 28.18it/s]
# 100% 2/2 [00:00<00:00, 71.83it/s]
# 100% 2/2 [00:00<00:00, 68.84it/s]
# Epoch:79 bace trn_loss:0.441 trn_roc:0.872 trn_prc:0.805 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:79 bace val_loss:0.881 val_roc:0.706 val_prc:0.599 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:79 bace test_loss:0.695 test_roc:0.787 test_prc:0.719 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 70.99it/s]
# 100% 2/2 [00:00<00:00, 70.28it/s]
# Epoch:80 bace trn_loss:0.441 trn_roc:0.864 trn_prc:0.788 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:80 bace val_loss:0.888 val_roc:0.703 val_prc:0.597 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:80 bace test_loss:0.692 test_roc:0.789 test_prc:0.722 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 71.09it/s]
# 100% 2/2 [00:00<00:00, 72.31it/s]
# Epoch:81 bace trn_loss:0.420 trn_roc:0.884 trn_prc:0.814 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:81 bace val_loss:0.912 val_roc:0.701 val_prc:0.590 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:81 bace test_loss:0.710 test_roc:0.790 test_prc:0.726 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 68.61it/s]
# 100% 2/2 [00:00<00:00, 69.65it/s]
# Epoch:82 bace trn_loss:0.438 trn_roc:0.872 trn_prc:0.825 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:82 bace val_loss:0.900 val_roc:0.706 val_prc:0.596 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:82 bace test_loss:0.713 test_roc:0.787 test_prc:0.721 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.97it/s]
# 100% 2/2 [00:00<00:00, 66.76it/s]
# 100% 2/2 [00:00<00:00, 71.16it/s]
# Epoch:83 bace trn_loss:0.446 trn_roc:0.875 trn_prc:0.818 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:83 bace val_loss:0.900 val_roc:0.702 val_prc:0.593 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:83 bace test_loss:0.707 test_roc:0.782 test_prc:0.720 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 68.58it/s]
# 100% 2/2 [00:00<00:00, 69.03it/s]
# Epoch:84 bace trn_loss:0.452 trn_roc:0.860 trn_prc:0.792 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:84 bace val_loss:0.906 val_roc:0.700 val_prc:0.588 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:84 bace test_loss:0.714 test_roc:0.788 test_prc:0.730 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.85it/s]
# 100% 2/2 [00:00<00:00, 70.07it/s]
# 100% 2/2 [00:00<00:00, 72.32it/s]
# Epoch:85 bace trn_loss:0.449 trn_roc:0.868 trn_prc:0.798 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:85 bace val_loss:0.903 val_roc:0.700 val_prc:0.587 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# Epoch:85 bace test_loss:0.709 test_roc:0.788 test_prc:0.742 lr_cur:0.00012 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.92it/s]
# 100% 2/2 [00:00<00:00, 72.15it/s]
# 100% 2/2 [00:00<00:00, 72.44it/s]
# Epoch:86 bace trn_loss:0.430 trn_roc:0.880 trn_prc:0.833 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:86 bace val_loss:0.890 val_roc:0.708 val_prc:0.589 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:86 bace test_loss:0.713 test_roc:0.784 test_prc:0.730 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.96it/s]
# 100% 2/2 [00:00<00:00, 70.53it/s]
# 100% 2/2 [00:00<00:00, 67.02it/s]
# Epoch:87 bace trn_loss:0.432 trn_roc:0.873 trn_prc:0.804 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:87 bace val_loss:0.890 val_roc:0.705 val_prc:0.586 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:87 bace test_loss:0.716 test_roc:0.783 test_prc:0.719 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 28.21it/s]
# 100% 2/2 [00:00<00:00, 71.50it/s]
# 100% 2/2 [00:00<00:00, 70.29it/s]
# Epoch:88 bace trn_loss:0.449 trn_roc:0.868 trn_prc:0.803 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:88 bace val_loss:0.899 val_roc:0.701 val_prc:0.584 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:88 bace test_loss:0.728 test_roc:0.773 test_prc:0.708 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.72it/s]
# 100% 2/2 [00:00<00:00, 70.94it/s]
# 100% 2/2 [00:00<00:00, 72.01it/s]
# Epoch:89 bace trn_loss:0.448 trn_roc:0.872 trn_prc:0.804 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:89 bace val_loss:0.908 val_roc:0.699 val_prc:0.584 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# Epoch:89 bace test_loss:0.704 test_roc:0.784 test_prc:0.719 lr_cur:0.00008 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 28.07it/s]
# 100% 2/2 [00:00<00:00, 71.28it/s]
# 100% 2/2 [00:00<00:00, 72.86it/s]
# Epoch:90 bace trn_loss:0.435 trn_roc:0.872 trn_prc:0.806 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:90 bace val_loss:0.905 val_roc:0.702 val_prc:0.589 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:90 bace test_loss:0.700 test_roc:0.787 test_prc:0.724 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 70.34it/s]
# 100% 2/2 [00:00<00:00, 70.72it/s]
# Epoch:91 bace trn_loss:0.433 trn_roc:0.876 trn_prc:0.811 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:91 bace val_loss:0.901 val_roc:0.703 val_prc:0.587 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:91 bace test_loss:0.721 test_roc:0.788 test_prc:0.729 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.72it/s]
# 100% 2/2 [00:00<00:00, 71.46it/s]
# 100% 2/2 [00:00<00:00, 71.16it/s]
# Epoch:92 bace trn_loss:0.456 trn_roc:0.868 trn_prc:0.797 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:92 bace val_loss:0.907 val_roc:0.701 val_prc:0.586 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:92 bace test_loss:0.719 test_roc:0.786 test_prc:0.724 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.93it/s]
# 100% 2/2 [00:00<00:00, 69.79it/s]
# 100% 2/2 [00:00<00:00, 67.41it/s]
# Epoch:93 bace trn_loss:0.449 trn_roc:0.866 trn_prc:0.787 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:93 bace val_loss:0.903 val_roc:0.700 val_prc:0.596 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:93 bace test_loss:0.696 test_roc:0.788 test_prc:0.727 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 69.49it/s]
# 100% 2/2 [00:00<00:00, 71.19it/s]
# Epoch:94 bace trn_loss:0.427 trn_roc:0.875 trn_prc:0.807 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:94 bace val_loss:0.879 val_roc:0.708 val_prc:0.599 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:94 bace test_loss:0.702 test_roc:0.789 test_prc:0.726 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.46it/s]
# 100% 2/2 [00:00<00:00, 70.78it/s]
# 100% 2/2 [00:00<00:00, 72.29it/s]
# Epoch:95 bace trn_loss:0.432 trn_roc:0.878 trn_prc:0.822 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:95 bace val_loss:0.861 val_roc:0.720 val_prc:0.609 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:95 bace test_loss:0.711 test_roc:0.787 test_prc:0.724 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.69it/s]
# 100% 2/2 [00:00<00:00, 70.07it/s]
# 100% 2/2 [00:00<00:00, 70.61it/s]
# Epoch:96 bace trn_loss:0.432 trn_roc:0.876 trn_prc:0.809 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:96 bace val_loss:0.854 val_roc:0.722 val_prc:0.613 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# Epoch:96 bace test_loss:0.715 test_roc:0.787 test_prc:0.726 lr_cur:0.00008 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.90it/s]
# 100% 2/2 [00:00<00:00, 72.04it/s]
# 100% 2/2 [00:00<00:00, 70.08it/s]
# Epoch:97 bace trn_loss:0.446 trn_roc:0.868 trn_prc:0.809 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:97 bace val_loss:0.857 val_roc:0.720 val_prc:0.612 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:97 bace test_loss:0.715 test_roc:0.785 test_prc:0.733 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 28.12it/s]
# 100% 2/2 [00:00<00:00, 68.54it/s]
# 100% 2/2 [00:00<00:00, 57.81it/s]
# Epoch:98 bace trn_loss:0.435 trn_roc:0.876 trn_prc:0.818 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:98 bace val_loss:0.854 val_roc:0.721 val_prc:0.611 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:98 bace test_loss:0.721 test_roc:0.786 test_prc:0.728 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.87it/s]
# 100% 2/2 [00:00<00:00, 68.48it/s]
# 100% 2/2 [00:00<00:00, 69.48it/s]
# Epoch:99 bace trn_loss:0.438 trn_roc:0.878 trn_prc:0.824 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:99 bace val_loss:0.854 val_roc:0.720 val_prc:0.610 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:99 bace test_loss:0.726 test_roc:0.781 test_prc:0.722 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 28.14it/s]
# 100% 2/2 [00:00<00:00, 71.53it/s]
# 100% 2/2 [00:00<00:00, 73.59it/s]
# Epoch:100 bace trn_loss:0.439 trn_roc:0.872 trn_prc:0.813 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:100 bace val_loss:0.850 val_roc:0.721 val_prc:0.605 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:100 bace test_loss:0.728 test_roc:0.781 test_prc:0.719 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.61it/s]
# 100% 2/2 [00:00<00:00, 71.23it/s]
# 100% 2/2 [00:00<00:00, 71.82it/s]
# Epoch:101 bace trn_loss:0.444 trn_roc:0.877 trn_prc:0.812 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:101 bace val_loss:0.858 val_roc:0.717 val_prc:0.603 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:101 bace test_loss:0.723 test_roc:0.785 test_prc:0.722 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.94it/s]
# 100% 2/2 [00:00<00:00, 70.68it/s]
# 100% 2/2 [00:00<00:00, 69.02it/s]
# Epoch:102 bace trn_loss:0.437 trn_roc:0.872 trn_prc:0.810 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:102 bace val_loss:0.854 val_roc:0.716 val_prc:0.601 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:102 bace test_loss:0.718 test_roc:0.786 test_prc:0.727 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 63.01it/s]
# 100% 2/2 [00:00<00:00, 70.82it/s]
# Epoch:103 bace trn_loss:0.447 trn_roc:0.870 trn_prc:0.797 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:103 bace val_loss:0.862 val_roc:0.713 val_prc:0.599 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# Epoch:103 bace test_loss:0.710 test_roc:0.790 test_prc:0.733 lr_cur:0.00006 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.51it/s]
# 100% 2/2 [00:00<00:00, 69.59it/s]
# 100% 2/2 [00:00<00:00, 71.01it/s]
# Epoch:104 bace trn_loss:0.428 trn_roc:0.874 trn_prc:0.810 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:104 bace val_loss:0.863 val_roc:0.712 val_prc:0.594 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:104 bace test_loss:0.685 test_roc:0.790 test_prc:0.728 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.68it/s]
# 100% 2/2 [00:00<00:00, 67.59it/s]
# 100% 2/2 [00:00<00:00, 69.70it/s]
# Epoch:105 bace trn_loss:0.415 trn_roc:0.884 trn_prc:0.829 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:105 bace val_loss:0.868 val_roc:0.712 val_prc:0.595 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:105 bace test_loss:0.676 test_roc:0.786 test_prc:0.730 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.74it/s]
# 100% 2/2 [00:00<00:00, 71.52it/s]
# 100% 2/2 [00:00<00:00, 64.81it/s]
# Epoch:106 bace trn_loss:0.423 trn_roc:0.884 trn_prc:0.828 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:106 bace val_loss:0.880 val_roc:0.711 val_prc:0.596 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:106 bace test_loss:0.692 test_roc:0.786 test_prc:0.723 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 65.27it/s]
# 100% 2/2 [00:00<00:00, 72.20it/s]
# Epoch:107 bace trn_loss:0.437 trn_roc:0.870 trn_prc:0.805 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:107 bace val_loss:0.872 val_roc:0.714 val_prc:0.593 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# Epoch:107 bace test_loss:0.710 test_roc:0.787 test_prc:0.729 lr_cur:0.00006 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.70it/s]
# 100% 2/2 [00:00<00:00, 67.93it/s]
# 100% 2/2 [00:00<00:00, 71.40it/s]
# Epoch:108 bace trn_loss:0.445 trn_roc:0.868 trn_prc:0.807 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:108 bace val_loss:0.871 val_roc:0.714 val_prc:0.600 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:108 bace test_loss:0.711 test_roc:0.790 test_prc:0.724 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.39it/s]
# 100% 2/2 [00:00<00:00, 69.46it/s]
# 100% 2/2 [00:00<00:00, 71.97it/s]
# Epoch:109 bace trn_loss:0.432 trn_roc:0.879 trn_prc:0.822 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:109 bace val_loss:0.875 val_roc:0.713 val_prc:0.600 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:109 bace test_loss:0.713 test_roc:0.792 test_prc:0.722 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 68.92it/s]
# 100% 2/2 [00:00<00:00, 67.99it/s]
# Epoch:110 bace trn_loss:0.433 trn_roc:0.879 trn_prc:0.811 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:110 bace val_loss:0.876 val_roc:0.713 val_prc:0.601 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:110 bace test_loss:0.716 test_roc:0.791 test_prc:0.723 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 69.01it/s]
# 100% 2/2 [00:00<00:00, 69.04it/s]
# Epoch:111 bace trn_loss:0.421 trn_roc:0.883 trn_prc:0.832 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# Epoch:111 bace val_loss:0.888 val_roc:0.707 val_prc:0.597 lr_cur:0.00004 time elapsed 0.01 hrs (0.8 mins)
# ...
# 100% 10/10 [00:00<00:00, 27.58it/s]
# 100% 2/2 [00:00<00:00, 70.30it/s]
# 100% 2/2 [00:00<00:00, 71.95it/s]
# Epoch:163 bace trn_loss:0.427 trn_roc:0.875 trn_prc:0.802 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:163 bace val_loss:0.896 val_roc:0.712 val_prc:0.592 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:163 bace test_loss:0.734 test_roc:0.789 test_prc:0.723 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 67.76it/s]
# 100% 2/2 [00:00<00:00, 67.41it/s]
# Epoch:164 bace trn_loss:0.415 trn_roc:0.886 trn_prc:0.833 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:164 bace val_loss:0.896 val_roc:0.711 val_prc:0.590 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:164 bace test_loss:0.735 test_roc:0.788 test_prc:0.722 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.77it/s]
# 100% 2/2 [00:00<00:00, 70.38it/s]
# 100% 2/2 [00:00<00:00, 65.18it/s]
# Epoch:165 bace trn_loss:0.418 trn_roc:0.885 trn_prc:0.825 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:165 bace val_loss:0.896 val_roc:0.711 val_prc:0.591 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:165 bace test_loss:0.735 test_roc:0.789 test_prc:0.723 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 28.07it/s]
# 100% 2/2 [00:00<00:00, 68.48it/s]
# 100% 2/2 [00:00<00:00, 67.29it/s]
# Epoch:166 bace trn_loss:0.418 trn_roc:0.887 trn_prc:0.833 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:166 bace val_loss:0.897 val_roc:0.710 val_prc:0.590 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:166 bace test_loss:0.735 test_roc:0.790 test_prc:0.723 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.64it/s]
# 100% 2/2 [00:00<00:00, 66.12it/s]
# 100% 2/2 [00:00<00:00, 69.03it/s]
# Epoch:167 bace trn_loss:0.415 trn_roc:0.885 trn_prc:0.825 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:167 bace val_loss:0.899 val_roc:0.709 val_prc:0.590 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:167 bace test_loss:0.734 test_roc:0.789 test_prc:0.723 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.87it/s]
# 100% 2/2 [00:00<00:00, 71.08it/s]
# 100% 2/2 [00:00<00:00, 70.62it/s]
# Epoch:168 bace trn_loss:0.423 trn_roc:0.885 trn_prc:0.824 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:168 bace val_loss:0.901 val_roc:0.708 val_prc:0.591 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:168 bace test_loss:0.734 test_roc:0.790 test_prc:0.723 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.51it/s]
# 100% 2/2 [00:00<00:00, 71.58it/s]
# 100% 2/2 [00:00<00:00, 71.29it/s]
# Epoch:169 bace trn_loss:0.418 trn_roc:0.884 trn_prc:0.831 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:169 bace val_loss:0.902 val_roc:0.708 val_prc:0.590 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:169 bace test_loss:0.735 test_roc:0.791 test_prc:0.724 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 65.04it/s]
# 100% 2/2 [00:00<00:00, 69.27it/s]
# Epoch:170 bace trn_loss:0.418 trn_roc:0.882 trn_prc:0.822 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:170 bace val_loss:0.902 val_roc:0.707 val_prc:0.590 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:170 bace test_loss:0.736 test_roc:0.792 test_prc:0.726 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.44it/s]
# 100% 2/2 [00:00<00:00, 67.17it/s]
# 100% 2/2 [00:00<00:00, 70.86it/s]
# Epoch:171 bace trn_loss:0.440 trn_roc:0.873 trn_prc:0.813 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:171 bace val_loss:0.901 val_roc:0.709 val_prc:0.591 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:171 bace test_loss:0.736 test_roc:0.791 test_prc:0.728 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.90it/s]
# 100% 2/2 [00:00<00:00, 69.38it/s]
# 100% 2/2 [00:00<00:00, 71.38it/s]
# Epoch:172 bace trn_loss:0.421 trn_roc:0.882 trn_prc:0.827 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:172 bace val_loss:0.899 val_roc:0.709 val_prc:0.591 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:172 bace test_loss:0.734 test_roc:0.790 test_prc:0.728 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.48it/s]
# 100% 2/2 [00:00<00:00, 68.91it/s]
# 100% 2/2 [00:00<00:00, 69.96it/s]
# Epoch:173 bace trn_loss:0.414 trn_roc:0.886 trn_prc:0.827 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:173 bace val_loss:0.900 val_roc:0.710 val_prc:0.592 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# Epoch:173 bace test_loss:0.734 test_roc:0.790 test_prc:0.726 lr_cur:0.00001 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 28.05it/s]
# 100% 2/2 [00:00<00:00, 72.27it/s]
# 100% 2/2 [00:00<00:00, 62.87it/s]
# Epoch:174 bace trn_loss:0.421 trn_roc:0.877 trn_prc:0.806 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:174 bace val_loss:0.898 val_roc:0.711 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:174 bace test_loss:0.733 test_roc:0.789 test_prc:0.728 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 28.25it/s]
# 100% 2/2 [00:00<00:00, 63.65it/s]
# 100% 2/2 [00:00<00:00, 72.85it/s]
# Epoch:175 bace trn_loss:0.421 trn_roc:0.881 trn_prc:0.827 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:175 bace val_loss:0.898 val_roc:0.711 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:175 bace test_loss:0.733 test_roc:0.789 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.60it/s]
# 100% 2/2 [00:00<00:00, 65.43it/s]
# 100% 2/2 [00:00<00:00, 70.09it/s]
# Epoch:176 bace trn_loss:0.422 trn_roc:0.881 trn_prc:0.819 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:176 bace val_loss:0.899 val_roc:0.711 val_prc:0.590 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:176 bace test_loss:0.734 test_roc:0.789 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 69.61it/s]
# 100% 2/2 [00:00<00:00, 70.71it/s]
# Epoch:177 bace trn_loss:0.415 trn_roc:0.887 trn_prc:0.829 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:177 bace val_loss:0.901 val_roc:0.711 val_prc:0.593 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:177 bace test_loss:0.734 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.74it/s]
# 100% 2/2 [00:00<00:00, 68.81it/s]
# 100% 2/2 [00:00<00:00, 63.68it/s]
# Epoch:178 bace trn_loss:0.420 trn_roc:0.885 trn_prc:0.830 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:178 bace val_loss:0.902 val_roc:0.710 val_prc:0.592 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:178 bace test_loss:0.733 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.98it/s]
# 100% 2/2 [00:00<00:00, 63.99it/s]
# 100% 2/2 [00:00<00:00, 70.88it/s]
# Epoch:179 bace trn_loss:0.424 trn_roc:0.884 trn_prc:0.820 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:179 bace val_loss:0.903 val_roc:0.710 val_prc:0.592 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:179 bace test_loss:0.734 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.88it/s]
# 100% 2/2 [00:00<00:00, 65.51it/s]
# 100% 2/2 [00:00<00:00, 71.31it/s]
# Epoch:180 bace trn_loss:0.428 trn_roc:0.878 trn_prc:0.807 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:180 bace val_loss:0.903 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:180 bace test_loss:0.734 test_roc:0.789 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 28.09it/s]
# 100% 2/2 [00:00<00:00, 70.85it/s]
# 100% 2/2 [00:00<00:00, 71.28it/s]
# Epoch:181 bace trn_loss:0.425 trn_roc:0.883 trn_prc:0.821 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:181 bace val_loss:0.902 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:181 bace test_loss:0.735 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.62it/s]
# 100% 2/2 [00:00<00:00, 70.90it/s]
# 100% 2/2 [00:00<00:00, 71.92it/s]
# Epoch:182 bace trn_loss:0.404 trn_roc:0.885 trn_prc:0.818 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:182 bace val_loss:0.902 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:182 bace test_loss:0.735 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.88it/s]
# 100% 2/2 [00:00<00:00, 67.32it/s]
# 100% 2/2 [00:00<00:00, 64.93it/s]
# Epoch:183 bace trn_loss:0.423 trn_roc:0.883 trn_prc:0.810 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:183 bace val_loss:0.903 val_roc:0.709 val_prc:0.592 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:183 bace test_loss:0.736 test_roc:0.789 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 28.03it/s]
# 100% 2/2 [00:00<00:00, 66.38it/s]
# 100% 2/2 [00:00<00:00, 68.62it/s]
# Epoch:184 bace trn_loss:0.420 trn_roc:0.880 trn_prc:0.821 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:184 bace val_loss:0.905 val_roc:0.709 val_prc:0.592 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:184 bace test_loss:0.735 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 69.34it/s]
# 100% 2/2 [00:00<00:00, 69.94it/s]
# Epoch:185 bace trn_loss:0.426 trn_roc:0.877 trn_prc:0.830 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:185 bace val_loss:0.906 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:185 bace test_loss:0.734 test_roc:0.789 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.46it/s]
# 100% 2/2 [00:00<00:00, 72.13it/s]
# 100% 2/2 [00:00<00:00, 69.39it/s]
# Epoch:186 bace trn_loss:0.424 trn_roc:0.884 trn_prc:0.842 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:186 bace val_loss:0.906 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:186 bace test_loss:0.734 test_roc:0.789 test_prc:0.726 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 70.96it/s]
# 100% 2/2 [00:00<00:00, 65.01it/s]
# Epoch:187 bace trn_loss:0.417 trn_roc:0.884 trn_prc:0.826 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:187 bace val_loss:0.905 val_roc:0.709 val_prc:0.592 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# Epoch:187 bace test_loss:0.734 test_roc:0.789 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 68.54it/s]
# 100% 2/2 [00:00<00:00, 68.30it/s]
# Epoch:188 bace trn_loss:0.425 trn_roc:0.883 trn_prc:0.831 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:188 bace val_loss:0.904 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:188 bace test_loss:0.735 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 64.64it/s]
# 100% 2/2 [00:00<00:00, 71.08it/s]
# Epoch:189 bace trn_loss:0.428 trn_roc:0.878 trn_prc:0.817 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:189 bace val_loss:0.905 val_roc:0.709 val_prc:0.591 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:189 bace test_loss:0.735 test_roc:0.788 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.82it/s]
# 100% 2/2 [00:00<00:00, 72.64it/s]
# 100% 2/2 [00:00<00:00, 72.93it/s]
# Epoch:190 bace trn_loss:0.421 trn_roc:0.885 trn_prc:0.831 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:190 bace val_loss:0.905 val_roc:0.708 val_prc:0.590 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:190 bace test_loss:0.734 test_roc:0.789 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.72it/s]
# 100% 2/2 [00:00<00:00, 70.62it/s]
# 100% 2/2 [00:00<00:00, 73.06it/s]
# Epoch:191 bace trn_loss:0.412 trn_roc:0.884 trn_prc:0.826 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:191 bace val_loss:0.907 val_roc:0.707 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:191 bace test_loss:0.734 test_roc:0.789 test_prc:0.725 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.43it/s]
# 100% 2/2 [00:00<00:00, 70.33it/s]
# 100% 2/2 [00:00<00:00, 61.53it/s]
# Epoch:192 bace trn_loss:0.428 trn_roc:0.883 trn_prc:0.826 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:192 bace val_loss:0.907 val_roc:0.707 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:192 bace test_loss:0.732 test_roc:0.789 test_prc:0.726 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.54it/s]
# 100% 2/2 [00:00<00:00, 65.83it/s]
# 100% 2/2 [00:00<00:00, 72.64it/s]
# Epoch:193 bace trn_loss:0.421 trn_roc:0.882 trn_prc:0.822 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:193 bace val_loss:0.908 val_roc:0.706 val_prc:0.588 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:193 bace test_loss:0.732 test_roc:0.789 test_prc:0.726 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.45it/s]
# 100% 2/2 [00:00<00:00, 70.19it/s]
# 100% 2/2 [00:00<00:00, 68.44it/s]
# Epoch:194 bace trn_loss:0.409 trn_roc:0.885 trn_prc:0.814 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:194 bace val_loss:0.908 val_roc:0.706 val_prc:0.588 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:194 bace test_loss:0.732 test_roc:0.790 test_prc:0.726 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 71.04it/s]
# 100% 2/2 [00:00<00:00, 70.89it/s]
# Epoch:195 bace trn_loss:0.419 trn_roc:0.880 trn_prc:0.818 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:195 bace val_loss:0.907 val_roc:0.707 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:195 bace test_loss:0.732 test_roc:0.790 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 70.42it/s]
# 100% 2/2 [00:00<00:00, 68.03it/s]
# Epoch:196 bace trn_loss:0.410 trn_roc:0.885 trn_prc:0.831 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:196 bace val_loss:0.907 val_roc:0.707 val_prc:0.590 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:196 bace test_loss:0.732 test_roc:0.790 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 28.30it/s]
# 100% 2/2 [00:00<00:00, 66.17it/s]
# 100% 2/2 [00:00<00:00, 68.66it/s]
# Epoch:197 bace trn_loss:0.417 trn_roc:0.888 trn_prc:0.851 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:197 bace val_loss:0.908 val_roc:0.707 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:197 bace test_loss:0.732 test_roc:0.791 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.57it/s]
# 100% 2/2 [00:00<00:00, 66.34it/s]
# 100% 2/2 [00:00<00:00, 70.06it/s]
# Epoch:198 bace trn_loss:0.410 trn_roc:0.884 trn_prc:0.822 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:198 bace val_loss:0.908 val_roc:0.707 val_prc:0.589 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:198 bace test_loss:0.733 test_roc:0.791 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.53it/s]
# 100% 2/2 [00:00<00:00, 68.17it/s]
# 100% 2/2 [00:00<00:00, 71.05it/s]
# Epoch:199 bace trn_loss:0.415 trn_roc:0.888 trn_prc:0.840 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:199 bace val_loss:0.907 val_roc:0.707 val_prc:0.590 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Epoch:199 bace test_loss:0.733 test_roc:0.791 test_prc:0.727 lr_cur:0.00000 time elapsed 0.02 hrs (1.4 mins)
# Model saved at epoch 199
# Testing...
# The best ckpt is ../test/06-02-21-53/best_model.ckpt
# Ckpt loading: ../test/06-02-21-53/best_model.ckpt
# 100% 2/2 [00:00<00:00, 71.73it/s]
# SEED 1234 DATASET bace  The best test_loss:0.733 test_roc:0.791 test_prc:0.727.

# %% [markdown]
# For drug dataset

# %%
# %cd TrimNet/trimnet_drug/source
# !python run.py --dataset bace --gpu 0
# Out:
# /content/TrimNet/trimnet_drug/source
# ################################################################################
# ################################################################################
# train set num:1216    valid set num:143    test set num: 154
# total parameters:98018
# ################################################################################
# ################################################################################
# Training start...
# 100% 10/10 [00:01<00:00,  8.82it/s]
# 100% 2/2 [00:00<00:00,  9.91it/s]
# 100% 2/2 [00:00<00:00, 52.19it/s]
# Epoch:0 bace trn_loss:0.711 trn_roc:0.527 trn_prc:0.476 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:0 bace val_loss:0.709 val_roc:0.357 val_prc:0.377 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:0 bace test_loss:0.696 test_roc:0.492 test_prc:0.395 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 0
# 100% 10/10 [00:00<00:00, 27.38it/s]
# 100% 2/2 [00:00<00:00, 73.88it/s]
# 100% 2/2 [00:00<00:00, 67.09it/s]
# Epoch:1 bace trn_loss:0.695 trn_roc:0.558 trn_prc:0.510 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:1 bace val_loss:0.684 val_roc:0.574 val_prc:0.489 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:1 bace test_loss:0.690 test_roc:0.597 test_prc:0.487 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Model saved at epoch 1
# 100% 10/10 [00:00<00:00, 27.91it/s]
# 100% 2/2 [00:00<00:00, 69.83it/s]
# 100% 2/2 [00:00<00:00, 72.32it/s]
# Epoch:2 bace trn_loss:0.706 trn_roc:0.520 trn_prc:0.471 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:2 bace val_loss:0.695 val_roc:0.522 val_prc:0.449 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:2 bace test_loss:0.698 test_roc:0.552 test_prc:0.422 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# 100% 10/10 [00:00<00:00, 27.78it/s]
# 100% 2/2 [00:00<00:00, 65.07it/s]
# 100% 2/2 [00:00<00:00, 67.36it/s]
# Epoch:3 bace trn_loss:0.714 trn_roc:0.483 trn_prc:0.440 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:3 bace val_loss:0.700 val_roc:0.530 val_prc:0.450 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# Epoch:3 bace test_loss:0.719 test_roc:0.600 test_prc:0.455 lr_cur:0.00100 time elapsed 0.00 hrs (0.0 mins)
# 100% 10/10 [00:00<00:00, 27.66it/s]
# 100% 2/2 [00:00<00:00, 73.65it/s]
# 100% 2/2 [00:00<00:00, 69.46it/s]
# Epoch:4 bace trn_loss:0.699 trn_roc:0.529 trn_prc:0.476 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:4 bace val_loss:0.694 val_roc:0.528 val_prc:0.453 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:4 bace test_loss:0.681 test_roc:0.658 test_prc:0.498 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.98it/s]
# 100% 2/2 [00:00<00:00, 73.54it/s]
# 100% 2/2 [00:00<00:00, 69.64it/s]
# Epoch:5 bace trn_loss:0.694 trn_roc:0.543 trn_prc:0.492 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:5 bace val_loss:0.668 val_roc:0.552 val_prc:0.576 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:5 bace test_loss:0.670 test_roc:0.580 test_prc:0.436 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 5
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 70.55it/s]
# 100% 2/2 [00:00<00:00, 71.95it/s]
# Epoch:6 bace trn_loss:0.685 trn_roc:0.572 trn_prc:0.490 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:6 bace val_loss:0.663 val_roc:0.632 val_prc:0.575 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:6 bace test_loss:0.661 test_roc:0.692 test_prc:0.587 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 6
# 100% 10/10 [00:00<00:00, 27.79it/s]
# 100% 2/2 [00:00<00:00, 68.80it/s]
# 100% 2/2 [00:00<00:00, 70.82it/s]
# Epoch:7 bace trn_loss:0.682 trn_roc:0.575 trn_prc:0.517 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:7 bace val_loss:0.656 val_roc:0.582 val_prc:0.515 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:7 bace test_loss:0.667 test_roc:0.591 test_prc:0.465 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.82it/s]
# 100% 2/2 [00:00<00:00, 69.70it/s]
# 100% 2/2 [00:00<00:00, 71.55it/s]
# Epoch:8 bace trn_loss:0.683 trn_roc:0.586 trn_prc:0.517 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:8 bace val_loss:0.654 val_roc:0.596 val_prc:0.544 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:8 bace test_loss:0.646 test_roc:0.637 test_prc:0.514 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.77it/s]
# 100% 2/2 [00:00<00:00, 73.12it/s]
# 100% 2/2 [00:00<00:00, 72.06it/s]
# Epoch:9 bace trn_loss:0.684 trn_roc:0.587 trn_prc:0.520 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:9 bace val_loss:0.651 val_roc:0.596 val_prc:0.555 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:9 bace test_loss:0.653 test_roc:0.649 test_prc:0.542 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.95it/s]
# 100% 2/2 [00:00<00:00, 69.94it/s]
# 100% 2/2 [00:00<00:00, 65.08it/s]
# Epoch:10 bace trn_loss:0.656 trn_roc:0.639 trn_prc:0.570 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:10 bace val_loss:0.649 val_roc:0.618 val_prc:0.586 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:10 bace test_loss:0.643 test_roc:0.678 test_prc:0.587 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 10
# 100% 10/10 [00:00<00:00, 27.07it/s]
# 100% 2/2 [00:00<00:00, 70.03it/s]
# 100% 2/2 [00:00<00:00, 70.64it/s]
# Epoch:11 bace trn_loss:0.660 trn_roc:0.623 trn_prc:0.533 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:11 bace val_loss:0.656 val_roc:0.601 val_prc:0.587 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:11 bace test_loss:0.629 test_roc:0.702 test_prc:0.594 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 11
# 100% 10/10 [00:00<00:00, 27.52it/s]
# 100% 2/2 [00:00<00:00, 73.19it/s]
# 100% 2/2 [00:00<00:00, 72.36it/s]
# Epoch:12 bace trn_loss:0.651 trn_roc:0.648 trn_prc:0.575 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:12 bace val_loss:0.678 val_roc:0.615 val_prc:0.575 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:12 bace test_loss:0.654 test_roc:0.715 test_prc:0.596 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.57it/s]
# 100% 2/2 [00:00<00:00, 70.50it/s]
# 100% 2/2 [00:00<00:00, 69.43it/s]
# Epoch:13 bace trn_loss:0.628 trn_roc:0.703 trn_prc:0.632 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:13 bace val_loss:0.707 val_roc:0.628 val_prc:0.596 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:13 bace test_loss:0.677 test_roc:0.702 test_prc:0.578 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 13
# 100% 10/10 [00:00<00:00, 27.89it/s]
# 100% 2/2 [00:00<00:00, 71.91it/s]
# 100% 2/2 [00:00<00:00, 67.66it/s]
# Epoch:14 bace trn_loss:0.644 trn_roc:0.685 trn_prc:0.605 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:14 bace val_loss:0.759 val_roc:0.640 val_prc:0.587 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:14 bace test_loss:0.675 test_roc:0.750 test_prc:0.628 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 14
# 100% 10/10 [00:00<00:00, 27.92it/s]
# 100% 2/2 [00:00<00:00, 66.47it/s]
# 100% 2/2 [00:00<00:00, 68.20it/s]
# Epoch:15 bace trn_loss:0.623 trn_roc:0.706 trn_prc:0.614 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:15 bace val_loss:0.692 val_roc:0.621 val_prc:0.588 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:15 bace test_loss:0.627 test_roc:0.748 test_prc:0.627 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# 100% 10/10 [00:00<00:00, 27.60it/s]
# 100% 2/2 [00:00<00:00, 72.54it/s]
# 100% 2/2 [00:00<00:00, 71.85it/s]
# Epoch:16 bace trn_loss:0.612 trn_roc:0.722 trn_prc:0.652 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:16 bace val_loss:0.726 val_roc:0.629 val_prc:0.602 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:16 bace test_loss:0.660 test_roc:0.740 test_prc:0.625 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 16
# 100% 10/10 [00:00<00:00, 27.89it/s]
# 100% 2/2 [00:00<00:00, 72.88it/s]
# 100% 2/2 [00:00<00:00, 71.57it/s]
# Epoch:17 bace trn_loss:0.613 trn_roc:0.716 trn_prc:0.620 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:17 bace val_loss:0.644 val_roc:0.648 val_prc:0.613 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Epoch:17 bace test_loss:0.651 test_roc:0.719 test_prc:0.612 lr_cur:0.00100 time elapsed 0.00 hrs (0.1 mins)
# Model saved at epoch 17
# 100% 10/10 [00:00<00:00, 28.12it/s]
# 100% 2/2 [00:00<00:00, 72.98it/s]
# 100% 2/2 [00:00<00:00, 64.41it/s]
# Epoch:18 bace trn_loss:0.599 trn_roc:0.725 trn_prc:0.621 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:18 bace val_loss:0.766 val_roc:0.627 val_prc:0.595 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:18 bace test_loss:0.654 test_roc:0.745 test_prc:0.631 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.28it/s]
# 100% 2/2 [00:00<00:00, 69.49it/s]
# 100% 2/2 [00:00<00:00, 70.94it/s]
# Epoch:19 bace trn_loss:0.617 trn_roc:0.706 trn_prc:0.607 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:19 bace val_loss:0.661 val_roc:0.614 val_prc:0.585 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:19 bace test_loss:0.638 test_roc:0.737 test_prc:0.626 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.89it/s]
# 100% 2/2 [00:00<00:00, 65.79it/s]
# 100% 2/2 [00:00<00:00, 68.02it/s]
# Epoch:20 bace trn_loss:0.609 trn_roc:0.707 trn_prc:0.595 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:20 bace val_loss:0.732 val_roc:0.644 val_prc:0.612 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:20 bace test_loss:0.692 test_roc:0.744 test_prc:0.639 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.35it/s]
# 100% 2/2 [00:00<00:00, 65.75it/s]
# 100% 2/2 [00:00<00:00, 68.44it/s]
# Epoch:21 bace trn_loss:0.605 trn_roc:0.725 trn_prc:0.661 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:21 bace val_loss:0.642 val_roc:0.611 val_prc:0.580 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:21 bace test_loss:0.647 test_roc:0.750 test_prc:0.644 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.73it/s]
# 100% 2/2 [00:00<00:00, 73.52it/s]
# 100% 2/2 [00:00<00:00, 68.07it/s]
# Epoch:22 bace trn_loss:0.599 trn_roc:0.724 trn_prc:0.626 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:22 bace val_loss:0.647 val_roc:0.626 val_prc:0.588 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:22 bace test_loss:0.655 test_roc:0.736 test_prc:0.633 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 71.77it/s]
# 100% 2/2 [00:00<00:00, 70.38it/s]
# Epoch:23 bace trn_loss:0.589 trn_roc:0.741 trn_prc:0.650 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:23 bace val_loss:0.653 val_roc:0.623 val_prc:0.595 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:23 bace test_loss:0.653 test_roc:0.755 test_prc:0.646 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.64it/s]
# 100% 2/2 [00:00<00:00, 67.92it/s]
# 100% 2/2 [00:00<00:00, 72.37it/s]
# Epoch:24 bace trn_loss:0.565 trn_roc:0.755 trn_prc:0.652 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:24 bace val_loss:0.649 val_roc:0.638 val_prc:0.574 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:24 bace test_loss:0.687 test_roc:0.744 test_prc:0.678 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.88it/s]
# 100% 2/2 [00:00<00:00, 73.53it/s]
# 100% 2/2 [00:00<00:00, 71.31it/s]
# Epoch:25 bace trn_loss:0.588 trn_roc:0.756 trn_prc:0.671 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:25 bace val_loss:0.617 val_roc:0.659 val_prc:0.622 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:25 bace test_loss:0.637 test_roc:0.768 test_prc:0.684 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Model saved at epoch 25
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 71.75it/s]
# 100% 2/2 [00:00<00:00, 71.06it/s]
# Epoch:26 bace trn_loss:0.574 trn_roc:0.759 trn_prc:0.684 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:26 bace val_loss:0.700 val_roc:0.626 val_prc:0.579 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:26 bace test_loss:0.642 test_roc:0.769 test_prc:0.687 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 28.02it/s]
# 100% 2/2 [00:00<00:00, 72.00it/s]
# 100% 2/2 [00:00<00:00, 67.54it/s]
# Epoch:27 bace trn_loss:0.566 trn_roc:0.764 trn_prc:0.685 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:27 bace val_loss:0.697 val_roc:0.633 val_prc:0.597 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:27 bace test_loss:0.651 test_roc:0.766 test_prc:0.703 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.61it/s]
# 100% 2/2 [00:00<00:00, 70.94it/s]
# 100% 2/2 [00:00<00:00, 70.80it/s]
# Epoch:28 bace trn_loss:0.555 trn_roc:0.769 trn_prc:0.669 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:28 bace val_loss:0.625 val_roc:0.639 val_prc:0.584 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:28 bace test_loss:0.621 test_roc:0.781 test_prc:0.757 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.87it/s]
# 100% 2/2 [00:00<00:00, 68.94it/s]
# 100% 2/2 [00:00<00:00, 70.40it/s]
# Epoch:29 bace trn_loss:0.545 trn_roc:0.781 trn_prc:0.714 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:29 bace val_loss:0.652 val_roc:0.637 val_prc:0.558 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:29 bace test_loss:0.629 test_roc:0.789 test_prc:0.764 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.49it/s]
# 100% 2/2 [00:00<00:00, 68.96it/s]
# 100% 2/2 [00:00<00:00, 69.37it/s]
# Epoch:30 bace trn_loss:0.562 trn_roc:0.773 trn_prc:0.690 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:30 bace val_loss:0.651 val_roc:0.671 val_prc:0.592 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:30 bace test_loss:0.680 test_roc:0.777 test_prc:0.677 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Model saved at epoch 30
# 100% 10/10 [00:00<00:00, 28.12it/s]
# 100% 2/2 [00:00<00:00, 74.46it/s]
# 100% 2/2 [00:00<00:00, 71.82it/s]
# Epoch:31 bace trn_loss:0.532 trn_roc:0.800 trn_prc:0.731 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:31 bace val_loss:0.637 val_roc:0.657 val_prc:0.592 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# Epoch:31 bace test_loss:0.627 test_roc:0.780 test_prc:0.716 lr_cur:0.00100 time elapsed 0.00 hrs (0.2 mins)
# 100% 10/10 [00:00<00:00, 27.84it/s]
# 100% 2/2 [00:00<00:00, 71.63it/s]
# 100% 2/2 [00:00<00:00, 66.64it/s]
# Epoch:32 bace trn_loss:0.533 trn_roc:0.802 trn_prc:0.732 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:32 bace val_loss:0.637 val_roc:0.674 val_prc:0.618 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:32 bace test_loss:0.624 test_roc:0.785 test_prc:0.711 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Model saved at epoch 32
# 100% 10/10 [00:00<00:00, 27.83it/s]
# 100% 2/2 [00:00<00:00, 70.32it/s]
# 100% 2/2 [00:00<00:00, 72.19it/s]
# Epoch:33 bace trn_loss:0.552 trn_roc:0.795 trn_prc:0.718 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:33 bace val_loss:0.624 val_roc:0.681 val_prc:0.631 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:33 bace test_loss:0.606 test_roc:0.803 test_prc:0.757 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Model saved at epoch 33
# 100% 10/10 [00:00<00:00, 27.81it/s]
# 100% 2/2 [00:00<00:00, 69.82it/s]
# 100% 2/2 [00:00<00:00, 70.53it/s]
# Epoch:34 bace trn_loss:0.520 trn_roc:0.807 trn_prc:0.726 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:34 bace val_loss:0.622 val_roc:0.680 val_prc:0.564 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:34 bace test_loss:0.612 test_roc:0.795 test_prc:0.753 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.70it/s]
# 100% 2/2 [00:00<00:00, 72.54it/s]
# 100% 2/2 [00:00<00:00, 72.02it/s]
# Epoch:35 bace trn_loss:0.528 trn_roc:0.813 trn_prc:0.747 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:35 bace val_loss:0.642 val_roc:0.737 val_prc:0.681 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:35 bace test_loss:0.643 test_roc:0.794 test_prc:0.734 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Model saved at epoch 35
# 100% 10/10 [00:00<00:00, 27.84it/s]
# 100% 2/2 [00:00<00:00, 74.44it/s]
# 100% 2/2 [00:00<00:00, 67.37it/s]
# Epoch:36 bace trn_loss:0.554 trn_roc:0.786 trn_prc:0.726 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:36 bace val_loss:0.611 val_roc:0.723 val_prc:0.664 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:36 bace test_loss:0.579 test_roc:0.806 test_prc:0.799 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.81it/s]
# 100% 2/2 [00:00<00:00, 71.29it/s]
# 100% 2/2 [00:00<00:00, 68.35it/s]
# Epoch:37 bace trn_loss:0.515 trn_roc:0.811 trn_prc:0.734 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:37 bace val_loss:0.638 val_roc:0.719 val_prc:0.667 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:37 bace test_loss:0.618 test_roc:0.794 test_prc:0.761 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.90it/s]
# 100% 2/2 [00:00<00:00, 71.85it/s]
# 100% 2/2 [00:00<00:00, 71.49it/s]
# Epoch:38 bace trn_loss:0.512 trn_roc:0.812 trn_prc:0.722 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:38 bace val_loss:0.581 val_roc:0.709 val_prc:0.626 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# Epoch:38 bace test_loss:0.616 test_roc:0.781 test_prc:0.721 lr_cur:0.00100 time elapsed 0.00 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.61it/s]
# 100% 2/2 [00:00<00:00, 69.53it/s]
# 100% 2/2 [00:00<00:00, 69.42it/s]
# Epoch:39 bace trn_loss:0.509 trn_roc:0.816 trn_prc:0.742 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:39 bace val_loss:0.582 val_roc:0.697 val_prc:0.628 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:39 bace test_loss:0.638 test_roc:0.784 test_prc:0.704 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.58it/s]
# 100% 2/2 [00:00<00:00, 70.74it/s]
# 100% 2/2 [00:00<00:00, 69.93it/s]
# Epoch:40 bace trn_loss:0.496 trn_roc:0.826 trn_prc:0.757 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:40 bace val_loss:0.617 val_roc:0.728 val_prc:0.688 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:40 bace test_loss:0.608 test_roc:0.803 test_prc:0.772 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Model saved at epoch 40
# 100% 10/10 [00:00<00:00, 27.66it/s]
# 100% 2/2 [00:00<00:00, 69.48it/s]
# 100% 2/2 [00:00<00:00, 58.14it/s]
# Epoch:41 bace trn_loss:0.492 trn_roc:0.822 trn_prc:0.748 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:41 bace val_loss:0.630 val_roc:0.721 val_prc:0.685 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:41 bace test_loss:0.618 test_roc:0.797 test_prc:0.755 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 67.77it/s]
# 100% 2/2 [00:00<00:00, 71.33it/s]
# Epoch:42 bace trn_loss:0.504 trn_roc:0.827 trn_prc:0.765 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:42 bace val_loss:0.599 val_roc:0.775 val_prc:0.720 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:42 bace test_loss:0.642 test_roc:0.802 test_prc:0.726 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Model saved at epoch 42
# 100% 10/10 [00:00<00:00, 27.84it/s]
# 100% 2/2 [00:00<00:00, 67.46it/s]
# 100% 2/2 [00:00<00:00, 66.07it/s]
# Epoch:43 bace trn_loss:0.524 trn_roc:0.807 trn_prc:0.740 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:43 bace val_loss:0.586 val_roc:0.767 val_prc:0.742 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:43 bace test_loss:0.636 test_roc:0.810 test_prc:0.738 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Model saved at epoch 43
# 100% 10/10 [00:00<00:00, 27.39it/s]
# 100% 2/2 [00:00<00:00, 73.84it/s]
# 100% 2/2 [00:00<00:00, 65.95it/s]
# Epoch:44 bace trn_loss:0.519 trn_roc:0.814 trn_prc:0.750 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:44 bace val_loss:0.606 val_roc:0.754 val_prc:0.746 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:44 bace test_loss:0.659 test_roc:0.788 test_prc:0.733 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Model saved at epoch 44
# 100% 10/10 [00:00<00:00, 27.88it/s]
# 100% 2/2 [00:00<00:00, 68.00it/s]
# 100% 2/2 [00:00<00:00, 71.16it/s]
# Epoch:45 bace trn_loss:0.491 trn_roc:0.832 trn_prc:0.771 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:45 bace val_loss:0.591 val_roc:0.718 val_prc:0.676 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# Epoch:45 bace test_loss:0.650 test_roc:0.794 test_prc:0.738 lr_cur:0.00100 time elapsed 0.01 hrs (0.3 mins)
# 100% 10/10 [00:00<00:00, 27.11it/s]
# 100% 2/2 [00:00<00:00, 70.87it/s]
# 100% 2/2 [00:00<00:00, 69.26it/s]
# Epoch:46 bace trn_loss:0.483 trn_roc:0.839 trn_prc:0.779 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:46 bace val_loss:0.626 val_roc:0.762 val_prc:0.710 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:46 bace test_loss:0.613 test_roc:0.802 test_prc:0.734 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 70.82it/s]
# 100% 2/2 [00:00<00:00, 71.13it/s]
# Epoch:47 bace trn_loss:0.495 trn_roc:0.837 trn_prc:0.781 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:47 bace val_loss:0.579 val_roc:0.756 val_prc:0.690 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:47 bace test_loss:0.642 test_roc:0.774 test_prc:0.694 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.77it/s]
# 100% 2/2 [00:00<00:00, 72.16it/s]
# 100% 2/2 [00:00<00:00, 63.20it/s]
# Epoch:48 bace trn_loss:0.508 trn_roc:0.821 trn_prc:0.755 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:48 bace val_loss:0.532 val_roc:0.807 val_prc:0.768 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:48 bace test_loss:0.605 test_roc:0.784 test_prc:0.750 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Model saved at epoch 48
# 100% 10/10 [00:00<00:00, 27.96it/s]
# 100% 2/2 [00:00<00:00, 68.62it/s]
# 100% 2/2 [00:00<00:00, 70.98it/s]
# Epoch:49 bace trn_loss:0.486 trn_roc:0.839 trn_prc:0.784 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:49 bace val_loss:0.582 val_roc:0.782 val_prc:0.720 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:49 bace test_loss:0.641 test_roc:0.785 test_prc:0.717 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.79it/s]
# 100% 2/2 [00:00<00:00, 71.60it/s]
# 100% 2/2 [00:00<00:00, 69.51it/s]
# Epoch:50 bace trn_loss:0.478 trn_roc:0.845 trn_prc:0.782 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:50 bace val_loss:0.573 val_roc:0.762 val_prc:0.704 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:50 bace test_loss:0.656 test_roc:0.805 test_prc:0.743 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.24it/s]
# 100% 2/2 [00:00<00:00, 69.41it/s]
# 100% 2/2 [00:00<00:00, 68.71it/s]
# Epoch:51 bace trn_loss:0.469 trn_roc:0.850 trn_prc:0.799 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:51 bace val_loss:0.543 val_roc:0.807 val_prc:0.772 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:51 bace test_loss:0.631 test_roc:0.809 test_prc:0.785 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Model saved at epoch 51
# 100% 10/10 [00:00<00:00, 27.68it/s]
# 100% 2/2 [00:00<00:00, 71.28it/s]
# 100% 2/2 [00:00<00:00, 66.54it/s]
# Epoch:52 bace trn_loss:0.478 trn_roc:0.844 trn_prc:0.782 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:52 bace val_loss:0.573 val_roc:0.797 val_prc:0.765 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:52 bace test_loss:0.660 test_roc:0.807 test_prc:0.778 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.63it/s]
# 100% 2/2 [00:00<00:00, 68.19it/s]
# 100% 2/2 [00:00<00:00, 69.56it/s]
# Epoch:53 bace trn_loss:0.462 trn_roc:0.848 trn_prc:0.793 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:53 bace val_loss:0.509 val_roc:0.799 val_prc:0.769 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:53 bace test_loss:0.626 test_roc:0.805 test_prc:0.759 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.36it/s]
# 100% 2/2 [00:00<00:00, 69.50it/s]
# 100% 2/2 [00:00<00:00, 71.03it/s]
# Epoch:54 bace trn_loss:0.470 trn_roc:0.852 trn_prc:0.790 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:54 bace val_loss:0.544 val_roc:0.824 val_prc:0.781 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:54 bace test_loss:0.664 test_roc:0.798 test_prc:0.746 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Model saved at epoch 54
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 73.25it/s]
# 100% 2/2 [00:00<00:00, 69.59it/s]
# Epoch:55 bace trn_loss:0.469 trn_roc:0.850 trn_prc:0.791 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:55 bace val_loss:0.592 val_roc:0.785 val_prc:0.746 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:55 bace test_loss:0.703 test_roc:0.791 test_prc:0.754 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.79it/s]
# 100% 2/2 [00:00<00:00, 74.03it/s]
# 100% 2/2 [00:00<00:00, 71.60it/s]
# Epoch:56 bace trn_loss:0.485 trn_roc:0.840 trn_prc:0.760 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:56 bace val_loss:0.562 val_roc:0.744 val_prc:0.676 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:56 bace test_loss:0.684 test_roc:0.783 test_prc:0.733 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.76it/s]
# 100% 2/2 [00:00<00:00, 70.28it/s]
# 100% 2/2 [00:00<00:00, 71.33it/s]
# Epoch:57 bace trn_loss:0.474 trn_roc:0.841 trn_prc:0.768 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:57 bace val_loss:0.530 val_roc:0.755 val_prc:0.686 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:57 bace test_loss:0.672 test_roc:0.787 test_prc:0.720 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.50it/s]
# 100% 2/2 [00:00<00:00, 72.54it/s]
# 100% 2/2 [00:00<00:00, 69.50it/s]
# Epoch:58 bace trn_loss:0.475 trn_roc:0.846 trn_prc:0.780 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:58 bace val_loss:0.557 val_roc:0.798 val_prc:0.767 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:58 bace test_loss:0.632 test_roc:0.831 test_prc:0.789 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# 100% 10/10 [00:00<00:00, 27.45it/s]
# 100% 2/2 [00:00<00:00, 74.51it/s]
# 100% 2/2 [00:00<00:00, 72.02it/s]
# Epoch:59 bace trn_loss:0.452 trn_roc:0.865 trn_prc:0.822 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:59 bace val_loss:0.510 val_roc:0.817 val_prc:0.794 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Epoch:59 bace test_loss:0.627 test_roc:0.817 test_prc:0.780 lr_cur:0.00100 time elapsed 0.01 hrs (0.4 mins)
# Model saved at epoch 59
# 100% 10/10 [00:00<00:00, 27.95it/s]
# 100% 2/2 [00:00<00:00, 73.20it/s]
# 100% 2/2 [00:00<00:00, 72.46it/s]
# Epoch:60 bace trn_loss:0.452 trn_roc:0.864 trn_prc:0.815 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:60 bace val_loss:0.470 val_roc:0.811 val_prc:0.775 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:60 bace test_loss:0.618 test_roc:0.827 test_prc:0.796 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.29it/s]
# 100% 2/2 [00:00<00:00, 70.00it/s]
# 100% 2/2 [00:00<00:00, 69.09it/s]
# Epoch:61 bace trn_loss:0.452 trn_roc:0.861 trn_prc:0.815 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:61 bace val_loss:0.477 val_roc:0.835 val_prc:0.805 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:61 bace test_loss:0.626 test_roc:0.828 test_prc:0.794 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Model saved at epoch 61
# 100% 10/10 [00:00<00:00, 27.96it/s]
# 100% 2/2 [00:00<00:00, 68.45it/s]
# 100% 2/2 [00:00<00:00, 70.62it/s]
# Epoch:62 bace trn_loss:0.454 trn_roc:0.863 trn_prc:0.805 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:62 bace val_loss:0.517 val_roc:0.819 val_prc:0.789 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:62 bace test_loss:0.667 test_roc:0.813 test_prc:0.780 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.41it/s]
# 100% 2/2 [00:00<00:00, 71.88it/s]
# 100% 2/2 [00:00<00:00, 71.13it/s]
# Epoch:63 bace trn_loss:0.450 trn_roc:0.858 trn_prc:0.788 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:63 bace val_loss:0.485 val_roc:0.800 val_prc:0.770 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:63 bace test_loss:0.650 test_roc:0.813 test_prc:0.792 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.72it/s]
# 100% 2/2 [00:00<00:00, 71.34it/s]
# 100% 2/2 [00:00<00:00, 69.03it/s]
# Epoch:64 bace trn_loss:0.464 trn_roc:0.843 trn_prc:0.787 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:64 bace val_loss:0.495 val_roc:0.812 val_prc:0.776 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:64 bace test_loss:0.639 test_roc:0.819 test_prc:0.769 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.26it/s]
# 100% 2/2 [00:00<00:00, 71.70it/s]
# 100% 2/2 [00:00<00:00, 69.99it/s]
# Epoch:65 bace trn_loss:0.437 trn_roc:0.869 trn_prc:0.824 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:65 bace val_loss:0.527 val_roc:0.827 val_prc:0.806 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:65 bace test_loss:0.684 test_roc:0.811 test_prc:0.749 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Model saved at epoch 65
# 100% 10/10 [00:00<00:00, 27.82it/s]
# 100% 2/2 [00:00<00:00, 69.99it/s]
# 100% 2/2 [00:00<00:00, 72.31it/s]
# Epoch:66 bace trn_loss:0.462 trn_roc:0.859 trn_prc:0.802 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:66 bace val_loss:0.540 val_roc:0.787 val_prc:0.735 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:66 bace test_loss:0.662 test_roc:0.816 test_prc:0.792 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.32it/s]
# 100% 2/2 [00:00<00:00, 73.86it/s]
# 100% 2/2 [00:00<00:00, 72.53it/s]
# Epoch:67 bace trn_loss:0.449 trn_roc:0.862 trn_prc:0.811 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:67 bace val_loss:0.508 val_roc:0.812 val_prc:0.764 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:67 bace test_loss:0.680 test_roc:0.822 test_prc:0.791 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.78it/s]
# 100% 2/2 [00:00<00:00, 70.82it/s]
# 100% 2/2 [00:00<00:00, 70.04it/s]
# Epoch:68 bace trn_loss:0.468 trn_roc:0.853 trn_prc:0.797 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:68 bace val_loss:0.494 val_roc:0.804 val_prc:0.761 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:68 bace test_loss:0.615 test_roc:0.826 test_prc:0.800 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.67it/s]
# 100% 2/2 [00:00<00:00, 71.60it/s]
# 100% 2/2 [00:00<00:00, 66.85it/s]
# Epoch:69 bace trn_loss:0.463 trn_roc:0.859 trn_prc:0.812 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:69 bace val_loss:0.492 val_roc:0.829 val_prc:0.808 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:69 bace test_loss:0.652 test_roc:0.814 test_prc:0.773 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Model saved at epoch 69
# 100% 10/10 [00:00<00:00, 27.23it/s]
# 100% 2/2 [00:00<00:00, 68.19it/s]
# 100% 2/2 [00:00<00:00, 71.67it/s]
# Epoch:70 bace trn_loss:0.437 trn_roc:0.868 trn_prc:0.822 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:70 bace val_loss:0.486 val_roc:0.833 val_prc:0.787 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# Epoch:70 bace test_loss:0.640 test_roc:0.838 test_prc:0.794 lr_cur:0.00100 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.65it/s]
# 100% 2/2 [00:00<00:00, 72.08it/s]
# 100% 2/2 [00:00<00:00, 70.57it/s]
# Epoch:71 bace trn_loss:0.471 trn_roc:0.859 trn_prc:0.801 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# Epoch:71 bace val_loss:0.542 val_roc:0.762 val_prc:0.691 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# Epoch:71 bace test_loss:0.738 test_roc:0.812 test_prc:0.752 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.54it/s]
# 100% 2/2 [00:00<00:00, 74.04it/s]
# 100% 2/2 [00:00<00:00, 72.28it/s]
# Epoch:72 bace trn_loss:0.475 trn_roc:0.850 trn_prc:0.792 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# Epoch:72 bace val_loss:0.541 val_roc:0.756 val_prc:0.670 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# Epoch:72 bace test_loss:0.649 test_roc:0.809 test_prc:0.752 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 73.62it/s]
# 100% 2/2 [00:00<00:00, 65.70it/s]
# Epoch:73 bace trn_loss:0.461 trn_roc:0.851 trn_prc:0.791 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# Epoch:73 bace val_loss:0.523 val_roc:0.805 val_prc:0.739 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# Epoch:73 bace test_loss:0.656 test_roc:0.808 test_prc:0.775 lr_cur:0.00070 time elapsed 0.01 hrs (0.5 mins)
# 100% 10/10 [00:00<00:00, 27.90it/s]
# 100% 2/2 [00:00<00:00, 67.58it/s]
# 100% 2/2 [00:00<00:00, 71.35it/s]
# Epoch:74 bace trn_loss:0.479 trn_roc:0.845 trn_prc:0.774 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:74 bace val_loss:0.519 val_roc:0.799 val_prc:0.760 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:74 bace test_loss:0.690 test_roc:0.798 test_prc:0.776 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.42it/s]
# 100% 2/2 [00:00<00:00, 69.19it/s]
# 100% 2/2 [00:00<00:00, 67.21it/s]
# Epoch:75 bace trn_loss:0.447 trn_roc:0.866 trn_prc:0.814 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:75 bace val_loss:0.509 val_roc:0.797 val_prc:0.739 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:75 bace test_loss:0.643 test_roc:0.800 test_prc:0.786 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.23it/s]
# 100% 2/2 [00:00<00:00, 72.24it/s]
# 100% 2/2 [00:00<00:00, 70.95it/s]
# Epoch:76 bace trn_loss:0.419 trn_roc:0.879 trn_prc:0.831 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:76 bace val_loss:0.500 val_roc:0.798 val_prc:0.748 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:76 bace test_loss:0.667 test_roc:0.803 test_prc:0.786 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.50it/s]
# 100% 2/2 [00:00<00:00, 73.27it/s]
# 100% 2/2 [00:00<00:00, 67.00it/s]
# Epoch:77 bace trn_loss:0.438 trn_roc:0.869 trn_prc:0.826 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:77 bace val_loss:0.488 val_roc:0.793 val_prc:0.735 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:77 bace test_loss:0.650 test_roc:0.811 test_prc:0.781 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.35it/s]
# 100% 2/2 [00:00<00:00, 68.20it/s]
# 100% 2/2 [00:00<00:00, 71.13it/s]
# Epoch:78 bace trn_loss:0.439 trn_roc:0.867 trn_prc:0.813 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:78 bace val_loss:0.477 val_roc:0.815 val_prc:0.768 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:78 bace test_loss:0.664 test_roc:0.825 test_prc:0.796 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.42it/s]
# 100% 2/2 [00:00<00:00, 72.36it/s]
# 100% 2/2 [00:00<00:00, 71.93it/s]
# Epoch:79 bace trn_loss:0.425 trn_roc:0.876 trn_prc:0.827 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:79 bace val_loss:0.500 val_roc:0.792 val_prc:0.732 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:79 bace test_loss:0.653 test_roc:0.819 test_prc:0.800 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.41it/s]
# 100% 2/2 [00:00<00:00, 71.25it/s]
# 100% 2/2 [00:00<00:00, 71.04it/s]
# Epoch:80 bace trn_loss:0.428 trn_roc:0.875 trn_prc:0.819 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:80 bace val_loss:0.511 val_roc:0.807 val_prc:0.770 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:80 bace test_loss:0.635 test_roc:0.827 test_prc:0.801 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.51it/s]
# 100% 2/2 [00:00<00:00, 73.95it/s]
# 100% 2/2 [00:00<00:00, 60.71it/s]
# Epoch:81 bace trn_loss:0.427 trn_roc:0.874 trn_prc:0.814 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:81 bace val_loss:0.534 val_roc:0.816 val_prc:0.785 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# Epoch:81 bace test_loss:0.678 test_roc:0.829 test_prc:0.809 lr_cur:0.00070 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.36it/s]
# 100% 2/2 [00:00<00:00, 59.97it/s]
# 100% 2/2 [00:00<00:00, 64.68it/s]
# Epoch:82 bace trn_loss:0.428 trn_roc:0.873 trn_prc:0.818 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:82 bace val_loss:0.504 val_roc:0.844 val_prc:0.819 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:82 bace test_loss:0.664 test_roc:0.825 test_prc:0.803 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Model saved at epoch 82
# 100% 10/10 [00:00<00:00, 27.49it/s]
# 100% 2/2 [00:00<00:00, 73.94it/s]
# 100% 2/2 [00:00<00:00, 72.98it/s]
# Epoch:83 bace trn_loss:0.423 trn_roc:0.876 trn_prc:0.825 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:83 bace val_loss:0.506 val_roc:0.832 val_prc:0.813 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:83 bace test_loss:0.690 test_roc:0.818 test_prc:0.798 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 73.37it/s]
# 100% 2/2 [00:00<00:00, 71.56it/s]
# Epoch:84 bace trn_loss:0.433 trn_roc:0.874 trn_prc:0.823 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:84 bace val_loss:0.469 val_roc:0.827 val_prc:0.802 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:84 bace test_loss:0.669 test_roc:0.818 test_prc:0.792 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 71.25it/s]
# 100% 2/2 [00:00<00:00, 65.05it/s]
# Epoch:85 bace trn_loss:0.412 trn_roc:0.883 trn_prc:0.833 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:85 bace val_loss:0.434 val_roc:0.824 val_prc:0.785 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:85 bace test_loss:0.618 test_roc:0.828 test_prc:0.805 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.92it/s]
# 100% 2/2 [00:00<00:00, 68.87it/s]
# 100% 2/2 [00:00<00:00, 71.07it/s]
# Epoch:86 bace trn_loss:0.410 trn_roc:0.884 trn_prc:0.844 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:86 bace val_loss:0.417 val_roc:0.815 val_prc:0.769 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:86 bace test_loss:0.627 test_roc:0.824 test_prc:0.798 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.98it/s]
# 100% 2/2 [00:00<00:00, 72.60it/s]
# 100% 2/2 [00:00<00:00, 65.56it/s]
# Epoch:87 bace trn_loss:0.415 trn_roc:0.881 trn_prc:0.838 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:87 bace val_loss:0.431 val_roc:0.810 val_prc:0.758 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# Epoch:87 bace test_loss:0.622 test_roc:0.835 test_prc:0.815 lr_cur:0.00049 time elapsed 0.01 hrs (0.6 mins)
# 100% 10/10 [00:00<00:00, 27.80it/s]
# 100% 2/2 [00:00<00:00, 73.24it/s]
# 100% 2/2 [00:00<00:00, 69.75it/s]
# Epoch:88 bace trn_loss:0.416 trn_roc:0.881 trn_prc:0.838 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:88 bace val_loss:0.458 val_roc:0.798 val_prc:0.750 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:88 bace test_loss:0.633 test_roc:0.831 test_prc:0.813 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.25it/s]
# 100% 2/2 [00:00<00:00, 73.13it/s]
# 100% 2/2 [00:00<00:00, 68.12it/s]
# Epoch:89 bace trn_loss:0.416 trn_roc:0.884 trn_prc:0.839 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:89 bace val_loss:0.449 val_roc:0.809 val_prc:0.752 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:89 bace test_loss:0.606 test_roc:0.837 test_prc:0.818 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 72.12it/s]
# 100% 2/2 [00:00<00:00, 72.47it/s]
# Epoch:90 bace trn_loss:0.400 trn_roc:0.893 trn_prc:0.852 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:90 bace val_loss:0.444 val_roc:0.804 val_prc:0.750 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:90 bace test_loss:0.681 test_roc:0.830 test_prc:0.806 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 28.12it/s]
# 100% 2/2 [00:00<00:00, 65.69it/s]
# 100% 2/2 [00:00<00:00, 68.99it/s]
# Epoch:91 bace trn_loss:0.405 trn_roc:0.885 trn_prc:0.843 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:91 bace val_loss:0.497 val_roc:0.807 val_prc:0.766 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:91 bace test_loss:0.645 test_roc:0.824 test_prc:0.793 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.43it/s]
# 100% 2/2 [00:00<00:00, 73.00it/s]
# 100% 2/2 [00:00<00:00, 72.37it/s]
# Epoch:92 bace trn_loss:0.406 trn_roc:0.887 trn_prc:0.844 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:92 bace val_loss:0.467 val_roc:0.810 val_prc:0.766 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:92 bace test_loss:0.618 test_roc:0.830 test_prc:0.806 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.58it/s]
# 100% 2/2 [00:00<00:00, 71.28it/s]
# 100% 2/2 [00:00<00:00, 71.04it/s]
# Epoch:93 bace trn_loss:0.400 trn_roc:0.892 trn_prc:0.847 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:93 bace val_loss:0.426 val_roc:0.831 val_prc:0.792 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:93 bace test_loss:0.607 test_roc:0.835 test_prc:0.803 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.60it/s]
# 100% 2/2 [00:00<00:00, 72.30it/s]
# 100% 2/2 [00:00<00:00, 65.80it/s]
# Epoch:94 bace trn_loss:0.401 trn_roc:0.888 trn_prc:0.843 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:94 bace val_loss:0.436 val_roc:0.822 val_prc:0.784 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:94 bace test_loss:0.612 test_roc:0.829 test_prc:0.803 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.95it/s]
# 100% 2/2 [00:00<00:00, 69.09it/s]
# 100% 2/2 [00:00<00:00, 72.44it/s]
# Epoch:95 bace trn_loss:0.397 trn_roc:0.894 trn_prc:0.856 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:95 bace val_loss:0.469 val_roc:0.808 val_prc:0.770 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:95 bace test_loss:0.638 test_roc:0.826 test_prc:0.799 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.49it/s]
# 100% 2/2 [00:00<00:00, 71.69it/s]
# 100% 2/2 [00:00<00:00, 69.84it/s]
# Epoch:96 bace trn_loss:0.403 trn_roc:0.885 trn_prc:0.845 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:96 bace val_loss:0.494 val_roc:0.806 val_prc:0.767 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# Epoch:96 bace test_loss:0.680 test_roc:0.816 test_prc:0.782 lr_cur:0.00049 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.06it/s]
# 100% 2/2 [00:00<00:00, 73.43it/s]
# 100% 2/2 [00:00<00:00, 72.45it/s]
# Epoch:97 bace trn_loss:0.398 trn_roc:0.893 trn_prc:0.855 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:97 bace val_loss:0.471 val_roc:0.806 val_prc:0.761 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:97 bace test_loss:0.617 test_roc:0.829 test_prc:0.801 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.07it/s]
# 100% 2/2 [00:00<00:00, 73.63it/s]
# 100% 2/2 [00:00<00:00, 65.66it/s]
# Epoch:98 bace trn_loss:0.396 trn_roc:0.884 trn_prc:0.836 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:98 bace val_loss:0.479 val_roc:0.807 val_prc:0.759 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:98 bace test_loss:0.643 test_roc:0.821 test_prc:0.791 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.67it/s]
# 100% 2/2 [00:00<00:00, 69.82it/s]
# 100% 2/2 [00:00<00:00, 71.79it/s]
# Epoch:99 bace trn_loss:0.396 trn_roc:0.890 trn_prc:0.849 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:99 bace val_loss:0.446 val_roc:0.818 val_prc:0.777 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:99 bace test_loss:0.678 test_roc:0.814 test_prc:0.787 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.35it/s]
# 100% 2/2 [00:00<00:00, 66.67it/s]
# 100% 2/2 [00:00<00:00, 69.65it/s]
# Epoch:100 bace trn_loss:0.401 trn_roc:0.891 trn_prc:0.846 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:100 bace val_loss:0.463 val_roc:0.814 val_prc:0.772 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:100 bace test_loss:0.654 test_roc:0.821 test_prc:0.794 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.49it/s]
# 100% 2/2 [00:00<00:00, 71.62it/s]
# 100% 2/2 [00:00<00:00, 70.61it/s]
# Epoch:101 bace trn_loss:0.398 trn_roc:0.892 trn_prc:0.853 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:101 bace val_loss:0.480 val_roc:0.805 val_prc:0.759 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# Epoch:101 bace test_loss:0.608 test_roc:0.825 test_prc:0.798 lr_cur:0.00034 time elapsed 0.01 hrs (0.7 mins)
# 100% 10/10 [00:00<00:00, 27.96it/s]
# 100% 2/2 [00:00<00:00, 73.10it/s]
# 100% 2/2 [00:00<00:00, 67.53it/s]
# Epoch:102 bace trn_loss:0.388 trn_roc:0.895 trn_prc:0.861 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:102 bace val_loss:0.440 val_roc:0.818 val_prc:0.772 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:102 bace test_loss:0.590 test_roc:0.836 test_prc:0.813 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.49it/s]
# 100% 2/2 [00:00<00:00, 67.96it/s]
# 100% 2/2 [00:00<00:00, 70.11it/s]
# Epoch:103 bace trn_loss:0.407 trn_roc:0.888 trn_prc:0.842 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:103 bace val_loss:0.473 val_roc:0.801 val_prc:0.745 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:103 bace test_loss:0.645 test_roc:0.823 test_prc:0.803 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.76it/s]
# 100% 2/2 [00:00<00:00, 73.03it/s]
# 100% 2/2 [00:00<00:00, 72.43it/s]
# Epoch:104 bace trn_loss:0.415 trn_roc:0.882 trn_prc:0.838 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:104 bace val_loss:0.474 val_roc:0.800 val_prc:0.754 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:104 bace test_loss:0.662 test_roc:0.823 test_prc:0.785 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.51it/s]
# 100% 2/2 [00:00<00:00, 73.65it/s]
# 100% 2/2 [00:00<00:00, 72.41it/s]
# Epoch:105 bace trn_loss:0.396 trn_roc:0.892 trn_prc:0.854 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:105 bace val_loss:0.481 val_roc:0.799 val_prc:0.755 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:105 bace test_loss:0.609 test_roc:0.826 test_prc:0.791 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.74it/s]
# 100% 2/2 [00:00<00:00, 72.83it/s]
# 100% 2/2 [00:00<00:00, 68.59it/s]
# Epoch:106 bace trn_loss:0.387 trn_roc:0.895 trn_prc:0.854 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:106 bace val_loss:0.497 val_roc:0.796 val_prc:0.750 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:106 bace test_loss:0.589 test_roc:0.836 test_prc:0.810 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# 100% 2/2 [00:00<00:00, 65.14it/s]
# 100% 2/2 [00:00<00:00, 70.84it/s]
# Epoch:107 bace trn_loss:0.399 trn_roc:0.894 trn_prc:0.860 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:107 bace val_loss:0.480 val_roc:0.796 val_prc:0.747 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# Epoch:107 bace test_loss:0.593 test_roc:0.832 test_prc:0.807 lr_cur:0.00034 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.73it/s]
# 100% 2/2 [00:00<00:00, 68.58it/s]
# 100% 2/2 [00:00<00:00, 71.10it/s]
# Epoch:108 bace trn_loss:0.384 trn_roc:0.897 trn_prc:0.858 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# Epoch:108 bace val_loss:0.482 val_roc:0.802 val_prc:0.760 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# Epoch:108 bace test_loss:0.624 test_roc:0.830 test_prc:0.802 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.61it/s]
# 100% 2/2 [00:00<00:00, 73.03it/s]
# 100% 2/2 [00:00<00:00, 72.46it/s]
# Epoch:109 bace trn_loss:0.391 trn_roc:0.894 trn_prc:0.850 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# Epoch:109 bace val_loss:0.474 val_roc:0.800 val_prc:0.758 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# Epoch:109 bace test_loss:0.608 test_roc:0.832 test_prc:0.807 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.57it/s]
# 100% 2/2 [00:00<00:00, 73.54it/s]
# 100% 2/2 [00:00<00:00, 69.82it/s]
# Epoch:110 bace trn_loss:0.391 trn_roc:0.896 trn_prc:0.861 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# Epoch:110 bace val_loss:0.475 val_roc:0.804 val_prc:0.758 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# Epoch:110 bace test_loss:0.608 test_roc:0.837 test_prc:0.814 lr_cur:0.00024 time elapsed 0.01 hrs (0.8 mins)
# 100% 10/10 [00:00<00:00, 27.75it/s]
# ...
# 100% 10/10 [00:00<00:00, 27.25it/s]
# 100% 2/2 [00:00<00:00, 70.47it/s]
# 100% 2/2 [00:00<00:00, 70.78it/s]
# Epoch:163 bace trn_loss:0.383 trn_roc:0.901 trn_prc:0.865 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:163 bace val_loss:0.468 val_roc:0.806 val_prc:0.757 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:163 bace test_loss:0.620 test_roc:0.835 test_prc:0.803 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.03it/s]
# 100% 2/2 [00:00<00:00, 72.20it/s]
# 100% 2/2 [00:00<00:00, 67.37it/s]
# Epoch:164 bace trn_loss:0.370 trn_roc:0.906 trn_prc:0.873 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:164 bace val_loss:0.472 val_roc:0.805 val_prc:0.757 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:164 bace test_loss:0.623 test_roc:0.834 test_prc:0.803 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.38it/s]
# 100% 2/2 [00:00<00:00, 70.43it/s]
# 100% 2/2 [00:00<00:00, 70.83it/s]
# Epoch:165 bace trn_loss:0.367 trn_roc:0.903 trn_prc:0.871 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:165 bace val_loss:0.472 val_roc:0.803 val_prc:0.754 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:165 bace test_loss:0.620 test_roc:0.834 test_prc:0.804 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.59it/s]
# 100% 2/2 [00:00<00:00, 66.01it/s]
# 100% 2/2 [00:00<00:00, 67.80it/s]
# Epoch:166 bace trn_loss:0.376 trn_roc:0.904 trn_prc:0.872 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:166 bace val_loss:0.471 val_roc:0.805 val_prc:0.756 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:166 bace test_loss:0.619 test_roc:0.834 test_prc:0.803 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.42it/s]
# 100% 2/2 [00:00<00:00, 65.81it/s]
# 100% 2/2 [00:00<00:00, 67.52it/s]
# Epoch:167 bace trn_loss:0.369 trn_roc:0.902 trn_prc:0.867 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:167 bace val_loss:0.471 val_roc:0.805 val_prc:0.757 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:167 bace test_loss:0.614 test_roc:0.835 test_prc:0.805 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.29it/s]
# 100% 2/2 [00:00<00:00, 69.15it/s]
# 100% 2/2 [00:00<00:00, 66.52it/s]
# Epoch:168 bace trn_loss:0.380 trn_roc:0.902 trn_prc:0.863 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:168 bace val_loss:0.471 val_roc:0.801 val_prc:0.753 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:168 bace test_loss:0.614 test_roc:0.836 test_prc:0.806 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.34it/s]
# 100% 2/2 [00:00<00:00, 70.64it/s]
# 100% 2/2 [00:00<00:00, 70.66it/s]
# Epoch:169 bace trn_loss:0.366 trn_roc:0.908 trn_prc:0.874 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:169 bace val_loss:0.469 val_roc:0.803 val_prc:0.756 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:169 bace test_loss:0.611 test_roc:0.835 test_prc:0.805 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 26.48it/s]
# 100% 2/2 [00:00<00:00, 62.43it/s]
# 100% 2/2 [00:00<00:00, 71.05it/s]
# Epoch:170 bace trn_loss:0.373 trn_roc:0.904 trn_prc:0.868 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:170 bace val_loss:0.473 val_roc:0.801 val_prc:0.755 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:170 bace test_loss:0.613 test_roc:0.837 test_prc:0.808 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 27.61it/s]
# 100% 2/2 [00:00<00:00, 72.84it/s]
# 100% 2/2 [00:00<00:00, 67.29it/s]
# Epoch:171 bace trn_loss:0.374 trn_roc:0.903 trn_prc:0.865 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:171 bace val_loss:0.475 val_roc:0.800 val_prc:0.755 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# Epoch:171 bace test_loss:0.612 test_roc:0.838 test_prc:0.810 lr_cur:0.00004 time elapsed 0.02 hrs (1.2 mins)
# 100% 10/10 [00:00<00:00, 26.16it/s]
# 100% 2/2 [00:00<00:00, 64.84it/s]
# 100% 2/2 [00:00<00:00, 70.95it/s]
# Epoch:172 bace trn_loss:0.371 trn_roc:0.906 trn_prc:0.876 lr_cur:0.00004 time elapsed 0.02 hrs (1.3 mins)
# Epoch:172 bace val_loss:0.474 val_roc:0.799 val_prc:0.754 lr_cur:0.00004 time elapsed 0.02 hrs (1.3 mins)
# Epoch:172 bace test_loss:0.609 test_roc:0.837 test_prc:0.810 lr_cur:0.00004 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.28it/s]
# 100% 2/2 [00:00<00:00, 69.37it/s]
# 100% 2/2 [00:00<00:00, 69.53it/s]
# Epoch:173 bace trn_loss:0.369 trn_roc:0.905 trn_prc:0.871 lr_cur:0.00004 time elapsed 0.02 hrs (1.3 mins)
# Epoch:173 bace val_loss:0.472 val_roc:0.800 val_prc:0.755 lr_cur:0.00004 time elapsed 0.02 hrs (1.3 mins)
# Epoch:173 bace test_loss:0.604 test_roc:0.835 test_prc:0.808 lr_cur:0.00004 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.16it/s]
# 100% 2/2 [00:00<00:00, 71.29it/s]
# 100% 2/2 [00:00<00:00, 65.76it/s]
# Epoch:174 bace trn_loss:0.381 trn_roc:0.899 trn_prc:0.862 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:174 bace val_loss:0.472 val_roc:0.800 val_prc:0.756 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:174 bace test_loss:0.606 test_roc:0.838 test_prc:0.812 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.48it/s]
# 100% 2/2 [00:00<00:00, 69.98it/s]
# 100% 2/2 [00:00<00:00, 72.37it/s]
# Epoch:175 bace trn_loss:0.377 trn_roc:0.900 trn_prc:0.866 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:175 bace val_loss:0.472 val_roc:0.799 val_prc:0.755 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:175 bace test_loss:0.607 test_roc:0.839 test_prc:0.812 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 67.91it/s]
# 100% 2/2 [00:00<00:00, 69.24it/s]
# Epoch:176 bace trn_loss:0.372 trn_roc:0.905 trn_prc:0.865 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:176 bace val_loss:0.472 val_roc:0.799 val_prc:0.755 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:176 bace test_loss:0.608 test_roc:0.839 test_prc:0.810 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.06it/s]
# 100% 2/2 [00:00<00:00, 70.38it/s]
# 100% 2/2 [00:00<00:00, 67.08it/s]
# Epoch:177 bace trn_loss:0.368 trn_roc:0.906 trn_prc:0.869 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:177 bace val_loss:0.473 val_roc:0.799 val_prc:0.755 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:177 bace test_loss:0.608 test_roc:0.838 test_prc:0.810 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.43it/s]
# 100% 2/2 [00:00<00:00, 72.83it/s]
# 100% 2/2 [00:00<00:00, 62.35it/s]
# Epoch:178 bace trn_loss:0.373 trn_roc:0.898 trn_prc:0.860 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:178 bace val_loss:0.472 val_roc:0.800 val_prc:0.755 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:178 bace test_loss:0.610 test_roc:0.838 test_prc:0.810 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.35it/s]
# 100% 2/2 [00:00<00:00, 64.11it/s]
# 100% 2/2 [00:00<00:00, 69.55it/s]
# Epoch:179 bace trn_loss:0.378 trn_roc:0.901 trn_prc:0.865 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:179 bace val_loss:0.471 val_roc:0.800 val_prc:0.753 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:179 bace test_loss:0.608 test_roc:0.839 test_prc:0.811 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.56it/s]
# 100% 2/2 [00:00<00:00, 68.29it/s]
# 100% 2/2 [00:00<00:00, 70.64it/s]
# Epoch:180 bace trn_loss:0.376 trn_roc:0.902 trn_prc:0.863 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:180 bace val_loss:0.469 val_roc:0.800 val_prc:0.752 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:180 bace test_loss:0.607 test_roc:0.840 test_prc:0.813 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.16it/s]
# 100% 2/2 [00:00<00:00, 70.98it/s]
# 100% 2/2 [00:00<00:00, 70.22it/s]
# Epoch:181 bace trn_loss:0.380 trn_roc:0.899 trn_prc:0.864 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:181 bace val_loss:0.467 val_roc:0.801 val_prc:0.753 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:181 bace test_loss:0.607 test_roc:0.838 test_prc:0.811 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.62it/s]
# 100% 2/2 [00:00<00:00, 70.29it/s]
# 100% 2/2 [00:00<00:00, 66.58it/s]
# Epoch:182 bace trn_loss:0.385 trn_roc:0.903 trn_prc:0.864 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:182 bace val_loss:0.468 val_roc:0.802 val_prc:0.754 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:182 bace test_loss:0.609 test_roc:0.837 test_prc:0.810 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.71it/s]
# 100% 2/2 [00:00<00:00, 67.19it/s]
# 100% 2/2 [00:00<00:00, 70.38it/s]
# Epoch:183 bace trn_loss:0.369 trn_roc:0.905 trn_prc:0.866 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:183 bace val_loss:0.465 val_roc:0.802 val_prc:0.754 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:183 bace test_loss:0.612 test_roc:0.838 test_prc:0.811 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.19it/s]
# 100% 2/2 [00:00<00:00, 70.48it/s]
# 100% 2/2 [00:00<00:00, 70.99it/s]
# Epoch:184 bace trn_loss:0.374 trn_roc:0.900 trn_prc:0.859 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:184 bace val_loss:0.468 val_roc:0.800 val_prc:0.752 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# Epoch:184 bace test_loss:0.615 test_roc:0.838 test_prc:0.811 lr_cur:0.00003 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.66it/s]
# 100% 2/2 [00:00<00:00, 73.82it/s]
# 100% 2/2 [00:00<00:00, 72.01it/s]
# Epoch:185 bace trn_loss:0.372 trn_roc:0.906 trn_prc:0.869 lr_cur:0.00002 time elapsed 0.02 hrs (1.3 mins)
# Epoch:185 bace val_loss:0.467 val_roc:0.800 val_prc:0.753 lr_cur:0.00002 time elapsed 0.02 hrs (1.3 mins)
# Epoch:185 bace test_loss:0.613 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.3 mins)
# 100% 10/10 [00:00<00:00, 27.41it/s]
# 100% 2/2 [00:00<00:00, 71.82it/s]
# 100% 2/2 [00:00<00:00, 64.76it/s]
# Epoch:186 bace trn_loss:0.369 trn_roc:0.902 trn_prc:0.866 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:186 bace val_loss:0.468 val_roc:0.801 val_prc:0.754 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:186 bace test_loss:0.612 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.23it/s]
# 100% 2/2 [00:00<00:00, 71.04it/s]
# 100% 2/2 [00:00<00:00, 70.80it/s]
# Epoch:187 bace trn_loss:0.370 trn_roc:0.903 trn_prc:0.865 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:187 bace val_loss:0.468 val_roc:0.801 val_prc:0.755 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:187 bace test_loss:0.612 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.09it/s]
# 100% 2/2 [00:00<00:00, 71.96it/s]
# 100% 2/2 [00:00<00:00, 71.44it/s]
# Epoch:188 bace trn_loss:0.368 trn_roc:0.906 trn_prc:0.871 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:188 bace val_loss:0.469 val_roc:0.803 val_prc:0.756 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:188 bace test_loss:0.613 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.60it/s]
# 100% 2/2 [00:00<00:00, 71.97it/s]
# 100% 2/2 [00:00<00:00, 66.69it/s]
# Epoch:189 bace trn_loss:0.366 trn_roc:0.909 trn_prc:0.875 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:189 bace val_loss:0.469 val_roc:0.806 val_prc:0.762 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:189 bace test_loss:0.611 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.51it/s]
# 100% 2/2 [00:00<00:00, 65.99it/s]
# 100% 2/2 [00:00<00:00, 64.15it/s]
# Epoch:190 bace trn_loss:0.374 trn_roc:0.901 trn_prc:0.861 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:190 bace val_loss:0.470 val_roc:0.807 val_prc:0.762 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:190 bace test_loss:0.613 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.09it/s]
# 100% 2/2 [00:00<00:00, 67.65it/s]
# 100% 2/2 [00:00<00:00, 70.00it/s]
# Epoch:191 bace trn_loss:0.369 trn_roc:0.903 trn_prc:0.867 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:191 bace val_loss:0.470 val_roc:0.807 val_prc:0.763 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:191 bace test_loss:0.613 test_roc:0.838 test_prc:0.812 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.59it/s]
# 100% 2/2 [00:00<00:00, 74.16it/s]
# 100% 2/2 [00:00<00:00, 72.88it/s]
# Epoch:192 bace trn_loss:0.363 trn_roc:0.906 trn_prc:0.872 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:192 bace val_loss:0.470 val_roc:0.807 val_prc:0.763 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:192 bace test_loss:0.614 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.42it/s]
# 100% 2/2 [00:00<00:00, 72.05it/s]
# 100% 2/2 [00:00<00:00, 65.06it/s]
# Epoch:193 bace trn_loss:0.372 trn_roc:0.905 trn_prc:0.867 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:193 bace val_loss:0.469 val_roc:0.807 val_prc:0.763 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:193 bace test_loss:0.615 test_roc:0.837 test_prc:0.811 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.40it/s]
# 100% 2/2 [00:00<00:00, 69.60it/s]
# 100% 2/2 [00:00<00:00, 71.19it/s]
# Epoch:194 bace trn_loss:0.374 trn_roc:0.904 trn_prc:0.867 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:194 bace val_loss:0.468 val_roc:0.807 val_prc:0.763 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:194 bace test_loss:0.616 test_roc:0.838 test_prc:0.812 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.09it/s]
# 100% 2/2 [00:00<00:00, 71.01it/s]
# 100% 2/2 [00:00<00:00, 71.21it/s]
# Epoch:195 bace trn_loss:0.365 trn_roc:0.906 trn_prc:0.871 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:195 bace val_loss:0.467 val_roc:0.807 val_prc:0.762 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# Epoch:195 bace test_loss:0.616 test_roc:0.838 test_prc:0.812 lr_cur:0.00002 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.48it/s]
# 100% 2/2 [00:00<00:00, 69.26it/s]
# 100% 2/2 [00:00<00:00, 68.95it/s]
# Epoch:196 bace trn_loss:0.375 trn_roc:0.906 trn_prc:0.873 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:196 bace val_loss:0.465 val_roc:0.807 val_prc:0.762 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:196 bace test_loss:0.616 test_roc:0.837 test_prc:0.811 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.46it/s]
# 100% 2/2 [00:00<00:00, 70.56it/s]
# 100% 2/2 [00:00<00:00, 71.14it/s]
# Epoch:197 bace trn_loss:0.362 trn_roc:0.908 trn_prc:0.873 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:197 bace val_loss:0.465 val_roc:0.808 val_prc:0.762 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:197 bace test_loss:0.617 test_roc:0.837 test_prc:0.810 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.63it/s]
# 100% 2/2 [00:00<00:00, 66.93it/s]
# 100% 2/2 [00:00<00:00, 69.63it/s]
# Epoch:198 bace trn_loss:0.368 trn_roc:0.906 trn_prc:0.871 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:198 bace val_loss:0.465 val_roc:0.808 val_prc:0.760 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:198 bace test_loss:0.616 test_roc:0.837 test_prc:0.810 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# 100% 10/10 [00:00<00:00, 27.77it/s]
# 100% 2/2 [00:00<00:00, 73.41it/s]
# 100% 2/2 [00:00<00:00, 71.81it/s]
# Epoch:199 bace trn_loss:0.368 trn_roc:0.904 trn_prc:0.866 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:199 bace val_loss:0.466 val_roc:0.807 val_prc:0.761 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Epoch:199 bace test_loss:0.615 test_roc:0.837 test_prc:0.809 lr_cur:0.00001 time elapsed 0.02 hrs (1.4 mins)
# Model saved at epoch 199
# Testing...
# The best ckpt is ../test/06-02-21-47/best_model.ckpt
# Ckpt loading: ../test/06-02-21-47/best_model.ckpt
# 100% 2/2 [00:00<00:00, 58.85it/s]
# SEED 68 DATASET bace  The best test_loss:0.615 test_roc:0.837 test_prc:0.809.
